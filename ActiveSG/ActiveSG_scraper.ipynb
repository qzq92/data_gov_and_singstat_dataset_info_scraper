# %% [markdown]
# # ActiveSG Events information scraper.
# This notebook is used for pulling and consolidating Sports event data found on ActiveSG page https://www.activesgcircle.gov.sg/things-to-do/events.
#
# A quick filtering which was done found that only events from Jan 2023 onwards are available from the page itself, hence it is advised, to filter date starting from Jan 2023 onwards so as to get past and upcoming events.

# %% [markdown]
# Library imports

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.firefox.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException, TimeoutException
from datetime import datetime
from selenium.webdriver.firefox.options import Options
import pandas as pd
import calendar
import time

# %% [markdown]
# Below are the firefox profile options set to speed up loading process. Note: Do download and Install GeckoDriver in Selenium and set the PATH variable in sys variable to point to it in order to ensure that the FireFox Driver for Selenium can work. You may point it via a Service module of selenium' firefox service instead of using PATH variable as an alternative as follows.

# %%
options=Options()
firefox_option = webdriver.FirefoxProfile()
firefox_option.set_preference("network.http.pipelining", True)
firefox_option.set_preference("network.http.proxy.pipelining", True)
firefox_option.set_preference("network.http.pipelining.maxrequests", 8)
firefox_option.set_preference("content.notify.interval", 500000)
firefox_option.set_preference("content.notify.ontimer", True)
firefox_option.set_preference("content.switch.threshold", 250000)

options.profile = firefox_option

# %% [markdown]
# ## Main execution of info scraping

# %% [markdown]
# Supporting function

# %% [markdown]
# DATE configuration section
# - Set start date and end date desired for START_DATE, END_DATE

# %%
# START and END DATE setting. Modify the dates based on your need. Must be in dd/mm/yyyy
START_DATE = "1-Jan-2023"
END_DATE = "1-Dec-2024"

# Construct monthly start interval between the start/end dates
dates_list = pd.date_range(START_DATE,END_DATE, freq='MS').strftime("%d-%b-%Y").tolist()
unix_time_dict= {x: calendar.timegm(datetime.datetime.strptime(x, "%d-%b-%Y").timetuple()) for x in dates_list}
unix_time_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 7
#       5 # Construct monthly start interval between the start/end dates
#       6 dates_list = pd.date_range(START_DATE,END_DATE, freq='MS').strftime("%d-%b-%Y").tolist()
# ----> 7 unix_time_dict= {x: calendar.timegm(datetime.datetime.strptime(x, "%d-%b-%Y").timetuple()) for x in dates_list}
#       8 unix_time_dict
#
# AttributeError: type object 'datetime.datetime' has no attribute 'datetime'

# %%
#CFG
service = Service(executable_path=r"C:\Program Files\geckodriver.exe")
driver = webdriver.Firefox(service=service, options=options)

event_tracking_list = []

# Loop thru each calendar month
for date, unix_time in unix_time_dict.items():
    # Note the unix time in the url is measured in millisec
    URL = f"https://www.activesgcircle.gov.sg/things-to-do/events?date={unix_time}000&filter=All&type=All&s=All"
    driver.get(URL)
    print(f"Page showing events for the month starting {date}")
    event_xpath= "//div[@id='oneDay']/div[@class='outerDiv']"
    # Webpage wait for required paginate stuff to load
    try:
        WebDriverWait(driver, 120).until(EC.presence_of_element_located((By.XPATH, event_xpath)))
    except TimeoutException:
        print("No events found")
        continue

    print("Finding total events listed in the page")
    total_events_ele_list =  driver.find_elements(by=By.XPATH, value=event_xpath)
    print(f"Total events for the page: {len(total_events_ele_list)}")

    if total_events_ele_list == []:
        print("No events for this month.., moving to next")
        continue
    for event in total_events_ele_list:
        # Case 1: Start and end date are different
        event_href_xpath = ".//a"
        try:
            event_href = event.find_element(by=By.XPATH, value=event_href_xpath).get_attribute("href")
        except NoSuchElementException:
            print("No href found.")
            event_href = ""

        event_title_xpath = ".//div[@class='cal-title']"
        try:
            event_title = event.find_element(by=By.XPATH, value=event_title_xpath).text
        except NoSuchElementException:
            print("No event title found.")
            event_title = ""
            
        event_location_xpath = ".//div[@class='venue']"
        try:
            event_location = event.find_element(by=By.XPATH, value=event_location_xpath).text
        except NoSuchElementException:
            print("No event location found.")
            event_location = ""

        # Case 1: Start and end date are different
        start_date_xpath = ".//div[@class='d-wrap']/div[@class='sDate']/div[contains(@class,'round')]/div[@class='b-date']"
        end_date_xpath = ".//div[@class='d-wrap']/div[@class='eDate']/div[contains(@class,'round')]/div[@class='b-date']"
        try:
            start_date = event.find_element(by=By.XPATH, value=start_date_xpath).text
            start_date = start_date.replace("\n", " ")
            end_date = event.find_element(by=By.XPATH, value=end_date_xpath).text
            end_date = end_date.replace("\n", " ")

            date_period = start_date + " - " + end_date
        except NoSuchElementException:
            print("No separate start/end date found")
            date_period = ""

        # Make another attempt
        if date_period == "":
            # Case 2: Start/end date the same
            print("Attempting to find date-day element")
            try:
                same_start_end_date_xpath = ".//div[@class='date-day']"
                date = event.find_element(by=By.XPATH, value=same_start_end_date_xpath).text
                date = date.replace("\n", " ")
                date_period = date + " - " + date
            except NoSuchElementException:
                print("No date-day element found")
                date_period = ""

        event_metadata_list = [event_title, date_period, event_location, event_href]
        print(event_metadata_list)
        event_tracking_list.append(event_metadata_list)
    print("Sleeping before going next page")
    time.sleep(5)
    print()

# Save to csv file
print("Saving to csv file")
if event_tracking_list:
    df = pd.DataFrame(event_tracking_list, columns=["Event Title", "Date", "Location", "URL"])

    # Drop duplicates for cases with same date/location/url
    df.drop_duplicates(subset=["Date", "Location", "URL"], inplace=True, keep="last")
    df.dropna(subset=["Date", "Location", "URL"], inplace=True)
    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime.now().strftime("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now

    dataset_filename = f"ActiveSG_dataset_{file_name_date}.csv"
    df.to_csv(dataset_filename, index=False, encoding='utf-8')

driver.quit()
# Out:
# Page showing events for the month starting 01-Jan-2023
# Finding total events listed in the page
# Total events for the page: 3
# ['2023 ABL Invitational Tournament', '02 Jan - 08 Jan', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/2023-abl-invitational-tournament-02/01/2023']
# ['Singapore Sail Grand Prix', '14 Jan - 15 Jan', 'Parkland Green, East Coast Park', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-sail-grand-prix-14/01/2023']
# ['Ice Magic - City Ski Championship 2023', '21 Jan - 21 Jan', 'Bayfront Event Space', 'https://www.activesgcircle.gov.sg/things-to-do/events/ice-magic---city-ski-championship-2023-21/01/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Feb-2023
# Finding total events listed in the page
# Total events for the page: 4
# ['National Open Championships 2023', '04 Feb - 10 Feb', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-open-championships-2023-04/02/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['TTX Festival 2023', '18 FEB - 18 FEB', 'OCBC Hall 1 @ 5 Stadium Drive OCBC Arena S397631', 'https://www.activesgcircle.gov.sg/things-to-do/events/ttx-festival-2023-18/02/2023']
# ['Toa Payoh Integrated Development (TPID) Public Roadshow', '25 Feb - 26 Feb', 'HDB Hub Atrium', 'https://www.activesgcircle.gov.sg/things-to-do/events/toa-payoh-integrated-development-(tpid)-public-roadshow-25/02/2023']
# ['37th ASEAN Senior Amateur Golf Championship 2023', '27 Feb - 01 Mar', 'Singapore Island Country Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/37th-asean-senior-amateur-golf-championship-2023-27/02/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Mar-2023
# Finding total events listed in the page
# Total events for the page: 10
# ['37th ASEAN Senior Amateur Golf Championship 2023', '27 Feb - 01 Mar', 'Singapore Island Country Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/37th-asean-senior-amateur-golf-championship-2023-27/02/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['MetaSprint Series Triathlon', '05 MAR - 05 MAR', 'East Coast Park', 'https://www.activesgcircle.gov.sg/things-to-do/events/metasprint-series-triathlon-05/03/2023']
# ['Singapore Smash 2023', '07 Mar - 19 Mar', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-smash-2023-07/03/2023']
# ['7th ASEAN Inline Freestyle Championship', '11 Mar - 13 Mar', 'DMarquee Exhibition Hall Downtown East', 'https://www.activesgcircle.gov.sg/things-to-do/events/7th-asean-inline-freestyle-championship-11/03/2023']
# ['PIF Aramco Team Series Presented by Public Investment Fund - Singapore', '16 Mar - 18 Mar', 'Laguna National Golf Resort Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/pif-aramco-team-series-presented-by-public-investment-fund---singapore--16/03/2023']
# ['Asian Water Polo Championships 2023', '22 Mar - 27 Mar', 'OCBC Aquatic Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/asian-water-polo-championships-2023-22/03/2023']
# ['Merlion Cup 2023', '24 Mar - 26 Mar', 'Jalan Besar Stadium, 100 Tyrwhitt Rd, Singapore 207542', 'https://www.activesgcircle.gov.sg/things-to-do/events/merlion-cup-2023-24/03/2023']
# No event location found.
# No separate start/end date found
# Attempting to find date-day element
# ['Active Health Webinar - Moving More at the Workplace', '25 MAR - 25 MAR', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/active-health-webinar---moving-more-at-the-workplace-25/03/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['GEN Z ALPHA Series', '26 MAR - 26 MAR', 'SINGAPORE SPORTS HUB (ARENA PARK)', 'https://www.activesgcircle.gov.sg/things-to-do/events/gen-z-alpha-series-26/03/2023']
# ['FIBA 3x3 Asia Cup 2023', '29 Mar - 02 Apr', 'Singapore Sports Hub, OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/fiba-3x3-asia-cup-2023--29/03/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Apr-2023
# Finding total events listed in the page
# Total events for the page: 9
# ['FIBA 3x3 Asia Cup 2023', '29 Mar - 02 Apr', 'Singapore Sports Hub, OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/fiba-3x3-asia-cup-2023--29/03/2023']
# ['HSBC Singapore Rugby Sevens 2023', '08 Apr - 09 Apr', 'National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/hsbc-singapore-rugby-sevens-2023-08/04/2023']
# ['Singapore Jump Fest 2023', '08 Apr - 09 Apr', 'HomeTeamNS Khatib, 2 Yishun Walk, Level 2 Ballroom, Singapore 767944', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-jump-fest-2023-08/04/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore International Triathlon 2023', '16 APR - 16 APR', 'Angsana Green at East Coast Parkway', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-international-triathlon-2023-16/04/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['2XU Compression Run', '16 APR - 16 APR', 'F1 Pit Building', 'https://www.activesgcircle.gov.sg/things-to-do/events/2xu-compression-run--16/04/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Bounce On Recovery - Stick Yoga', '16 APR - 16 APR', 'OCBC Square (Stadium Walk)', 'https://www.activesgcircle.gov.sg/things-to-do/events/bounce-on-recovery---stick-yoga-16/04/2023']
# ['83rd Singapore Open Track & Field Championships 2023', '26 Apr - 28 Apr', 'Home of Athletics & National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/83rd-singapore-open-track-&-field-championships-2023-26/04/2023']
# ['Celebrate Hari Raya at Stadium Roar', '29 Apr - 01 May', 'Singapore Sports Hub, Stadium Roar', 'https://www.activesgcircle.gov.sg/things-to-do/events/celebrate-hari-raya-at-stadium-roar-29/04/2023']
# ['Citi Para Swimming World Series Singapore 2023', '29 Apr - 01 May', 'OCBC Aquatic Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/citi-para-swimming-world-series-singapore-2023-29/04/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-May-2023
# Finding total events listed in the page
# Total events for the page: 19
# ['Celebrate Hari Raya at Stadium Roar', '29 Apr - 01 May', 'Singapore Sports Hub, Stadium Roar', 'https://www.activesgcircle.gov.sg/things-to-do/events/celebrate-hari-raya-at-stadium-roar-29/04/2023']
# ['Citi Para Swimming World Series Singapore 2023', '29 Apr - 01 May', 'OCBC Aquatic Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/citi-para-swimming-world-series-singapore-2023-29/04/2023']
# No event location found.
# ['ActivChallenge Season 1 - 7 Day Personalised Home Fitness Challenge', '01 May - 07 May', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/activchallenge-season-1---7-day-personalised-home-fitness-challenge-01/05/2023']
# No event location found.
# ['Olympic Esports Week Singapore 2023 Community Activation', '05 May - 25 Jun', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/olympic-esports-week-singapore-2023-community-activation-05/05/2023']
# ['OCBC Cycle 2023', '06 May - 05 Jun', 'Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/ocbc-cycle-2023-06/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['The Urgent Run 2023', '07 MAY - 07 MAY', 'Event Square @ Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/the-urgent-run-2023-07/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Fort Canning Run 2023', '07 MAY - 07 MAY', 'Fort Canning Park, Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/fort-canning-run-2023-07/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['2XU Challenge', '14 MAY - 14 MAY', 'Marina Barrage', 'https://www.activesgcircle.gov.sg/things-to-do/events/2xu-challenge-14/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A Division Volleyball', '16 MAY - 16 MAY', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---a-division-volleyball--16/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A Division Badminton', '17 MAY - 17 MAY', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---a-division-badminton-17/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A & B Division Swimming', '19 MAY - 19 MAY', 'OCBC Aquatic Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---a-&-b-division-swimming-19/05/2023']
# ['OSIM Sundown Marathon Singapore 2023', '20 May - 21 May', 'F1 Pit Building', 'https://www.activesgcircle.gov.sg/things-to-do/events/osim-sundown-marathon-singapore-2023-20/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Femmes First 2023 - Celebrate WoW', '20 MAY - 20 MAY', 'Stadium Riverside Walk, Singapore Sports Hub, Singapore 271003', 'https://www.activesgcircle.gov.sg/things-to-do/events/femmes-first-2023---celebrate-wow-20/05/2023']
# ['Batam Triathlon', '20 May - 21 May', 'Nongsa Resorts, Batam Indonesia', 'https://www.activesgcircle.gov.sg/things-to-do/events/batam-triathlon-20/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A Division Basketball Finals', '22 MAY - 22 MAY', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---a-division-basketball-finals-22/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A Division Table Tennis Finals', '22 MAY - 22 MAY', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---table-tennis-a-division-finals-22/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2023 - A Division Football', '26 MAY - 26 MAY', 'National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2023---a-division-football-26/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['TriFactor Bike & CycleRun Singapore', '28 MAY - 28 MAY', 'Nicoll Highway, Republic Avenue', 'https://www.activesgcircle.gov.sg/things-to-do/events/-trifactor-bike-&-cyclerun-singapore-28/05/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Family Fun Day', '28 MAY - 28 MAY', 'United World College - 1207 Dover Road', 'https://www.activesgcircle.gov.sg/things-to-do/events/family-fun-day--28/05/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Jun-2023
# Finding total events listed in the page
# Total events for the page: 11
# No event location found.
# ['Olympic Esports Week Singapore 2023 Community Activation', '05 May - 25 Jun', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/olympic-esports-week-singapore-2023-community-activation-05/05/2023']
# ['OCBC Cycle 2023', '06 May - 05 Jun', 'Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/ocbc-cycle-2023-06/05/2023']
# ['LES MILLS LIVE Singapore', '03 Jun - 04 Jun', 'OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/les-mills-live-singapore-03/06/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Community Group Fitness Classes by Les Mills Asia Pacific x Sport Singapore', '03 JUN - 03 JUN', 'Atrium of Kallang Wave Mall, 1 Stadium Pl, Singapore 397628', 'https://www.activesgcircle.gov.sg/things-to-do/events/community-group-fitness-classes-by-les-mills-asia-pacific-x-sport-singapore-03/06/2023']
# ['Singapore Badminton Open 2023', '06 Jun - 11 Jun', 'Singapore Indoor Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-badminton-open-2023-06/06/2023']
# No event location found.
# ["Support and follow Navy Medical Officer Dr Chua Jia Long's Fund Raising effort for St Luke's Hospital!", '09 Jun - 16 Jun', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/fund-raising-for-st-luke-hospital-09/06/2023']
# ['Asian Artistic Gymnastics Championships 2023', '10 Jun - 18 Jun', 'OCBC Arena Hall 1, 1 Stadium Drive Singapore, 397629', 'https://www.activesgcircle.gov.sg/things-to-do/events/asian-artistic-gymnastics-championships-2023-10/06/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Income Eco Run 2023', '11 JUN - 11 JUN', 'Marina Barrage: 8 Marina Gardens Dr, Singapore 018951', 'https://www.activesgcircle.gov.sg/things-to-do/events/income-eco-run-2023-11/06/2023']
# ["Men's 'A' International Friendlies (16-18 June)", '16 Jun - 18 Jun', 'National Stadium, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/mens-a-international-friendlies-(16-18-june)-16/06/2023']
# ['Discover the Future of Esports, Uncovered', '20 Jun - 21 Jun', 'Asian Civilisations Museum, 1 Empress Place SG 179555', 'https://www.activesgcircle.gov.sg/things-to-do/events/discover-the-future-of-esports,-uncovered-21/03/2023']
# ['Olympic Esports Week Singapore 2023', '23 Jun - 25 Jun', 'Suntec Singapore Convention & Exhibition Centre Hall 401-406', 'https://www.activesgcircle.gov.sg/things-to-do/events/olympic-esports-week-singapore-2023-23/06/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Jul-2023
# Finding total events listed in the page
# Total events for the page: 17
# No separate start/end date found
# Attempting to find date-day element
# ['Run As One Singapore 2023', '02 JUL - 02 JUL', 'Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/run-as-one-singapore-2023-02/07/2023']
# No event location found.
# No separate start/end date found
# Attempting to find date-day element
# ['Active Health Webinar - Rest & Recovery for Better Performance', '12 JUL - 12 JUL', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/active-health-webinar---rest-&-recovery-for-better-performance-12/07/2023']
# No event location found.
# ['World Youth Tchoukball Championships 2023', '14 Jul - 16 Jul', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/world-youth-tchoukball-championships-2023-14/07/2023']
# No event location found.
# ['Pesta Sukan 2023', '15 Jul - 06 Aug', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/pesta-sukan-2023-15/07/2023']
# No event location found.
# ['MWS Empowerun 2023', '21 Jul - 30 Jul', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/mws-empowerun-2023-21/07/2023']
# ['Harmony Sports Fiesta 2023', '22 Jul - 23 Jul', 'OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/harmony-sports-fiesta-2023-22/07/2023']
# ['GetActive! Singapore Sport Festivals 2023 - Woodlands', '29 Jul - 30 Jul', 'Woodlands Sport Centre (Swimming Pool)', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-sports-festival-2023-woodlands']
# ['GetActive! Singapore Sport Festivals 2023 - Toa Payoh', '29 Jul - 30 Jul', 'Toa Payoh Sport Centre (Swimming Pool)', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-sports-festival-2023-toa-payoh']
# ['GetActive! Singapore Sport Festivals 2023 - Bedok', '29 Jul - 30 Jul', 'Heartbeat @ Bedok Atrium Level 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-sports-festival-2023-bedok']
# ['GetActive! Singapore Sport Festivals 2023 - Jurong', '29 Jul - 30 Jul', 'Jurong West Sport Centre (Swimming Pool)', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-sports-festival-2023-jurong']
# ['ActiveGroove - Lion City Dance', '29 Jul - 06 Aug', 'Sports Hub Black Box Auditorium / Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/active-groove-lion-city-dance']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Fit Blast (Cardio, Strength & Endurance)', '30 JUL - 30 JUL', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-fit-blast-3-july']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - International Remix (Cardio Rocks)', '30 JUL - 30 JUL', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-international-remix-cardio-rocks']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Piloxing', '31 JUL - 31 JUL', 'OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-piloxing-31-july']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - KpopX® Fitness', '31 JUL - 31 JUL', 'OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-kpop-fitness-31-july']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Les Mills BODYCOMBAT®', '31 JUL - 31 JUL', 'OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-les-mills-bodycombat-31-july']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - International Remix (Dance Storm)', '31 JUL - 31 JUL', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-international-remix-dance-storm']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Aug-2023
# Finding total events listed in the page
# Total events for the page: 22
# No event location found.
# ['Pesta Sukan 2023', '15 Jul - 06 Aug', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/pesta-sukan-2023-15/07/2023']
# ['ActiveGroove - Lion City Dance', '29 Jul - 06 Aug', 'Sports Hub Black Box Auditorium / Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/active-groove-lion-city-dance']
# No separate start/end date found
# Attempting to find date-day element
# ["Seniors' Sports Day 2023", '03 AUG - 03 AUG', 'Sports Hub, OCBC Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/seniors-sports-day-2023']
# ['YouthCreates - Ramp it Up', '04 Aug - 06 Aug', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/youthcreates-ramp-it-up']
# ['GetActive! Singapore Heartland Festivals 2023 - Jurong', '05 Aug - 06 Aug', 'Jurong West Sport Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-heartland-festival-2023-jurong']
# ['GetActive! Singapore Heartland Festivals 2023 - Toa Payoh', '05 Aug - 06 Aug', 'Toa Payoh Sport Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-heartland-festival-2023-toa-payoh']
# ['GetActive! Singapore Heartland Festivals 2023 - Woodlands', '05 Aug - 06 Aug', 'Woodlands Sport Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-heartland-festival-2023-woodlands']
# ['GetActive! Singapore Heartland Festivals 2023 - Bedok', '05 Aug - 06 Aug', 'Bedok Sport Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-heartland-festival-2023-bedok']
# No separate start/end date found
# Attempting to find date-day element
# ['GetActive! Singapore Heartland Festivals 2023 - Tampines', '06 AUG - 06 AUG', 'Our Tampines Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/getactive-singapore-heartland-festival-2023-tampines']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - KpopX® Fitness', '07 AUG - 07 AUG', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-kpop-fitness-7-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Zumba', '07 AUG - 07 AUG', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-zumba-1-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Les Mills BODYCOMBAT®', '07 AUG - 07 AUG', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-les-mills-bodycombat-7-aug']
# ['YouthCreates - Shredder Series', '07 Aug - 09 Aug', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/youthcreates-shredder-series']
# No separate start/end date found
# Attempting to find date-day element
# ["Majulah Fiesta - Les Mills SH'BAM®", '08 AUG - 08 AUG', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-les-mills-shbam-8-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Zumba', '08 AUG - 08 AUG', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-zumba-8-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - K-Kardio', '08 AUG - 08 AUG', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-k-kardio-8-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Piloxing', '08 AUG - 08 AUG', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-piloxing-7-aug']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - MMA Workout with ONE Championship', '08 AUG - 08 AUG', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-mma-workout-with-one-championship']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Great Singapore Workout (90s) & Dance', '09 AUG - 09 AUG', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-great-singapore-workout-90s-dance']
# No separate start/end date found
# Attempting to find date-day element
# ['Majulah Fiesta - Cardio (with Singapore Twist)', '09 AUG - 09 AUG', 'Sports Hub OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/majulah-fiesta-cardio-with-singapore-twist']
# ['PTO Asian Open', '19 Aug - 20 Aug', 'Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/pto-asian-open-19/08/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['PTO Asian Open - Duathlon', '20 AUG - 20 AUG', 'Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/pto-asian-open---duathlon--20/08/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Sep-2023
# Finding total events listed in the page
# Total events for the page: 6
# No separate start/end date found
# Attempting to find date-day element
# ['Run for Inclusion 2023', '02 SEP - 02 SEP', 'Singapore Turf Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/run-for-inclusion-2023']
# No event location found.
# ['NUS Giving Run BIG 2023', '02 Sep - 11 Sep', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/nus-giving-run-big-2023-02/09/2023']
# ['FIBA ICC Singapore 2023', '21 Sep - 24 Sep', 'Singapore Indoor Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/fiba-icc-singapore-2023-21/09/2023']
# ['Mandai Wildlife Run', '23 Sep - 24 Sep', '80, Mandai Lake Road - Singapore Zoo, River Wonders, Night Safari', 'https://www.activesgcircle.gov.sg/things-to-do/events/mandai-wildlife-run-23/09/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Great Green Run', '24 SEP - 24 SEP', 'Marina Barrage', 'https://www.activesgcircle.gov.sg/things-to-do/events/great-green-run-24/09/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Walk into Life', '30 SEP - 30 SEP', 'Bedok Reservoir', 'https://www.activesgcircle.gov.sg/things-to-do/events/walk-into-life-30/09/2023']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Oct-2023
# Finding total events listed in the page
# Total events for the page: 6
# No separate start/end date found
# Attempting to find date-day element
# ['HYROX Singapore', '07 OCT - 07 OCT', 'Singapore National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/hyrox-singapore-07/10/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Ride and Ralk for Rainbows 2023', '08 OCT - 08 OCT', '8 Marina Gardens Dr, Singapore 018951', 'https://www.activesgcircle.gov.sg/things-to-do/events/ride-and-ralk-for-rainbows-2023-08/10/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['FIFA World Cup Qualifiers: Singapore vs Guam', '12 OCT - 12 OCT', 'National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/fifa-world-cup-qualifiers:-singapore-vs-guam-1697068800000']
# ['Mirxes Nations Cup 2023', '22 Oct - 28 Oct', 'Sports Hub OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/mirxes-nations-cup-2023-22102023']
# No separate start/end date found
# Attempting to find date-day element
# ['A Sporting Journey', '28 OCT - 28 OCT', '100 Guillemard Rd, Singapore Badminton Hall, Singapore 399718', 'https://www.activesgcircle.gov.sg/things-to-do/events/a-sporting-journey-28102023']
# No separate start/end date found
# Attempting to find date-day element
# ["Great Eastern Women's Run 2023", '29 OCT - 29 OCT', '1 Stadium Drive (S)397629', "https://www.activesgcircle.gov.sg/things-to-do/events/great-eastern-women's-run-2023-29/10/2023"]
# Sleeping before going next page
#
# Page showing events for the month starting 01-Nov-2023
# Finding total events listed in the page
# Total events for the page: 9
# ['74th Singapore Cricket Club International Rugby 7s', '04 Nov - 05 Nov', 'SCC Padang', 'https://www.activesgcircle.gov.sg/things-to-do/events/74th-singapore-cricket-club-international-rugby-7s-545831']
# ['Asian Canoe Polo Championships 2023', '09 Nov - 12 Nov', '12A Bayfront Ave, Singapore 018970', 'https://www.activesgcircle.gov.sg/things-to-do/events/asian-canoe-polo-championships-2023-233314']
# ['CELEBRATE DEEPAVALI WITH RANGOLI & RHYTHM', '10 Nov - 11 Nov', 'OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/celebrate-deepavali-with-rangoli-&-rhythm-303664']
# No separate start/end date found
# Attempting to find date-day element
# ['Ngee Ann City 3V2 Tag Rugby Carnival', '11 NOV - 11 NOV', 'Ngee Ann City, Civic Plaza', 'https://www.activesgcircle.gov.sg/things-to-do/events/ngee-ann-city-3v2-tag-rugby-carnival-647726']
# No separate start/end date found
# Attempting to find date-day element
# ['Tales from the Nusantara: The Victorious Buffalo', '11 NOV - 11 NOV', 'Singapore Sports Museum, 6 Stadium Walk', 'https://www.activesgcircle.gov.sg/things-to-do/events/tales-from-the-nusantara:-the-victorious-buffalo-311810']
# No separate start/end date found
# Attempting to find date-day element
# ['Jump For Hope 2023', '18 NOV - 18 NOV', 'Far East Plaza, Atrium @ Level 2, 14 Scotts Rd, Singapore 228213', 'https://www.activesgcircle.gov.sg/things-to-do/events/jump-for-hope-2023--568979']
# No separate start/end date found
# Attempting to find date-day element
# ['FIFA World Cup 2026 Qualifiers: Singapore vs Thailand', '21 NOV - 21 NOV', 'Singapore National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/fifa-world-cup-2026-qualifiers-singapore-vs-thai-21112023']
# ['SINGAPORE REGATTA WATERFEST 2023', '25 Nov - 26 Nov', 'Water Sports Centre, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-regatta-waterfest-2023-454864']
# No separate start/end date found
# Attempting to find date-day element
# ['National Fours Championships 2023 Semifinals & Finals (Lawn Bowls)', '25 NOV - 25 NOV', 'Kallang Lawn Bowls Green - 8 Stadium Boulevard, Singapore 397804', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-fours-championships-2023-semifinals-&-finals-(lawn-bowls)-223262']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Dec-2023
# Finding total events listed in the page
# Total events for the page: 12
# ['Singapore Standard Chartered Marathon 2023', '01 Dec - 03 Dec', 'Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-standard-chartered-marathon-2023-01/12/2023']
# No separate start/end date found
# Attempting to find date-day element
# ['Sporty Playdate', '02 DEC - 02 DEC', 'OCBC Square, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/sporty-playdate-476813']
# ['14TH WOMEN’S WORLD FLOORBALL CHAMPIONSHIPS 2023', '02 Dec - 10 Dec', 'OCBC Arena & Singapore Indoor Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/14th-women%E2%80%99s-world-floorball-championships-2023-322571']
# ['The Journey Onwards', '06 Dec - 31 Dec', 'Stadium Roar, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/the-journey-onwards-760843']
# No event location found.
# ['Santa Race For Wishes 2023', '09 Dec - 31 Dec', '', 'https://www.activesgcircle.gov.sg/things-to-do/events/santa-race-for-wishes-2023-699733']
# No separate start/end date found
# Attempting to find date-day element
# ['A Golden Thread: Sport in Singapore - Visions For Change Book Talk', '13 DEC - 13 DEC', "National Library Building, Level 1, Visitor's Briefing Room", 'https://www.activesgcircle.gov.sg/things-to-do/events/a-golden-thread:-sport-in-singapore---visions-for-change-book-talk-607289']
# ['4 Nations Hockey Tournament 2023', '13 Dec - 17 Dec', '57 Anchorvale Road, Sengkang Sport Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/4-nations-hockey-tournament-2023-160672']
# ['Bianka Panova International Cup 2023 (BPIC)', '20 Dec - 22 Dec', 'OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/bianka-panova-international-cup-2023-(bpic)-485622']
# ['"Queen Leoterra" Theatre Show', '20 Dec - 22 Dec', 'OCBC Arena Hall 1', 'https://www.activesgcircle.gov.sg/things-to-do/events/']
# ['Dragon Awakening Virtual Marathon 2024', '20 Dec - 10 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/dragon-awakening-virtual-marathon-2024-776711']
# ['Way of the Warrior Virtual Marathon 2024', '20 Dec - 10 Apr', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/way-of-the-warrior-virtual-marathon-2024-424313']
# No separate start/end date found
# Attempting to find date-day element
# ['GRIT ASIA 3x3 PRO CHALLENGE FINALS PLAYOFF', '23 DEC - 23 DEC', 'Our Tampines Hub, Team Sports Hall, Level 2', 'https://www.activesgcircle.gov.sg/things-to-do/events/grit-asia-3x3-pro-challenge-finals-playoff-424820']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Jan-2024
# Finding total events listed in the page
# Total events for the page: 22
# ['Dragon Awakening Virtual Marathon 2024', '20 Dec - 10 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/dragon-awakening-virtual-marathon-2024-776711']
# ['Way of the Warrior Virtual Marathon 2024', '20 Dec - 10 Apr', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/way-of-the-warrior-virtual-marathon-2024-424313']
# ['Jumpshot 3x3', '06 Jan - 07 Jan', 'Bukit Panjang Plaza', 'https://www.activesgcircle.gov.sg/things-to-do/events/jumpshot-3x3-544636']
# No separate start/end date found
# Attempting to find date-day element
# ['Sunday Morning Flow Yoga', '07 JAN - 07 JAN', 'Gazebo @ Fort Canning Green', 'https://www.activesgcircle.gov.sg/things-to-do/events/sunday-morning-flow-yoga-07012024']
# ['Carry Hope 2024', '07 Jan - 29 Feb', '25 Feb 2024 - OCBC Square, Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/carry-hope-2024-571139']
# No separate start/end date found
# Attempting to find date-day element
# ['Football Legends Charity Match, Teams: LMTB Global FC vs SHINE All-Stars', '12 JAN - 12 JAN', 'Our Tampines Hub, Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/lmtb-global-fc-vs-shine-all-stars']
# ['Waein Cup Open Championship Singapore 2024', '12 Jan - 14 Jan', 'Our Tampines Hub, Community Auditorium', 'https://www.activesgcircle.gov.sg/things-to-do/events/waein-cup-open-championship-singapore']
# No separate start/end date found
# Attempting to find date-day element
# ['NUS Bizad Charity Run 2024', '13 JAN - 13 JAN', 'National University Singapore, 12 Science Drive 2, Singapore 117549', 'https://www.activesgcircle.gov.sg/things-to-do/events/nus-bizad-charity-run-2024']
# No separate start/end date found
# Attempting to find date-day element
# ["Kid's Cycling Clinic", '13 JAN - 13 JAN', 'Our Tampines Hub, Central Plaza', 'https://www.activesgcircle.gov.sg/things-to-do/events/kids-cycling-clinic']
# No separate start/end date found
# Attempting to find date-day element
# ['Sunday Morning Flow Yoga', '14 JAN - 14 JAN', 'Gazebo @ Fort Canning Green', 'https://www.activesgcircle.gov.sg/things-to-do/events/sunday-morning-flow-yoga-14012024']
# ['Walk Challenge @ South West', '15 Jan - 29 Feb', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/walk-challenge-@-south-west-969454']
# No separate start/end date found
# Attempting to find date-day element
# ['ASICS Running Club', '16 JAN - 16 JAN', 'Singapore Indoor Stadium (Carpark L)', 'https://www.activesgcircle.gov.sg/things-to-do/events/asics-running-club-150124']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport360: Discover Badminton', '18 JAN - 18 JAN', 'Yio Chu Kang Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport360-discover-badminton-18012024']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore Netball Team - Netball Clinic X Meet & Greet', '20 JAN - 20 JAN', 'Our Tampines Hub, Level 3 Community Auditorium', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-netball-team-clinic-meet-greet']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport360: Discover Powerchair Football', '20 JAN - 20 JAN', 'Handicaps Welfare Association', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport360-discover-powerchair-football-20012024']
# No separate start/end date found
# Attempting to find date-day element
# ['Sunday Morning Flow Yoga', '21 JAN - 21 JAN', 'Gazebo @ Fort Canning Green', 'https://www.activesgcircle.gov.sg/things-to-do/events/sunday-morning-flow-yoga-21012024']
# No separate start/end date found
# Attempting to find date-day element
# ['2024 Singapore Canoe Marathon', '21 JAN - 21 JAN', 'Sports Hub Water Sports Centre, 8 Stadium Walk, Singapore 397699', 'https://www.activesgcircle.gov.sg/things-to-do/events/2024-singapore-canoe-marathon-885180']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport360: Discover Badminton', '25 JAN - 25 JAN', 'Yio Chu Kang Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport360-discover-badminton-25012024']
# No separate start/end date found
# Attempting to find date-day element
# ['Let’s Walk, Singapore', '27 JAN - 27 JAN', 'Jurong Lake Gardens', 'https://www.activesgcircle.gov.sg/things-to-do/events/let%E2%80%99s-walk,-singapore-680899']
# No separate start/end date found
# Attempting to find date-day element
# ['Fitness Aesthetic 2024', '28 JAN - 28 JAN', 'Civil Service Club @ Tessensohn', 'https://www.activesgcircle.gov.sg/things-to-do/events/fitness-aesthetic-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['MetaSprint Series Aquathlon 2024', '28 JAN - 28 JAN', 'Sentosa', 'https://www.activesgcircle.gov.sg/things-to-do/events/metasprintseries-aquathlon-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Bowling', '31 JAN - 31 JAN', 'Singapore Island Country Club (Island Location)', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport360-discover-bowling-31012024']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Feb-2024
# Finding total events listed in the page
# Total events for the page: 18
# ['Dragon Awakening Virtual Marathon 2024', '20 Dec - 10 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/dragon-awakening-virtual-marathon-2024-776711']
# ['Way of the Warrior Virtual Marathon 2024', '20 Dec - 10 Apr', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/way-of-the-warrior-virtual-marathon-2024-424313']
# ['Carry Hope 2024', '07 Jan - 29 Feb', '25 Feb 2024 - OCBC Square, Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/carry-hope-2024-571139']
# ['Walk Challenge @ South West', '15 Jan - 29 Feb', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/walk-challenge-@-south-west-969454']
# ['February Happenings @Bukit Canberra', '01 Feb - 29 Feb', '21 Canberra Link Singapore, Singapore 756973', 'https://www.activesgcircle.gov.sg/things-to-do/events/february-happenings-bukit-canberra-feb-2024']
# ['Changi Run 2024', '01 Feb - 31 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/changi-run-2024-443983']
# ['MUSportIC 2024', '01 Feb - 31 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/musportic-2024-678668']
# No separate start/end date found
# Attempting to find date-day element
# ['Austcham Newbie Day', '03 FEB - 03 FEB', 'Kallang Dragon Boat Nursery', 'https://www.activesgcircle.gov.sg/things-to-do/events/austcham-newbie-day-03022024']
# ['Lunar Competition Singapore Gymnastics', '03 Feb - 04 Feb', 'Bishan Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/lunar-competition-singapore-gymnastics-360459']
# ['Singapore-Malaysia Test Series 2024', '15 Feb - 18 Feb', 'Our Tampines Hub Arena', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-malaysia-test-series-2024-212179']
# ['NATIONAL 3X3 LEAGUE 2024', '17 Feb - 18 Feb', 'SENG KANG GRAND MALL', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-3x3-league-2024-484008']
# ['Singapore Sports Hub National Open Championships 2024', '18 Feb - 24 Feb', 'Singapore Sports Hub, OCBC Arena Hall 2', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-sports-hub-national-open-championship-2024']
# ['National Championships Gymnastics 2024 - RG Junior Championships', '23 Feb - 25 Feb', 'Bishan Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-championships-gymnastics-2024---rg-junior-championships-340108']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore Premier League Pre-season Friendlies', '23 FEB - 23 FEB', 'Various locations', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-premier-league-pre-season-friendlies-870481']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore Premier League Pre-season Friendlies', '24 FEB - 24 FEB', 'Our Tampines Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-premier-league-pre-season-friendlies-298131']
# No separate start/end date found
# Attempting to find date-day element
# ['Dragon Soars, Fortune Roars: Prosperity Run 2024', '24 FEB - 24 FEB', 'Arena Park, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/dragon-soars-fortune-roars-prosperity-run-2024%E2%80%8B']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore Premier League Pre-season Friendlies', '24 FEB - 24 FEB', 'Our Tampines Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-premier-league-pre-season-friendlies-492089']
# ["HSBC Women's World Championship 2024", '29 Feb - 03 Mar', 'Sentosa Golf Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/hsbc-womens-world-championship-2024']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Mar-2024
# Finding total events listed in the page
# Total events for the page: 25
# ['Dragon Awakening Virtual Marathon 2024', '20 Dec - 10 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/dragon-awakening-virtual-marathon-2024-776711']
# ['Way of the Warrior Virtual Marathon 2024', '20 Dec - 10 Apr', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/way-of-the-warrior-virtual-marathon-2024-424313']
# ['Changi Run 2024', '01 Feb - 31 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/changi-run-2024-443983']
# ['MUSportIC 2024', '01 Feb - 31 Mar', 'Virtual', 'https://www.activesgcircle.gov.sg/things-to-do/events/musportic-2024-678668']
# ["HSBC Women's World Championship 2024", '29 Feb - 03 Mar', 'Sentosa Golf Club', 'https://www.activesgcircle.gov.sg/things-to-do/events/hsbc-womens-world-championship-2024']
# ['National Championships Gymnastics 2024 - Artistic Junior Championships', '02 Mar - 03 Mar', 'Bishan Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-championships-gymnastics-2024---artistic-junior-championships-944665']
# No separate start/end date found
# Attempting to find date-day element
# ['Youth Aquathlon League', '02 MAR - 02 MAR', 'XCL Academy 2 Yishun Street 42 Singapore 76', 'https://www.activesgcircle.gov.sg/things-to-do/events/youth-aquathlon-league-738656']
# ['National 3x3 League 2024', '02 Mar - 03 Mar', 'Bugis+', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-3x3-league-2024-511059']
# No separate start/end date found
# Attempting to find date-day element
# ['Badminton Tournament 2024', '03 MAR - 03 MAR', 'Teck Whye Avenue, Chua Chu Kang Community Club, Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/badminton-tournament-2024-197764']
# No separate start/end date found
# Attempting to find date-day element
# ['North West Brisk Walking @ Marsiling', '03 MAR - 03 MAR', 'Choa Chu Kang Sport Centre, 1 Choa Chu Kang Street 53, Singapore 689236', 'https://www.activesgcircle.gov.sg/things-to-do/events/north-west-brisk-walking-@-marsiling-329394']
# ['National Championships Gymnastics 2024', '08 Mar - 17 Mar', 'Bishan Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-championships-gymnastics-2024-370684']
# ['Daisy Tan Carnival 2024', '09 Mar - 16 Mar', 'Kallang Netball Centre', 'https://www.activesgcircle.gov.sg/things-to-do/events/daisy-tan-carnival-2024-338671']
# ['Singapore Smash 2024', '10 Mar - 17 Mar', 'OCBC Arena, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-smash-2024-192208']
# No separate start/end date found
# Attempting to find date-day element
# ['ActiveSG Aikido Club School Holiday Programme', '15 MAR - 15 MAR', 'Serangoon Stadium Activity Room', 'https://www.activesgcircle.gov.sg/things-to-do/events/activesg-aikido-club-school-holiday-programme-515446']
# ['Pink Warriors 3X3', '16 Mar - 17 Mar', 'Sports Hub Hard Courts', 'https://www.activesgcircle.gov.sg/things-to-do/events/pink-warriors-3x3-170324']
# No separate start/end date found
# Attempting to find date-day element
# ['National Para Table Tennis Championships 2024', '16 MAR - 16 MAR', 'Jurong East Sport Hall 21 Jurong East Street 31, Singapore 609517', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-para-table-tennis-championships-2024-555617']
# No separate start/end date found
# Attempting to find date-day element
# ['MetaSprint Series Duathlon 2024', '17 MAR - 17 MAR', 'F1 Village', 'https://www.activesgcircle.gov.sg/things-to-do/events/metasprintseries-duathlon-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['Car-Free Sunday', '17 MAR - 17 MAR', "Civic & Central Business Districts (starting from St. Andrew's Road)", 'https://www.activesgcircle.gov.sg/things-to-do/events/car-free-sunday-242241']
# No separate start/end date found
# Attempting to find date-day element
# ['FIFA World Cup 2026™ - Preliminary (Round 2) - Singapore vs China', '21 MAR - 21 MAR', 'National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/fifa-world-cup-2026-round-2-preliminary-singapore-vs-china-857625']
# No separate start/end date found
# Attempting to find date-day element
# ['Children’s Wishing Well Inter-School Aquathlon Championships 2024', '23 MAR - 23 MAR', 'Sentosa, New Mempari Beach, 110 Tanjong Beach Walk, 098943 Singapore, 098943', 'https://www.activesgcircle.gov.sg/things-to-do/events/children-wishing-well-inter-school-aquathlon-championships-2024-899357']
# No separate start/end date found
# Attempting to find date-day element
# ['Sembawang West Biathlon Challenge 2024', '24 MAR - 24 MAR', 'Woodlands Stadium (1 Woodlands Street 13, Singapore 738597)', 'https://www.activesgcircle.gov.sg/things-to-do/events/sembawang-west-biathlon-challenge-2024-278241']
# ['FIBA 3x3 Asia Cup 2024', '27 Mar - 31 Mar', 'OCBC Square, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/fiba-3x3-asia-cup-2024-312600']
# No separate start/end date found
# Attempting to find date-day element
# ['Run For Light 2024', '30 MAR - 30 MAR', 'Pasir Ris Park, Native Lawn, Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/run-for-light-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['Tour de Care 2024', '30 MAR - 30 MAR', '100PLUS Promenade @ Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/tour-de-care-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['1st Singapore Indoor Rowing Championships', '30 MAR - 30 MAR', 'The Row Space, 1 Aliwal St, Level 3 Unit 3B, Singapore 199894', 'https://www.activesgcircle.gov.sg/things-to-do/events/1st-singapore-indoor-rowing-championships-842552']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Apr-2024
# Finding total events listed in the page
# Total events for the page: 20
# ['Way of the Warrior Virtual Marathon 2024', '20 Dec - 10 Apr', 'Virtual Run', 'https://www.activesgcircle.gov.sg/things-to-do/events/way-of-the-warrior-virtual-marathon-2024-424313']
# No separate start/end date found
# Attempting to find date-day element
# ['RSR Challenge Series Race #2', '04 APR - 04 APR', 'East Coast Park, CP B1', 'https://www.activesgcircle.gov.sg/things-to-do/events/rsr-challenge-series-race-2-800347']
# No separate start/end date found
# Attempting to find date-day element
# ['The Music Run', '13 APR - 13 APR', 'Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/the-music-run-885384']
# No separate start/end date found
# Attempting to find date-day element
# ['PTO Asian Open 2024 Duathlon', '14 APR - 14 APR', 'Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/pto-asian-open-2024-duathlon--669295']
# No separate start/end date found
# Attempting to find date-day element
# ['PTO Asian Open 2024 Triathlon', '14 APR - 14 APR', 'Marina Bay', 'https://www.activesgcircle.gov.sg/things-to-do/events/pto-asian-open-2024--377622']
# No separate start/end date found
# Attempting to find date-day element
# ['GEN Z Alpha Series 1 & Urban Eliminator', '14 APR - 14 APR', '5 Stadium Dr, Singapore 397631', 'https://www.activesgcircle.gov.sg/things-to-do/events/gen-z-alpha-series-1-&-urban-eliminator--703642']
# ['National School Games 2024 Swimming Junior and Senior Division Finals', '15 Apr - 19 Apr', 'OCBC Aquatic Centre, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-swimming-junior-and-senior-division-finals-936594']
# ['National School Games 2024 Wushu Junior and Senior Division Finals', '15 Apr - 19 Apr', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-wushu-junior-and-senior-division-finals-381186']
# ['National School Games 2024 Track and Field A, B and C Division Finals', '18 Apr - 19 Apr', 'National Stadium, SIngapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-track-and-field-a-b-c-division-finals-320870']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Badminton B Division Finals', '18 APR - 18 APR', 'OCBC Arena Hall 2, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-badminton-b-division-finals--644036']
# ['April Camp with Olympian Nicol Zelikman', '19 Apr - 30 Apr', '2 Bukit Merah Central, #02-03, Singapore 159835', 'https://www.activesgcircle.gov.sg/things-to-do/events/april-camp-with-olympian-nicol-zelikman-498704']
# ['Masterclass with Olympian Nicol Zelikman', '20 Apr - 28 Apr', '2 Bukit Merah Central, #02-03, Singapore 159835', 'https://www.activesgcircle.gov.sg/things-to-do/events/masterclass-with-olympian-nicol-zelikman-248325']
# ['NATIONAL 3X3 LEAGUE 2024', '20 Apr - 21 Apr', 'Westgate Lvl 1 Courtyard', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-3x3-league-2024-941737']
# No separate start/end date found
# Attempting to find date-day element
# ['2XU Compression Run 2024', '21 APR - 21 APR', 'F1 Pit Building', 'https://www.activesgcircle.gov.sg/things-to-do/events/2xu-compression-run-2024-243103']
# No separate start/end date found
# Attempting to find date-day element
# ['Starhub Football Festival', '21 APR - 21 APR', 'Town Square @ Our Tampines Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/starhub-football-festival-191240']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Goalball', '21 APR - 21 APR', 'Delta Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport-360-discover-goalball-742705']
# ['National School Games 2024 Swimming A, B and C Division Finals', '22 Apr - 26 Apr', 'OCBC Aquatic Centre, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-swimming-a,-b-and-c-division-finals-450659']
# ['National School Games 2024 Wushu A, B and C Division Finals', '22 Apr - 26 Apr', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-wushu-a,-b-and-c-division-finals-517597']
# No separate start/end date found
# Attempting to find date-day element
# ['HWA Wheel, Walk or Jog & Family Carnival 2024', '27 APR - 27 APR', 'OCBC Square, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/hwa-wheel,-walk-or-jog-&-family-carnival-2024-114361']
# No separate start/end date found
# Attempting to find date-day element
# ['Let’s Walk, Singapore (FREE 6KM WALK @ VIVOCITY - SILOSO BEACH)', '27 APR - 27 APR', 'From VivoCity to Sentosa Siloso Beach and back', 'https://www.activesgcircle.gov.sg/things-to-do/events/let%E2%80%99s-walk,-singapore-(free-6km-walk-@-vivocity---siloso-beach)-471994']
# Sleeping before going next page
#
# Page showing events for the month starting 01-May-2024
# Finding total events listed in the page
# Total events for the page: 26
# No separate start/end date found
# Attempting to find date-day element
# ['SEA 7s', '02 MAY - 02 MAY', 'Jurong West ActiveSG Stadium, 20 Jurong West Street 93, Singapore 648965', 'https://www.activesgcircle.gov.sg/things-to-do/events/sea-7s--191430']
# ['Singapore Rugby Sevens', '03 May - 05 May', 'Singapore National Stadium', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-rugby-sevens-628461']
# No separate start/end date found
# Attempting to find date-day element
# ['Singapore Jump Fest 2024', '04 MAY - 04 MAY', 'Sheltered Futsal Court of SAFRA Choa Chu Kang', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-jump-fest-2024-488191']
# No separate start/end date found
# Attempting to find date-day element
# ['Paralympic Fiesta 2024', '04 MAY - 04 MAY', 'Our Tampines Hub (1 Tampines Walk, Singapore 528523)', 'https://www.activesgcircle.gov.sg/things-to-do/events/paralympic-fiesta-2024-557367']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Powerchair Football', '04 MAY - 04 MAY', 'Handicaps Welfare Association', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport-360-discover-powerchair-football-968708']
# No separate start/end date found
# Attempting to find date-day element
# ['MetaSprint Series Triathlon 2024', '05 MAY - 05 MAY', 'East Coast Park', 'https://www.activesgcircle.gov.sg/things-to-do/events/metasprintseries-triathlon-2024']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Goalball', '05 MAY - 05 MAY', 'Delta Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport-360-discover-goalball-944068']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Rugby B Division Finals', '06 MAY - 06 MAY', 'National Stadium, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-rugby-b-division-finals-258138']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Badminton A Division Finals', '08 MAY - 08 MAY', 'OCBC Arena Hall 2, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-badminton-a-division-finals-448569']
# ['National School Games 2024 Fencing A, B and C Division Finals', '09 May - 10 May', 'OCBC Arena Hall 3, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-fencing-a,-b-and-c-division-finals-954980']
# ['OCBC Cycle 2024', '11 May - 12 May', 'Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/ocbc-cycle-2024-543122']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Table Tennis Senior Division Finals', '13 MAY - 13 MAY', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-table-tennis-senior-division-finals-170785']
# ['National School Games 2024 Fencing A, B and C Division Finals', '13 May - 17 May', 'OCBC Arena Hall 3, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-fencing-a,-b-and-c-division-finals-970104']
# ['National School Games 2024 Judo A, B and C Division Finals', '14 May - 17 May', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-judo-a,-b-and-c-division-finals-320948']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Cross Country A, B and C Division Finals', '14 MAY - 14 MAY', 'OCBC Square, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-cross-country-a,-b-and-c-division-finals-178226']
# ['CITI Para Swimming World Series Singapore 2024', '17 May - 19 May', 'OCBC Aquatic Centre, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/citi-para-swimming-world-series-singapore-2024-556963']
# ['Singapore Wake Sports Nationals 2024', '18 May - 19 May', 'Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/singapore-wake-sports-nationals-2024-770986']
# No separate start/end date found
# Attempting to find date-day element
# ['Unlabelled Run 2024', '18 MAY - 18 MAY', 'OCBC Square', 'https://www.activesgcircle.gov.sg/things-to-do/events/unlabelled-run-2024-177003']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Basketball A Division Finals', '20 MAY - 20 MAY', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-basketball-a-division-finals-442638']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Netball A Division Finals', '23 MAY - 23 MAY', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-netball-a-division-finals-434945']
# No separate start/end date found
# Attempting to find date-day element
# ['TF Bike & CycleRun 2024', '26 MAY - 26 MAY', 'Nicole Highway, Republic Avenue', 'https://www.activesgcircle.gov.sg/things-to-do/events/tf-bike-&-cyclerun-2024-512602']
# No separate start/end date found
# Attempting to find date-day element
# ['Income Eco Run 2024', '26 MAY - 26 MAY', 'Marina Barrage', 'https://www.activesgcircle.gov.sg/things-to-do/events/income-eco-run-2024-143658']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Goalball', '26 MAY - 26 MAY', 'Delta Sports Hall', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport-360-discover-goalball-682060']
# ['KFF Singapore Badminton Open 2024', '28 May - 02 Jun', 'Singapore Indoor Stadium, 2 Stadium Walk, Singapore 397691', 'https://www.activesgcircle.gov.sg/things-to-do/events/kff-singapore-badminton-open-2024-883151']
# No separate start/end date found
# Attempting to find date-day element
# ['Parasport 360: Discover Bowling', '29 MAY - 29 MAY', 'Singapore Island Country Club, 180 Island Club Road Singapore, 578774', 'https://www.activesgcircle.gov.sg/things-to-do/events/parasport-360-discover-bowling-296657']
# No separate start/end date found
# Attempting to find date-day element
# ['RSR Challenge Series Race #3', '30 MAY - 30 MAY', 'East Coast Park, CP B1', 'https://www.activesgcircle.gov.sg/things-to-do/events/rsr-challenge-series-race-3-537864']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Jun-2024
# Finding total events listed in the page
# Total events for the page: 7
# ['KFF Singapore Badminton Open 2024', '28 May - 02 Jun', 'Singapore Indoor Stadium, 2 Stadium Walk, Singapore 397691', 'https://www.activesgcircle.gov.sg/things-to-do/events/kff-singapore-badminton-open-2024-883151']
# No separate start/end date found
# Attempting to find date-day element
# ['Cold Storage and Giant Kids Run 2024', '02 JUN - 02 JUN', 'Palawan Green, Sentosa', 'https://www.activesgcircle.gov.sg/things-to-do/events/cold-storage-and-giant-kids-run-2024-810606']
# No separate start/end date found
# Attempting to find date-day element
# ['Skechers Friendship Walk 2024', '08 JUN - 08 JUN', 'Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/skechers-friendship-walk-2024-128166']
# No separate start/end date found
# Attempting to find date-day element
# ['Spartan Race', '22 JUN - 22 JUN', 'Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/spartan-race-196097']
# No separate start/end date found
# Attempting to find date-day element
# ['Trampoliné Fitness Neon Party', '22 JUN - 22 JUN', '509 Bishan Street 11 Singapore, Singapore 570509', 'https://www.activesgcircle.gov.sg/things-to-do/events/trampolin%C3%A9-fitness-neon-party-879196']
# No separate start/end date found
# Attempting to find date-day element
# ['TRIFACTOR RUN & RUNSWIM 2024', '23 JUN - 23 JUN', 'East Coast Park, Casuarina Grove', 'https://www.activesgcircle.gov.sg/things-to-do/events/trifactor-run-&-runswim-2024-440635']
# No separate start/end date found
# Attempting to find date-day element
# ['Cigna Healthcare | HYROX Singapore', '29 JUN - 29 JUN', 'National Stadium, SIngapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/cigna-healthcare-|-hyrox-singapore-782590']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Jul-2024
# Finding total events listed in the page
# Total events for the page: 2
# ['National School Games 2024 Judo C Division Finals', '17 Jul - 18 Jul', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-judo-c-division-finals-548999']
# No separate start/end date found
# Attempting to find date-day element
# ['TRIFACTOR TRIATHLON & SPORTS FEST 2024', '28 JUL - 28 JUL', 'East Coast Park, Angsana Green', 'https://www.activesgcircle.gov.sg/things-to-do/events/trifactor-triathlon-&-sports-fest-2024-127168']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Aug-2024
# Finding total events listed in the page
# Total events for the page: 2
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Badminton C Division Finals', '15 AUG - 15 AUG', 'OCBC Arena Hall 2, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-badminton-c-division-finals-446739']
# No separate start/end date found
# Attempting to find date-day element
# ['National School Games 2024 Basketball C Division Finals', '20 AUG - 20 AUG', 'OCBC Arena Hall 1A, Singapore Sports Hub', 'https://www.activesgcircle.gov.sg/things-to-do/events/national-school-games-2024-basketball-c-division-finals-686067']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Sep-2024
# Finding total events listed in the page
# Total events for the page: 1
# ['Formula 1 Singapore Airlines Singapore Grand Prix', '20 Sep - 22 Sep', 'Marina Bay Street Circuit', 'https://www.activesgcircle.gov.sg/things-to-do/events/formula-1-singapore-airlines-singapore-grand-prix-489320']
# Sleeping before going next page
#
# Page showing events for the month starting 01-Oct-2024
# No events found
# Page showing events for the month starting 01-Nov-2024
# No events found
# Page showing events for the month starting 01-Dec-2024
# Finding total events listed in the page
# Total events for the page: 1
# ['IWWF Asia Wakefest Singapore', '01 Dec - 31 Dec', 'Singapore', 'https://www.activesgcircle.gov.sg/things-to-do/events/iwwf-asia-wakefest-singapore--764299']
# Sleeping before going next page
#
# Saving to csv file

# %% [markdown]
# # Singstat and Data.gov.sg Information crawler.
# This notebook is used for pulling and consolidating datasets found in both sites

# %% [markdown]
# ## Install dependencies for pulling data sources information
#
# ### Notes: BeautifulSoup can only handle static website content scraping. Selenium library is required together with beautifulsoup to read all dynamically loaded content which is the case for singstat and data.gov.sg.

# %% [markdown]
# Library imports

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException, TimeoutException, NoSuchWindowException, ElementClickInterceptedException
from datetime import datetime
from typing import NewType
import pandas as pd
# Define options for webdriver
chrome_options = Options()

# %% [markdown]
# Try to click Data.gov.sg and pull data information
# Attempt to load as much information as possible before one shot scraping. TO avoid issues, please do not minimize the page when executing

# %%
# Helper function
def load_all_data(dataset_on_display: list,
                  total_results: int,
                  load_more_button: object,
                  datasets_div_xpath:str,
                  load_more_xpath:str,
                  driver: NewType):
    while len(dataset_on_display) < total_results and load_more_button:
        print("Loading more data")
        # Count displayed dataset

        dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
        try:
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, 
            load_more_xpath)))
        except TimeoutException:
            print("No load more button available after waiting. Assuming the end of page")

        try:
            load_more_button = driver.find_element(by=By.XPATH, value=load_more_xpath)
            print(f"Current display data: {len(dataset_on_display)}/{total_results}")
            load_more_button.click()
        except NoSuchElementException:
            print("Unable to click load more button due to no such element")
            dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
            print(f"Current display data: {len(dataset_on_display)}/{total_results}")
        except ElementClickInterceptedException:
            print("Encountered interference with clicking...")
            dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
            print(f"Current display data: {len(dataset_on_display)}/{total_results}")

# %%
URL = "https://beta.data.gov.sg/datasets?sort=Last%20updated"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
driver.get(URL)

# XPATH
load_more_xpath = "//button[contains(@class, 'chakra-button') and text()='Load more']"
results_xpath = "//div[@class='css-no1clx']/p[contains(@class, 'chakra-text')][2]"
datasets_div_xpath = "//a[@class='chakra-link css-mfiv8d']"

# Webpage wait
WebDriverWait(driver, 5).until(EC.element_to_be_clickable((By.XPATH, load_more_xpath)))

# FInd elements
total_results = driver.find_element(by=By.XPATH, value=results_xpath)
if total_results:
    # Results value in the string format of xxx,xxx. Hence need to remove commas
    total_results_text = total_results.text
    total_results = total_results_text.replace(",","")
    total_results = int(total_results)
else:
    print("Cant extract any results information from page")
    exit()
load_more_button = driver.find_element(by=By.XPATH, value=load_more_xpath)
# Count displayed dataset
dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)

# CHeck current dataset display numbers
if load_more_button and total_results:
    print(f"Found load more button with {total_results} total results available")

# This function will force expansion of web page by clicking on load more button until there isnt any.
   
load_all_data(dataset_on_display=dataset_on_display,
              total_results=total_results,
              load_more_button=load_more_button,
              datasets_div_xpath=datasets_div_xpath,
              load_more_xpath=load_more_xpath,
              driver=driver)
# Out:
# Found load more button with 4859 total results available
# Loading more data
# Current display data: 20/4859
# Loading more data
# Current display data: 20/4859
# Loading more data
# Current display data: 40/4859
# Loading more data
# Current display data: 60/4859
# Loading more data
# Current display data: 80/4859
# Loading more data
# Current display data: 100/4859
# Loading more data
# Current display data: 120/4859
# Loading more data
# Current display data: 140/4859
# Loading more data
# Current display data: 160/4859
# Loading more data
# Current display data: 180/4859
# Loading more data
# Current display data: 200/4859
# Loading more data
# Current display data: 220/4859
# Loading more data
# Current display data: 240/4859
# Loading more data
# Current display data: 260/4859
# Loading more data
# Current display data: 280/4859
# Loading more data
# Current display data: 300/4859
# Loading more data
# Current display data: 320/4859
# Loading more data
# Current display data: 340/4859
# Loading more data
# Current display data: 360/4859
# Loading more data
# Current display data: 380/4859
# Loading more data
# Current display data: 400/4859
# Loading more data
# Current display data: 420/4859
# Loading more data
# Current display data: 440/4859
# Loading more data
# Current display data: 460/4859
# Loading more data
# Current display data: 480/4859
# Loading more data
# Current display data: 520/4859
# Loading more data
# Current display data: 520/4859
# Loading more data
# Current display data: 540/4859
# Loading more data
# Current display data: 560/4859
# Loading more data
# Current display data: 580/4859
# Loading more data
# Current display data: 620/4859
# Loading more data
# Current display data: 640/4859
# Loading more data
# Current display data: 660/4859
# Loading more data
# Current display data: 680/4859
# Loading more data
# Current display data: 700/4859
# Loading more data
# Current display data: 720/4859
# Loading more data
# Current display data: 740/4859
# Loading more data
# Current display data: 740/4859
# Loading more data
# Current display data: 780/4859
# Loading more data
# Current display data: 800/4859
# Loading more data
# Current display data: 820/4859
# Loading more data
# Current display data: 840/4859
# Loading more data
# Current display data: 860/4859
# Loading more data
# Current display data: 880/4859
# Loading more data
# Current display data: 900/4859
# Loading more data
# Current display data: 920/4859
# Loading more data
# Current display data: 940/4859
# Loading more data
# Current display data: 960/4859
# Loading more data
# Current display data: 980/4859
# Loading more data
# Current display data: 1000/4859
# Loading more data
# Current display data: 1020/4859
# Loading more data
# Current display data: 1040/4859
# Loading more data
# Current display data: 1060/4859
# Loading more data
# Current display data: 1080/4859
# Loading more data
# Current display data: 1100/4859
# Loading more data
# Current display data: 1120/4859
# Loading more data
# Current display data: 1140/4859
# Loading more data
# Current display data: 1160/4859
# Loading more data
# Current display data: 1180/4859
# Loading more data
# Current display data: 1200/4859
# Loading more data
# Current display data: 1220/4859
# Loading more data
# Current display data: 1240/4859
# Loading more data
# Current display data: 1260/4859
# Loading more data
# Current display data: 1280/4859
# Loading more data
# Current display data: 1300/4859
# Loading more data
# Current display data: 1320/4859
# Loading more data
# Current display data: 1340/4859
# Loading more data
# Current display data: 1360/4859
# Loading more data
# Current display data: 1380/4859
# Loading more data
# Current display data: 1400/4859
# Loading more data
# Current display data: 1420/4859
# Loading more data
# Current display data: 1440/4859
# Loading more data
# Current display data: 1460/4859
# Loading more data
# Current display data: 1480/4859
# Loading more data
# Current display data: 1500/4859
# Loading more data
# Current display data: 1520/4859
# Loading more data
# Current display data: 1540/4859
# Loading more data
# Current display data: 1560/4859
# Loading more data
# Current display data: 1580/4859
# Loading more data
# Current display data: 1600/4859
# Loading more data
# Current display data: 1620/4859
# Loading more data
# Current display data: 1640/4859
# Loading more data
# Current display data: 1660/4859
# Loading more data
# Current display data: 1680/4859
# Loading more data
# Current display data: 1700/4859
# Loading more data
# Current display data: 1720/4859
# Loading more data
# Current display data: 1740/4859
# Loading more data
# Current display data: 1760/4859
# Loading more data
# Current display data: 1780/4859
# Loading more data
# Current display data: 1800/4859
# Loading more data
# Current display data: 1820/4859
# Loading more data
# Current display data: 1840/4859
# Loading more data
# Current display data: 1860/4859
# Loading more data
# Current display data: 1880/4859
# Loading more data
# Current display data: 1900/4859
# Loading more data
# Current display data: 1920/4859
# Loading more data
# Current display data: 1940/4859
# Loading more data
# Current display data: 1960/4859
# Loading more data
# Current display data: 1980/4859
# Loading more data
# Current display data: 2000/4859
# Loading more data
# Current display data: 2020/4859
# Loading more data
# Current display data: 2040/4859
# Loading more data
# Current display data: 2060/4859
# Loading more data
# Current display data: 2080/4859
# Loading more data
# Current display data: 2100/4859
# Loading more data
# Current display data: 2120/4859
# Loading more data
# Current display data: 2140/4859
# Loading more data
# Current display data: 2160/4859
# Loading more data
# Current display data: 2180/4859
# Loading more data
# Current display data: 2200/4859
# Loading more data
# Current display data: 2220/4859
# Loading more data
# Current display data: 2240/4859
# Loading more data
# Current display data: 2260/4859
# Loading more data
# Current display data: 2280/4859
# Loading more data
# Current display data: 2300/4859
# Loading more data
# Current display data: 2320/4859
# Loading more data
# Current display data: 2340/4859
# Loading more data
# Current display data: 2360/4859
# Loading more data
# Current display data: 2380/4859
# Loading more data
# Current display data: 2400/4859
# Loading more data
# Current display data: 2420/4859
# Loading more data
# Current display data: 2440/4859
# Loading more data
# Current display data: 2460/4859
# Loading more data
# Current display data: 2480/4859
# Loading more data
# Current display data: 2500/4859
# Loading more data
# Current display data: 2520/4859
# Loading more data
# Current display data: 2540/4859
# Loading more data
# Current display data: 2560/4859
# Loading more data
# Current display data: 2580/4859
# Loading more data
# Current display data: 2600/4859
# Loading more data
# Current display data: 2620/4859
# Loading more data
# Current display data: 2640/4859
# Loading more data
# Current display data: 2660/4859
# Loading more data
# Current display data: 2680/4859
# Loading more data
# Current display data: 2700/4859
# Loading more data
# Current display data: 2720/4859
# Loading more data
# Current display data: 2740/4859
# Loading more data
# Current display data: 2760/4859
# Loading more data
# Current display data: 2780/4859
# Loading more data
# Current display data: 2800/4859
# Loading more data
# Current display data: 2820/4859
# Loading more data
# Current display data: 2840/4859
# Loading more data
# Current display data: 2860/4859
# Loading more data
# Current display data: 2880/4859
# Loading more data
# Current display data: 2900/4859
# Loading more data
# Current display data: 2920/4859
# Loading more data
# Current display data: 2940/4859
# Loading more data
# Current display data: 2960/4859
# Loading more data
# Current display data: 2980/4859
# Loading more data
# Current display data: 3000/4859
# Loading more data
# Current display data: 3020/4859
# Loading more data
# Current display data: 3040/4859
# Loading more data
# Current display data: 3060/4859
# Loading more data
# Current display data: 3080/4859
# Loading more data
# Current display data: 3100/4859
# Loading more data
# Current display data: 3120/4859
# Loading more data
# Current display data: 3140/4859
# Loading more data
# Current display data: 3160/4859
# Loading more data
# Current display data: 3160/4859
# Loading more data
# Current display data: 3200/4859
# Loading more data
# Current display data: 3220/4859
# Loading more data
# Current display data: 3240/4859
# Loading more data
# Current display data: 3260/4859
# Loading more data
# Current display data: 3280/4859
# Loading more data
# Current display data: 3300/4859
# Loading more data
# Current display data: 3320/4859
# Loading more data
# Current display data: 3340/4859
# Loading more data
# Current display data: 3360/4859
# Loading more data
# Current display data: 3380/4859
# Loading more data
# Current display data: 3400/4859
# Loading more data
# Current display data: 3420/4859
# Loading more data
# Current display data: 3440/4859
# Loading more data
# Current display data: 3460/4859
# Loading more data
# Current display data: 3480/4859
# Loading more data
# Current display data: 3500/4859
# Loading more data
# Current display data: 3520/4859
# Loading more data
# Current display data: 3540/4859
# Loading more data
# Current display data: 3560/4859
# Loading more data
# Current display data: 3580/4859
# Loading more data
# Current display data: 3600/4859
# Loading more data
# Current display data: 3620/4859
# Loading more data
# Current display data: 3640/4859
# Loading more data
# Current display data: 3660/4859
# Loading more data
# Current display data: 3680/4859
# Loading more data
# Current display data: 3700/4859
# Loading more data
# Current display data: 3720/4859
# Loading more data
# Current display data: 3740/4859
# Loading more data
# Current display data: 3760/4859
# Loading more data
# Current display data: 3780/4859
# Loading more data
# Current display data: 3800/4859
# Loading more data
# Current display data: 3820/4859
# Loading more data
# Current display data: 3840/4859
# Loading more data
# Current display data: 3860/4859
# Loading more data
# Current display data: 3880/4859
# Loading more data
# Current display data: 3900/4859
# Loading more data
# Current display data: 3920/4859
# Loading more data
# Current display data: 3940/4859
# Loading more data
# Current display data: 3960/4859
# Loading more data
# Current display data: 3980/4859
# Loading more data
# Current display data: 4000/4859
# Loading more data
# Current display data: 4020/4859
# Loading more data
# Current display data: 4040/4859
# Loading more data
# Current display data: 4060/4859
# Loading more data
# Current display data: 4080/4859
# Loading more data
# Current display data: 4100/4859
# Loading more data
# Current display data: 4120/4859
# Loading more data
# Current display data: 4140/4859
# Loading more data
# Current display data: 4160/4859
# Loading more data
# Current display data: 4180/4859
# Loading more data
# Current display data: 4200/4859
# Loading more data
# Current display data: 4220/4859
# Loading more data
# Current display data: 4240/4859
# Loading more data
# Current display data: 4260/4859
# Loading more data
# Current display data: 4280/4859
# Loading more data
# Current display data: 4300/4859
# Loading more data
# Current display data: 4320/4859
# Loading more data
# Current display data: 4340/4859
# Loading more data
# Current display data: 4360/4859
# Loading more data
# Current display data: 4380/4859
# Loading more data
# Current display data: 4400/4859
# Loading more data
# Current display data: 4420/4859
# Loading more data
# Current display data: 4440/4859
# Loading more data
# Current display data: 4460/4859
# Loading more data
# Current display data: 4480/4859
# Loading more data
# Current display data: 4500/4859
# Loading more data
# Current display data: 4520/4859
# Loading more data
# Current display data: 4540/4859
# Loading more data
# Current display data: 4560/4859
# Loading more data
# Current display data: 4580/4859
# Loading more data
# Current display data: 4600/4859
# Loading more data
# Current display data: 4620/4859
# Loading more data
# Current display data: 4640/4859
# Loading more data
# Current display data: 4660/4859
# Loading more data
# Current display data: 4680/4859
# Loading more data
# Current display data: 4700/4859
# Loading more data
# Current display data: 4720/4859
# Loading more data
# Current display data: 4740/4859
# Loading more data
# Current display data: 4760/4859
# Loading more data
# Current display data: 4780/4859
# Loading more data
# Current display data: 4800/4859
# Loading more data
# Current display data: 4820/4859
# Loading more data
# Current display data: 4840/4859
# Loading more data
# No load more button available after waiting. Assuming the end of page
# Unable to click load more button due to no such element
# Current display data: 4859/4859

# %% [markdown]
# ## Do an overall count after load more has been exhausted

# %%
try:
    total_dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
    print(len(total_dataset_on_display))

except NoSuchWindowException:
    print("Window has been inadvertently closed")
    driver.quit()
# Out:
# 4859

# %% [markdown]
# ## Extract metadata of dataset for storing purpose

# %%
# #Collection dict to store collections info
collection_tracker_dict = {}

# Dataset dict to store dataset info
dataset_tracker_dict= {}

get_dataset_name_xpath = ".//div/div/p"
get_metadata_info_xpath = ".//div/div/div[contains(@class, 'chakra-wrap')]/ul/p[contains(@class, 'chakra-text')]"
for dataset in total_dataset_on_display:

    # Extract href
    try:
        href = dataset.get_attribute('href')
        print("Dataset link:")
        print(href)
    except AttributeError:
        href = "No info"
        print("No href info found.")
    
    # Extract dataset name
    try:
        name = dataset.find_element(by=By.XPATH, value=get_dataset_name_xpath)
        name = name.text
        print("Dataset name:")
        print(name) 
    except NoSuchElementException:
        print("No name information found")

    # Multiple metadata information
    metadata_list = dataset.find_elements(by=By.XPATH, value=get_metadata_info_xpath)
    # Filter alternate elements (excluding the dot separator)
    metadata_list = [metadata.text for i,metadata in enumerate(metadata_list) if i%2==0]

    # Default will see data period last updated, datatype, source information
    #print(metadata_list)

    std_metadata_list = []
    REQUIRED_ACTUAL_META_LENGTH = 4
    if metadata_list:
        
        # Combine all data source info to single entity as last list element as we want to have
        # date, updated, filetype, source structure
        if "(" in metadata_list[-1] and metadata_list[-1].endswith(")"):
            source_str = ""
            # Concatenate all sources together if two elements contains (
            while " (" in metadata_list[-1] and metadata_list[-1].endswith(")"):
                source_str += metadata_list.pop()
                source_str += ","
            std_metadata_list.append(source_str)
        else:
            std_metadata_list.append("No source info")
        #print(metadata_list)
        # Check third element, which usuall indicates datatype
        if metadata_list[-1].isupper():
            std_metadata_list.append(metadata_list[-1])
            metadata_list.pop()
        else:
            std_metadata_list.append("No file info")

        #print(metadata_list)
        # CHeck second element from left (can be updated or datasets)
        if metadata_list[-1].startswith("Updated") or metadata_list[-1].endswith(" datasets"):
            std_metadata_list.append(metadata_list[-1])
            metadata_list.pop()
        else:
            std_metadata_list.append("No update info")

        #print(metadata_list)
        if " - " in metadata_list:
            std_metadata_list.append(metadata_list)
        else:
            std_metadata_list.append("No date info")
    # When all info are not available. Construct a fix list of length 4
    else:
        std_metadata_list = ["No date info", "No update info", "No file info", "No source info"]

    #Insert href info to last element (5th element representing url)
    
    std_metadata_list = std_metadata_list[::-1]
    std_metadata_list.append(href)
    
    print(std_metadata_list)
    # MEtadata construct influence whether we are dealing with collections or dataset
    if any(" dataset" in metadata for metadata in std_metadata_list):
        collection_tracker_dict[name] = std_metadata_list
    else:
        dataset_tracker_dict[name] = std_metadata_list
    print()
# Out:
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e477350cc4eedf507d9b435e0b89e7ae/view
# Dataset name:
# Statutes 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_e477350cc4eedf507d9b435e0b89e7ae/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_5791c6e4cbb2487b877322b410e39d09/view
# Dataset name:
# Others 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_5791c6e4cbb2487b877322b410e39d09/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_2c7c87c899bf1264f34eba18890518e5/view
# Dataset name:
# Notices under the Constitution 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_2c7c87c899bf1264f34eba18890518e5/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_68ec1ad5ce7a99da51edf182fe0e12cf/view
# Dataset name:
# Bankruptcy Act Notices 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_68ec1ad5ce7a99da51edf182fe0e12cf/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_830ca47f48adfac75b79dc7d0efd8744/view
# Dataset name:
# Leave 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_830ca47f48adfac75b79dc7d0efd8744/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_edb599302d97748dc95ef4fe16fcecd5/view
# Dataset name:
# Death 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_edb599302d97748dc95ef4fe16fcecd5/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_03f6016f32c83fecdf724ea536d8ecb7/view
# Dataset name:
# Appointments 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_03f6016f32c83fecdf724ea536d8ecb7/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8baea0c703f1918607ab1ea31989f4f2/view
# Dataset name:
# Leave 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_8baea0c703f1918607ab1ea31989f4f2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_66ce50ab169cf6e5db6c53561dbacb0f/view
# Dataset name:
# Vacation of Service 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_66ce50ab169cf6e5db6c53561dbacb0f/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f56855c1736a13ef1b2a262e25e277e1/view
# Dataset name:
# Dismissals 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_f56855c1736a13ef1b2a262e25e277e1/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_4dc111478d0294c30e9cd071105a48cf/view
# Dataset name:
# Bankruptcy Act Notices 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_4dc111478d0294c30e9cd071105a48cf/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8f848100c27d6d4c534769130dbba7ff/view
# Dataset name:
# Supplements (Current Notices)
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_8f848100c27d6d4c534769130dbba7ff/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_359c51c213daec19bb5f7eaa4208466b/view
# Dataset name:
# Vacation of Service 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_359c51c213daec19bb5f7eaa4208466b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_6f49bdf5154df5772291cd3e02eec5da/view
# Dataset name:
# Tenders 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_6f49bdf5154df5772291cd3e02eec5da/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_95daf2b05bda238dee921352130de047/view
# Dataset name:
# Trade Marks Supplement 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_95daf2b05bda238dee921352130de047/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_6d140ae3bf111d222c1e5a835db3a69b/view
# Dataset name:
# Companies Act Notices 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_6d140ae3bf111d222c1e5a835db3a69b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_335892afe91b3875281b2f20b95a8d51/view
# Dataset name:
# Bills Supplement 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_335892afe91b3875281b2f20b95a8d51/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_d49abc655fbbe92f89bc00f4498c9123/view
# Dataset name:
# Appointments 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_d49abc655fbbe92f89bc00f4498c9123/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_3bc5e9401a77986ab974a95b197ff4bc/view
# Dataset name:
# Legislation Gazettes (Current Notices)
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_3bc5e9401a77986ab974a95b197ff4bc/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_1a520c1ec747499dc1418b03f6e68b49/view
# Dataset name:
# Others 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_1a520c1ec747499dc1418b03f6e68b49/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_c78740f1761cb3cc9952fa73a8c87f5a/view
# Dataset name:
# Advertisements 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_c78740f1761cb3cc9952fa73a8c87f5a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_75b4ab74fb58ac99daf2ab01d218c142/view
# Dataset name:
# Revocation 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_75b4ab74fb58ac99daf2ab01d218c142/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e845c87f3dfe3979022ba7ac5b3a9b10/view
# Dataset name:
# Cessation of Service 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_e845c87f3dfe3979022ba7ac5b3a9b10/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_474aecabe7646d6a26432cf2e7b3e68e/view
# Dataset name:
# Advertisements 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_474aecabe7646d6a26432cf2e7b3e68e/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_07bae9a30cd02f43f1475b134188060b/view
# Dataset name:
# Government Gazette Supplement 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_07bae9a30cd02f43f1475b134188060b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_bb491a649a3745659802bee63da1a658/view
# Dataset name:
# Audited Reports 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_bb491a649a3745659802bee63da1a658/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_7e3623bb66b9ef7116e9ec4567bc309d/view
# Dataset name:
# Revised Subsidiary Legislation 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_7e3623bb66b9ef7116e9ec4567bc309d/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_a9e75af8a5c5166f253894f9d2ae1fa0/view
# Dataset name:
# Companies Act Notices 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_a9e75af8a5c5166f253894f9d2ae1fa0/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8c7861d7a398f8a623d564bfbc79d56f/view
# Dataset name:
# Dismissals 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_8c7861d7a398f8a623d564bfbc79d56f/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_6c4962191579570a3cf54916559aba8f/view
# Dataset name:
# Notices under the Constitution 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_6c4962191579570a3cf54916559aba8f/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_ca749dc6f7e54f6da111ea472fa4bb59/view
# Dataset name:
# Corrigendum 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_ca749dc6f7e54f6da111ea472fa4bb59/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_199409ce3729f893cd4ca5186f8d3e62/view
# Dataset name:
# Cessation of Service 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_199409ce3729f893cd4ca5186f8d3e62/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e2de193f0888e615ec7b6b12f099db16/view
# Dataset name:
# Tenders 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_e2de193f0888e615ec7b6b12f099db16/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_ee93625bbc9dee11eafa92aaa8c671aa/view
# Dataset name:
# Notices under other Acts 2023
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_ee93625bbc9dee11eafa92aaa8c671aa/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_60877dfe2dc76b197660c16c7d43cffa/view
# Dataset name:
# Termination of Service 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_60877dfe2dc76b197660c16c7d43cffa/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_80e193bd9517638c4a60a9317c49c3b8/view
# Dataset name:
# Government Gazettes (Current Notices)
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_80e193bd9517638c4a60a9317c49c3b8/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_82ec4cf03da7592a89479daaf9b4dc1b/view
# Dataset name:
# Corrigendum 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_82ec4cf03da7592a89479daaf9b4dc1b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_54f824a6d704ca16747406549f7b85e4/view
# Dataset name:
# Subsidiary Legislation Supplement 2024
# ['Updated 25 minutes ago', 'CSV']
# ['Updated 25 minutes ago']
# []
# ['No date info', 'Updated 25 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_54f824a6d704ca16747406549f7b85e4/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_7de78ed5dcffc31092945d41a898c16a/view
# Dataset name:
# Acts Supplement 2024
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_7de78ed5dcffc31092945d41a898c16a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_20a3ac83c89cd1e26ff3ba0b892a152a/view
# Dataset name:
# Government Gazette Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_20a3ac83c89cd1e26ff3ba0b892a152a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_c31c965da0c7c4bdc897eebb6747486a/view
# Dataset name:
# Notices under other Acts 2024
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_c31c965da0c7c4bdc897eebb6747486a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_5fe7d3d7d513150e0db49e7d8cf4410e/view
# Dataset name:
# Treaties Supplement 2024
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_5fe7d3d7d513150e0db49e7d8cf4410e/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_d42e07edc3ed498db9f7701737594cb3/view
# Dataset name:
# Statutes 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_d42e07edc3ed498db9f7701737594cb3/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_9f4db5fa5416ecdca2557170f3ab5f53/view
# Dataset name:
# Treaties Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_9f4db5fa5416ecdca2557170f3ab5f53/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_ba477613fce8881922d0e484ee071ce7/view
# Dataset name:
# Death 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_ba477613fce8881922d0e484ee071ce7/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_fec59dbfd4f1f6020212394aa45fb861/view
# Dataset name:
# Industrial Relations Supplement 2024
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_fec59dbfd4f1f6020212394aa45fb861/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f1d530a536bc6985fea6a7ecacd8706b/view
# Dataset name:
# Revocation 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_f1d530a536bc6985fea6a7ecacd8706b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_0ce1cfdc8904d692bcaaaa9d55439ff2/view
# Dataset name:
# Trade Marks Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_0ce1cfdc8904d692bcaaaa9d55439ff2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_212501e1ebebcc3d69f81875b90775ca/view
# Dataset name:
# Subsidiary Legislation Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_212501e1ebebcc3d69f81875b90775ca/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_75a8ec0018721707ac67c8df6b570cb4/view
# Dataset name:
# Termination of Service 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_75a8ec0018721707ac67c8df6b570cb4/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_acdac3f791d2eee1e8cd533843eec9b7/view
# Dataset name:
# Audited Reports 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_acdac3f791d2eee1e8cd533843eec9b7/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8b7a2451d909b031f3cbd91ce226bce2/view
# Dataset name:
# Industrial Relations Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_8b7a2451d909b031f3cbd91ce226bce2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_dba59293f2bbbdb270eae7152969f4da/view
# Dataset name:
# Revised Subsidiary Legislation 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_dba59293f2bbbdb270eae7152969f4da/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_4a61275b92165a1f1303ba706c93656c/view
# Dataset name:
# Bills Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_4a61275b92165a1f1303ba706c93656c/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e9a6deefeaba9cec98b9dc3184926455/view
# Dataset name:
# Acts Supplement 2023
# ['Updated 26 minutes ago', 'CSV']
# ['Updated 26 minutes ago']
# []
# ['No date info', 'Updated 26 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI),', 'https://beta.data.gov.sg/datasets/d_e9a6deefeaba9cec98b9dc3184926455/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_07c63be0f37e6e59c07a4ddc2fd87fcb/view
# Dataset name:
# CEA Salesperson Information
# ['Jan 2011 - Sep 2023', 'Updated 4 hours ago', 'CSV']
# ['Jan 2011 - Sep 2023', 'Updated 4 hours ago']
# ['Jan 2011 - Sep 2023']
# ['No date info', 'Updated 4 hours ago', 'CSV', 'Council For Estate Agencies (CEA),', 'https://beta.data.gov.sg/datasets/d_07c63be0f37e6e59c07a4ddc2fd87fcb/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_ad0e7576e8133d78420f0b79f59b7ed2/view
# Dataset name:
# Enterprise Landscape By Ownership, Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_ad0e7576e8133d78420f0b79f59b7ed2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_36bfb288c5cf7a3ac830609d331beebd/view
# Dataset name:
# Foreign Direct Investment In Singapore By Industry (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_36bfb288c5cf7a3ac830609d331beebd/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f21d39f915a2c70bfa8d0cf5bc833f1f/view
# Dataset name:
# Total Divorces By Duration Of Marriage, Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_f21d39f915a2c70bfa8d0cf5bc833f1f/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e39eeaeadb571c0d0725ef1eec48d166/view
# Dataset name:
# Births And Fertility Rates, Annual
# ['Dec 1969 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Dec 1969 - Jan 1970', 'Updated 2 days ago']
# ['Dec 1969 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_e39eeaeadb571c0d0725ef1eec48d166/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_3d227e5d9fdec73f3bcadce671c333a6/view
# Dataset name:
# Indicators On Population, Annual
# ['Dec 1969 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Dec 1969 - Jan 1970', 'Updated 2 days ago']
# ['Dec 1969 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_3d227e5d9fdec73f3bcadce671c333a6/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_6cba526492c2b80c855323165af4cc94/view
# Dataset name:
# Total Marriages By Age Differential Of Grooms To Brides And Marriage Order, Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_6cba526492c2b80c855323165af4cc94/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_23a8f40ee4b91655af1146be3f4cbe55/view
# Dataset name:
# Total Divorces By Age Group And Sex Of Divorcees, Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_23a8f40ee4b91655af1146be3f4cbe55/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_941ea5994ac9af325c210d90d2ea8dd3/view
# Dataset name:
# Return On Foreign Direct Investment In Singapore By Industry (During The Year), Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_941ea5994ac9af325c210d90d2ea8dd3/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f53746fc716c85a0b05452d56fa2f5c3/view
# Dataset name:
# Singapore's Portfolio Investment Assets By Destination Economy And Instrument, (End Of Period), Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_f53746fc716c85a0b05452d56fa2f5c3/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_9b2176a4a24fd65312755ca13b620e40/view
# Dataset name:
# Divorces Under The Administration Of Muslim Law Act By Age Group And Sex Of Divorcees, Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_9b2176a4a24fd65312755ca13b620e40/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_072616b46959a455a5ec91663e61b231/view
# Dataset name:
# Return On Foreign Direct Investment In Singapore By Source Economy (During The Year), Annual
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 2 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_072616b46959a455a5ec91663e61b231/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_84f2c4878725990c6fdefc9845ed0591/view
# Dataset name:
# SICS Dataset 1 - Canteen Advertisements
# ['Jun 2023 - Dec 2023', 'Updated 2 days ago', 'CSV']
# ['Jun 2023 - Dec 2023', 'Updated 2 days ago']
# ['Jun 2023 - Dec 2023']
# ['No date info', 'Updated 2 days ago', 'CSV', 'Ministry of Education (MOE),', 'https://beta.data.gov.sg/datasets/d_84f2c4878725990c6fdefc9845ed0591/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8b84c4ee58e3cfc0ece0d773c8ca6abc/view
# Dataset name:
# Resale flat prices based on registration date from Jan-2017 onwards
# ['Jan 2017 - Sep 2023', 'Updated 3 days ago', 'CSV']
# ['Jan 2017 - Sep 2023', 'Updated 3 days ago']
# ['Jan 2017 - Sep 2023']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/datasets/d_8b84c4ee58e3cfc0ece0d773c8ca6abc/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_6b78d625911483860e162288a4000a0c/view
# Dataset name:
# Retail Sales Index, (2017 = 100), In Chained Volume Terms, Monthly
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_6b78d625911483860e162288a4000a0c/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_ed77aee396f778d9166970cf826094fe/view
# Dataset name:
# Food & Beverage Services Index, (2017 = 100), At Current Prices, Monthly, Seasonally Adjusted
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_ed77aee396f778d9166970cf826094fe/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_29d0626a2259ac6c3695e470451ab4d2/view
# Dataset name:
# Food & Beverage Services Index, (2017 = 100), In Chained Volume Terms, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_29d0626a2259ac6c3695e470451ab4d2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e5f83bef6d21f3e9edd7f9308bf9eeba/view
# Dataset name:
# Retail Sales Index, (2017 = 100), In Chained Volume Terms, Quarterly
# ['Updated 3 days ago', 'CSV']
# ['Updated 3 days ago']
# []
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_e5f83bef6d21f3e9edd7f9308bf9eeba/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_0cd4e1d703f04efda7dcf64485c950cc/view
# Dataset name:
# Retail Sales Index, (2017 = 100), In Chained Volume Terms, Monthly, Seasonally Adjusted
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_0cd4e1d703f04efda7dcf64485c950cc/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_2a3204c2f3b4a783f66978f1dc99073a/view
# Dataset name:
# Food & Beverage Services Index, (2017 = 100), In Chained Volume Terms, Monthly, Seasonally Adjusted
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_2a3204c2f3b4a783f66978f1dc99073a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_b4d70547507f7a717072278daf8ed1c2/view
# Dataset name:
# Divorces Under The Administration Of Muslim Law Act By Age Group, Ethnic Group And Sex Of Divorcees, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_b4d70547507f7a717072278daf8ed1c2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_c64fba78b4a144bfb1ba0e3430a648eb/view
# Dataset name:
# First Marriages For Couples Under The Administration Of Muslim Law Act By Age Group Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_c64fba78b4a144bfb1ba0e3430a648eb/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_50fcfc2989b8b34cdef15b89cacf7911/view
# Dataset name:
# Business Expectations Of The Services Sector - General Business Outlook For The Next 6 Months, Net Weighted Balance, Quarterly
# ['Updated 3 days ago', 'CSV']
# ['Updated 3 days ago']
# []
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_50fcfc2989b8b34cdef15b89cacf7911/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f7569e58a97006324771bd94ab00e66d/view
# Dataset name:
# Marriages Under The Women's Charter By Age Group And Ethnic Group Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_f7569e58a97006324771bd94ab00e66d/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_235cda81c98c02c8fe2e6d86dab461f0/view
# Dataset name:
# Marriages Under The Women's Charter By Educational Qualification Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_235cda81c98c02c8fe2e6d86dab461f0/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_9469614eabe5a56e76e1ad34804f74ba/view
# Dataset name:
# First Marriages For Grooms Under The Administration Of Muslim Law Act By Age Group Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_9469614eabe5a56e76e1ad34804f74ba/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_504d991189c4cd84689f7da9abc63a5a/view
# Dataset name:
# Singapore Residents Aged 25 Years & Over By Highest Qualification Attained, Sex And Age Group, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_504d991189c4cd84689f7da9abc63a5a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_a972c0c752ca2aab0d1bd6466cde9149/view
# Dataset name:
# Inter-Ethnic Marriages Under The Women's Charter By Educational Qualification Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_a972c0c752ca2aab0d1bd6466cde9149/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_5c4667aee18cb4b99528b9d98effb579/view
# Dataset name:
# Proportion Of Singles Among Resident Population By Selected Age Group, Sex And Highest Qualification Attained, Annual
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 3 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 3 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_5c4667aee18cb4b99528b9d98effb579/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_adb86124a1f18ad5c2a06aa4f9027443/view
# Dataset name:
# Singapore's Direct Investment Abroad By Industry Abroad (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_adb86124a1f18ad5c2a06aa4f9027443/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_73fe329d76ce493c14ee4cb70a7dbcdd/view
# Dataset name:
# Value Of Food & Beverage Sales (Based On 2017=100 Index) - Estimated, Monthly
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_73fe329d76ce493c14ee4cb70a7dbcdd/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_b8ec51aaee1e2a81c2204a34e034422c/view
# Dataset name:
# Unit Labour Cost Index (2015 = 100), Quarterly, Seasonally Adjusted
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_b8ec51aaee1e2a81c2204a34e034422c/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_cde9e35f2fbd803a801ee9601b03fe6d/view
# Dataset name:
# Trade In Services By Services Category, Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_cde9e35f2fbd803a801ee9601b03fe6d/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_fa4dcbefadf3e93e99c7d88de0f53406/view
# Dataset name:
# Value Added Per Worker In Chained (2015) Dollars, By Industry (SSIC 2020), Quarterly
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_fa4dcbefadf3e93e99c7d88de0f53406/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f9fc9b5420d96bcab45bc31eeb8ae3c3/view
# Dataset name:
# Unit Labour Cost Index (2015 = 100), Quarterly
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_f9fc9b5420d96bcab45bc31eeb8ae3c3/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_a6ae8c74853b12947f700b379b70c618/view
# Dataset name:
# Total Equity By Broad Industry (End Of Period), Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_a6ae8c74853b12947f700b379b70c618/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_9f5a4d29cd1385f15b1829812f2a142a/view
# Dataset name:
# Annulments Under The Women's Charter By Ethnic Group Of Couple, Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_9f5a4d29cd1385f15b1829812f2a142a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_56b851e313d9be1b5045ec7dea325b85/view
# Dataset name:
# Unit Business Cost Index Of Manufacturing (2015 = 100), Quarterly
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_56b851e313d9be1b5045ec7dea325b85/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e1dd5184a84da218b0572bfe533849ab/view
# Dataset name:
# Singapore's Portfolio Investment Assets By Destination Economy And Instrument, (End Of Period), Half-Yearly
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_e1dd5184a84da218b0572bfe533849ab/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_eb359d23d82cd039d7d879b59f1a2b58/view
# Dataset name:
# Trade In Services By Detailed Services Category, Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_eb359d23d82cd039d7d879b59f1a2b58/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_b030d5a428962240005f47a2c527df36/view
# Dataset name:
# Value Added Per Worker At Current Prices, By Industry (SSIC 2020), Quarterly
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_b030d5a428962240005f47a2c527df36/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_dfa1555631b123e09d58609168925020/view
# Dataset name:
# Value Added Per Worker At Current Prices, By Industry (SSIC 2020), Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_dfa1555631b123e09d58609168925020/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_91317ce93ed54603c1b12f099b57f19b/view
# Dataset name:
# Total Marriages By Residential Status Of Grooms And Brides, Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_91317ce93ed54603c1b12f099b57f19b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_43c4c89b056bc3b3959e4cf6771c2898/view
# Dataset name:
# Value Added Per Worker In Chained (2015) Dollars, By Industry (SSIC 2020), Annual
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 4 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_43c4c89b056bc3b3959e4cf6771c2898/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_1d19ddd0222e9412d394b5a5b659c828/view
# Dataset name:
# Unit Business Cost Index Of Manufacturing (2015 = 100), Quarterly, Seasonally Adjusted
# ['Updated 4 days ago', 'CSV']
# ['Updated 4 days ago']
# []
# ['No date info', 'Updated 4 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_1d19ddd0222e9412d394b5a5b659c828/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_dea084e8924680c954f1569a27f6d96c/view
# Dataset name:
# Singapore's Direct Investment Abroad By Destination Economy And Industry Abroad (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_dea084e8924680c954f1569a27f6d96c/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_3dcfd9108ee04bd2b7978d6eaab1ed9a/view
# Dataset name:
# Singapore's Direct Investment Abroad By Destination Economy And Industry Of Investor In Singapore (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_3dcfd9108ee04bd2b7978d6eaab1ed9a/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8e709087c3b95d056a51dfd5a18a58dd/view
# Dataset name:
# Singapore's Direct Investment Abroad By Industry Of Investor In Singapore And Industry Abroad (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_8e709087c3b95d056a51dfd5a18a58dd/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8927bba50b025d2b1b854f59c303f1e0/view
# Dataset name:
# Singapore's Direct Investment Abroad (Stock As At Year-End), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_8927bba50b025d2b1b854f59c303f1e0/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_1b471402bf21f0bdf567098c2cb901d1/view
# Dataset name:
# Selected Merchandise Trade, (At Current Market Prices), Monthly, Seasonally Adjusted
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_1b471402bf21f0bdf567098c2cb901d1/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_d7933d23e5fab92a086585cfb9224ba2/view
# Dataset name:
# Food & Beverage Services Index, (2017 = 100), At Current Prices, Monthly
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_d7933d23e5fab92a086585cfb9224ba2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_76c4baa322f3913b64fb9013c78a45d1/view
# Dataset name:
# Singapore's Balance Of Payments, Additional Details Of The Financial Account, Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_76c4baa322f3913b64fb9013c78a45d1/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_2c64be843b0ec19c4f84e68e9a34894b/view
# Dataset name:
# Singapore External Debt Statistics, (End Of Period), Quarterly
# ['Updated 5 days ago', 'CSV']
# ['Updated 5 days ago']
# []
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_2c64be843b0ec19c4f84e68e9a34894b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_d7107430fd97730391b1c8fa4a373174/view
# Dataset name:
# Singapore's Balance Of Payments, (BPM6 Format), Quarterly
# ['Jan 2023 - Feb 2023', 'Updated 5 days ago', 'CSV']
# ['Jan 2023 - Feb 2023', 'Updated 5 days ago']
# ['Jan 2023 - Feb 2023']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_d7107430fd97730391b1c8fa4a373174/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_b4de9dea7770690a215481e932dda8b2/view
# Dataset name:
# Singapore Citizens By Age Group, Ethnic Group And Sex, End June, Annual
# ['Jan 2023 - Feb 2023', 'Updated 5 days ago', 'CSV']
# ['Jan 2023 - Feb 2023', 'Updated 5 days ago']
# ['Jan 2023 - Feb 2023']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_b4de9dea7770690a215481e932dda8b2/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_75622125bef79f38ee4d71b75f5713ab/view
# Dataset name:
# Singapore International Investment Position, (End Of Period), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_75622125bef79f38ee4d71b75f5713ab/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_a9c4eadcf61867aff502ab475dc6a6cd/view
# Dataset name:
# Singapore's Balance Of Payments, (BPM6 Format), Annual
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Jan 1970 - Jan 1970', 'Updated 5 days ago']
# ['Jan 1970 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_a9c4eadcf61867aff502ab475dc6a6cd/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_23b79a9ab5cb28aa1b75fce6e53cd38d/view
# Dataset name:
# Share Of Nominal Gross Value Added, By Industry (SSIC 2020), Annual
# ['Dec 1969 - Jan 1970', 'Updated 5 days ago', 'CSV']
# ['Dec 1969 - Jan 1970', 'Updated 5 days ago']
# ['Dec 1969 - Jan 1970']
# ['No date info', 'Updated 5 days ago', 'CSV', 'Singapore Department of Statistics (SINGSTAT),', 'https://beta.data.gov.sg/datasets/d_23b79a9ab5cb28aa1b75fce6e53cd38d/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_593aa4bdab00b961ce652f5324dd273b/view
# Dataset name:
# NPARKS Play/Fitness Equipment
# ['Updated 5 days ago', 'GEOJSON']
# ['Updated 5 days ago']
# []
# ['No date info', 'Updated 5 days ago', 'GEOJSON', 'National Parks Board (NPARKS),', 'https://beta.data.gov.sg/datasets/d_593aa4bdab00b961ce652f5324dd273b/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_aea5df8dc9e1850857afd0e5e8e25795/view
# Dataset name:
# Listing of Centres Licence History
# ['Mar 2020 - Sep 2023', 'Updated 6 days ago', 'CSV']
# ...
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1736/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1738/view
# Dataset name:
# Master Plan 2019 SDCP Park Connector Text layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1738/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1737/view
# Dataset name:
# Master Plan 2019 SDCP Park Connector Line layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1737/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1717/view
# Dataset name:
# Master Plan 2019 Region Boundary (No Sea)
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1717/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1749/view
# Dataset name:
# Master Plan 2019 Subzone Boundary (No Sea)
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1749/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1731/view
# Dataset name:
# Master Plan 2019 SDCP Monument Number layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1731/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1730/view
# Dataset name:
# Master Plan 2019 SDCP Monument layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1730/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1743/view
# Dataset name:
# Master Plan 2019 SDCP Street Block layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1743/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1733/view
# Dataset name:
# Master Plan 2019 SDCP Nature Boundary layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1733/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1742/view
# Dataset name:
# Master Plan 2019 SDCP Public Space layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1742/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1748/view
# Dataset name:
# Master Plan 2019 SDCP Waterbody layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1748/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1713/view
# Dataset name:
# Master Plan 2019 Other Line layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1713/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1750/view
# Dataset name:
# Master Plan 2019 Symbol Line layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1750/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1714/view
# Dataset name:
# Master Plan 2019 Other Text layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1714/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1716/view
# Dataset name:
# Master Plan 2019 Rail Station Name layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1716/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1715/view
# Dataset name:
# Master Plan 2019 Rail Station layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1715/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1751/view
# Dataset name:
# Master Plan 2019 Underground Structure layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1751/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1648/view
# Dataset name:
# Master Plan 2019 Rail Line layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1648/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1649/view
# Dataset name:
# Master Plan 2019 Road Graphic layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1649/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1744/view
# Dataset name:
# Master Plan 2019 SDCP UNESCO Heritage Site layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1744/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1732/view
# Dataset name:
# Master Plan 2019 SDCP Monument Site layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1732/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1712/view
# Dataset name:
# Master Plan 2019 Monument Site layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1712/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1651/view
# Dataset name:
# Master Plan 2019 Symbol Text layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1651/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1646/view
# Dataset name:
# Master Plan 2019 Land Use layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1646/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1725/view
# Dataset name:
# Master Plan 2019 SDCP Conservation Area layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1725/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1711/view
# Dataset name:
# Master Plan 2019 Monument Number layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1711/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1719/view
# Dataset name:
# Master Plan 2019 SDCP Building Height Control layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1719/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1721/view
# Dataset name:
# Master Plan 2019 SDCP Building Height Control Text layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1721/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1720/view
# Dataset name:
# Master Plan 2019 SDCP Building Height Control Relaxation layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1720/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1718/view
# Dataset name:
# Master Plan 2019 Road layer
# ['2 datasets', 'KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1718/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1710/view
# Dataset name:
# Master Plan 2019 Monument Building layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1710/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1645/view
# Dataset name:
# Master Plan 2019 Building layer
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Urban Redevelopment Authority (URA),', 'https://beta.data.gov.sg/collections/1645/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/579/view
# Dataset name:
# Singapore Police Force Establishments
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Singapore Police Force (SPF),', 'https://beta.data.gov.sg/collections/579/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/178/view
# Dataset name:
# Sample Household Survey: Employed HDB Resident Population Aged 15 Years and Above by Occupation
# ['Jan 2013 - Dec 2018', '2 datasets', 'CSV']
# ['Jan 2013 - Dec 2018', '2 datasets']
# ['Jan 2013 - Dec 2018']
# ['No date info', '2 datasets', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/collections/178/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_9c6271959306ec3d2726f1fc296794e8/view
# Dataset name:
# Employed HDB Resident Population by Occupation and Sex
# ['Jan 2013 - Dec 2018', 'Updated 2 years ago', 'CSV']
# ['Jan 2013 - Dec 2018', 'Updated 2 years ago']
# ['Jan 2013 - Dec 2018']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/datasets/d_9c6271959306ec3d2726f1fc296794e8/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1598/view
# Dataset name:
# Singapore Polytechnic Diploma Plus Programmes, Annual
# ['Jan 2016 - Dec 2020', '2 datasets', 'CSV']
# ['Jan 2016 - Dec 2020', '2 datasets']
# ['Jan 2016 - Dec 2020']
# ['No date info', '2 datasets', 'CSV', 'Singapore Polytechnic (SP),', 'https://beta.data.gov.sg/collections/1598/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_50830e6a799ccfd00b1ed0a5294920d7/view
# Dataset name:
# NEWater Tariff
# ['Jul 2018 - Dec 2021', 'Updated 2 years ago', 'CSV']
# ['Jul 2018 - Dec 2021', 'Updated 2 years ago']
# ['Jul 2018 - Dec 2021']
# ['No date info', 'Updated 2 years ago', 'CSV', "PUB, Singapore's national water agency (PUB),", 'https://beta.data.gov.sg/datasets/d_50830e6a799ccfd00b1ed0a5294920d7/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_bab2ba9ae53292abd526f4476bfa4de5/view
# Dataset name:
# Industrial Water Tariff
# ['Jul 2018 - Dec 2021', 'Updated 2 years ago', 'CSV']
# ['Jul 2018 - Dec 2021', 'Updated 2 years ago']
# ['Jul 2018 - Dec 2021']
# ['No date info', 'Updated 2 years ago', 'CSV', "PUB, Singapore's national water agency (PUB),", 'https://beta.data.gov.sg/datasets/d_bab2ba9ae53292abd526f4476bfa4de5/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_3690370a32ae16f886adb2dcc43a91bd/view
# Dataset name:
# singapore-polytechnic-diploma-plus-programmes-annual.csv
# ['Jan 2016 - Dec 2020', 'Updated 2 years ago', 'CSV']
# ['Jan 2016 - Dec 2020', 'Updated 2 years ago']
# ['Jan 2016 - Dec 2020']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Singapore Polytechnic (SP),', 'https://beta.data.gov.sg/datasets/d_3690370a32ae16f886adb2dcc43a91bd/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_b4441d68ce973f949df9371bda50e0bf/view
# Dataset name:
# SP's Short Courses
# ['Jan 2022 - Dec 2022', 'Updated 2 years ago', 'CSV']
# ['Jan 2022 - Dec 2022', 'Updated 2 years ago']
# ['Jan 2022 - Dec 2022']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Singapore Polytechnic (SP),', 'https://beta.data.gov.sg/datasets/d_b4441d68ce973f949df9371bda50e0bf/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_dad4567fc02596774010f765567780e3/view
# Dataset name:
# Renting Out of Flat Approvals by Flat Type, Quarterly
# ['Jan 2007 - Sep 2021', 'Updated 2 years ago', 'CSV']
# ['Jan 2007 - Sep 2021', 'Updated 2 years ago']
# ['Jan 2007 - Sep 2021']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/datasets/d_dad4567fc02596774010f765567780e3/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_676bc7fa1d69de0e74c0ceb8897dcb10/view
# Dataset name:
# Cumulative Industrial Properties Completed Since 1960
# ['Apr 2008 - Mar 2018', 'Updated 2 years ago', 'CSV']
# ['Apr 2008 - Mar 2018', 'Updated 2 years ago']
# ['Apr 2008 - Mar 2018']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/datasets/d_676bc7fa1d69de0e74c0ceb8897dcb10/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/1531/view
# Dataset name:
# Parliamentary General Election Results
# ['Jan 1955 - Dec 2020', '4 datasets', 'CSV']
# ['Jan 1955 - Dec 2020', '4 datasets']
# ['Jan 1955 - Dec 2020']
# ['No date info', '4 datasets', 'CSV', 'Elections Department (ELD),', 'https://beta.data.gov.sg/collections/1531/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/174/view
# Dataset name:
# Sample Household Survey: HDB Resident Population and Growth Rate
# ['Jan 1987 - Dec 2018', '2 datasets', 'CSV']
# ['Jan 1987 - Dec 2018', '2 datasets']
# ['Jan 1987 - Dec 2018']
# ['No date info', '2 datasets', 'CSV', 'Housing and Development Board (HDB),', 'https://beta.data.gov.sg/collections/174/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_fdfb854fcb7428b29734d2e0c0674220/view
# Dataset name:
# Parliamentary General Election - Registered Electors, Rejected Votes and Spoilt Ballots
# ['Jan 1955 - Dec 2020', 'Updated 2 years ago', 'CSV']
# ['Jan 1955 - Dec 2020', 'Updated 2 years ago']
# ['Jan 1955 - Dec 2020']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Elections Department (ELD),', 'https://beta.data.gov.sg/datasets/d_fdfb854fcb7428b29734d2e0c0674220/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_00d89e5d100a612e36432d91493785bd/view
# Dataset name:
# Parliamentary General Election Dates
# ['Jan 1955 - Dec 2020', 'Updated 2 years ago', 'CSV']
# ['Jan 1955 - Dec 2020', 'Updated 2 years ago']
# ['Jan 1955 - Dec 2020']
# ['No date info', 'Updated 2 years ago', 'CSV', 'Elections Department (ELD),', 'https://beta.data.gov.sg/datasets/d_00d89e5d100a612e36432d91493785bd/view']
#
# Dataset link:
# https://beta.data.gov.sg/collections/580/view
# Dataset name:
# Singapore Police Force NPC Boundary
# ['2 datasets', 'GEOJSON, KML']
# ['2 datasets']
# []
# ['No date info', '2 datasets', 'GEOJSON, KML', 'Singapore Police Force (SPF),', 'https://beta.data.gov.sg/collections/580/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_06aa11466fbd84215558efb92a00e611/view
# Dataset name:
# SPF Boundaries
# ['Updated 2 years ago', 'KML']
# ['Updated 2 years ago']
# []
# ['No date info', 'Updated 2 years ago', 'KML', 'Singapore Police Force (SPF),', 'https://beta.data.gov.sg/datasets/d_06aa11466fbd84215558efb92a00e611/view']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_356f132925557e7eb72925578bfdfad7/view

# %%
print(f"Datasets: {len(dataset_tracker_dict)}, Collections: {len(collection_tracker_dict)}")
# Out:
# Datasets: 4437, Collections: 0

# %%
std_metadata_list
# Out:
# ['No date info',
#  'Updated 13 years ago',
#  'GEOJSON',
#  'Elections Department (ELD),',
#  'https://beta.data.gov.sg/datasets/d_305b03ed3c477aba648eeddaea2d4279/view']

# %%
## Convert dataset dictionary to dataframe
if dataset_tracker_dict:
    df = pd.DataFrame.from_dict(dataset_tracker_dict, orient="index", columns=["Data period", "Last updated", "Datatype", "Source", "Dataset url"])

    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime.now().strftime("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now
    df.index.name = "Datasets"
    df.head()

    dataset_filename = f"Datagovsg_dataset_{file_name_date}.csv"
    df.to_csv(dataset_filename,index=True)


## Convert collections dictionary to dataframe
if collection_tracker_dict:
    df = pd.DataFrame.from_dict(dataset_tracker_dict, orient="index", columns=["Data period", "Number of datasets", "Datatype", "Source", "Collections url"])

    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime.now().strftime("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now
    df.index.name = "Collections"
    df.head()

    dataset_filename = f"Datagovsg_collections_{file_name_date}.csv"
    df.to_csv(dataset_filename,index=True)


# Close driver upon completion
driver.quit()

# %% [markdown]
# ## Handling SingStat tablebuilder as source

# %%
new_url="https://tablebuilder.singstat.gov.sg/"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
#maximize browser
driver.get(new_url)

# Wait popup
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Maybe Later']"))).click()

# Wait removal of popup
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Expand all']"))).click()

singstat_data_dict = {}

# Navigate through the body after expand all

# We have 6 headers
main_categories_xpath = "//span[contains(@class, 'irmCui')]"
main_categories = driver.find_elements(by=By.XPATH, value=main_categories_xpath)

print(f"Total sections: {len(main_categories)}")
for i, option in enumerate(main_categories):
    
    main_category = option.text
    print(f"Main category: {main_category}")

    sub_category_caret_xpath = f"//*[contains(text(), '{option.text}')]/../../../following-sibling::div/div"

    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, sub_category_caret_xpath)))
    
    # Get the caret-right
    sub_categories_carets = option.find_elements(by=By.XPATH, value=sub_category_caret_xpath)

    print("Total sub categories:")
    print(len(sub_categories_carets))

    # Nested loop to extract subcategories
    for sub_categories_caret in sub_categories_carets:
        # Expand each subcategories
        sub_categories_caret.click()

        # Get the text of sub category
        text_div= ".//a/div/div[2]/div"
        sub_category_text_name = sub_categories_caret.find_element(by=By.XPATH, value=text_div).text

        # THere are nested sub categories
        sub_sub_category_caret_xpath =".//div[contains(@class, 'sgds-accordion-body is-open')]/div"

        # FInd number of such
        sub_sub_categories_list = sub_categories_caret.find_elements(by=By.XPATH, value=sub_sub_category_caret_xpath)
        print(f"Sub category: {sub_category_text_name} has {len(sub_sub_categories_list)} sub-sub categories")

        # Inner nested loop for sub-sub categories
        for sub_sub_cat in sub_sub_categories_list:
            sub_sub_cat.click()

            sub_sub_category_text_name = sub_sub_cat.find_element(by=By.XPATH, value = text_div).text

            sub_sub_category_file_xpath = ".//div/a"
            file_elements_list = sub_sub_cat.find_elements(by=By.XPATH, value=sub_sub_category_file_xpath)
            
            print(f"Sub-sub category: {sub_sub_category_text_name} has {len(file_elements_list)} dataset")
            # Processing or the anchor tags <a> to obtain href info and text

            if file_elements_list:
                for file in file_elements_list:
                    href = file.get_attribute('href')
                    text = file.text

                    dataset_hierarachy_str = main_category + ">" + sub_category_text_name + ">" + sub_sub_category_text_name + ">" + text

                    singstat_data_dict[dataset_hierarachy_str] = [href]
        print()
# Quit browser to free resources
driver.quit()
# Out:
# Total sections: 6
# Main category: Economy & Prices
# Total sub categories:
# 10
# Sub category: Balance of Payments (BOP) has 2 sub-sub categories
# Sub-sub category: Singapore's Balance of Payments (BOP) has 3 dataset
# Sub-sub category: Singapore's Inward Direct Investment Flows has 5 dataset
#
# Sub category: External Debt has 1 sub-sub categories
# Sub-sub category: Singapore's External Debt has 1 dataset
#
# Sub category: Household Sector Balance Sheet has 1 sub-sub categories
# Sub-sub category: Household Net Worth, Assets and Liabilities has 1 dataset
#
# Sub category: International Investment Position (IIP) has 3 sub-sub categories
# Sub-sub category: Singapore's International Investment Position (IIP) has 1 dataset
# Sub-sub category: Singapore's Portfolio Investment Assets has 1 dataset
# Sub-sub category: Singapore’s Portfolio Investment Liabilities has 1 dataset
#
# Sub category: Labour, Employment, Wages and Productivity has 12 sub-sub categories
# Sub-sub category: CPF Members and Employers has 4 dataset
# Sub-sub category: Employment has 16 dataset
# Sub-sub category: Job Vacancies has 1 dataset
# Sub-sub category: Labour Force has 11 dataset
# Sub-sub category: Labour Relations has 3 dataset
# Sub-sub category: Productivity has 7 dataset
# Sub-sub category: Recruitment and Resignation Rate has 2 dataset
# Sub-sub category: Redundancy has 3 dataset
# Sub-sub category: Training has 2 dataset
# Sub-sub category: Unemployment has 4 dataset
# Sub-sub category: Unit Labour Cost (ULC) has 1 dataset
# Sub-sub category: Wages and Income from Employment has 5 dataset
#
# Sub category: Leading Indicators has 1 sub-sub categories
# Sub-sub category: Composite Leading Index (CLI) has 1 dataset
#
# Sub category: National Accounts has 14 sub-sub categories
# Sub-sub category: Capital Stock has 6 dataset
# Sub-sub category: Compensation of Employees has 1 dataset
# Sub-sub category: Expenditure on Gross Domestic Product (GDP) has 4 dataset
# Sub-sub category: Government Consumption Expenditure has 1 dataset
# Sub-sub category: Gross Domestic Product (GDP) has 12 dataset
# Sub-sub category: Gross Fixed Capital Formation (GFCF) has 2 dataset
# Sub-sub category: Gross Operating Surplus has 1 dataset
# Sub-sub category: Gross Value Added (GVA) by Institutional Sector has 2 dataset
# Sub-sub category: Other Taxes Less Subsidies on Production has 1 dataset
# Sub-sub category: Output, Saving and Investment has 2 dataset
# Sub-sub category: Personal Disposable Income and Personal Saving has 1 dataset
# Sub-sub category: Private Consumption Expenditure has 2 dataset
# Sub-sub category: Supply, Use and Input-Output Tables (SUT and IOT) has 22 dataset
# Sub-sub category: Total Demand has 2 dataset
#
# Sub category: Prices and Price Indices has 6 sub-sub categories
# Sub-sub category: Construction Materials has 1 dataset
# Sub-sub category: Consumer Price Index (CPI)/ Inflation Rate has 11 dataset
# Sub-sub category: HDB Resale Flats has 1 dataset
# Sub-sub category: International Trade Price Indices (EPI and IPI) has 10 dataset
# Sub-sub category: Private Property has 9 dataset
# Sub-sub category: Producer Price Indices (DSPI, SMPPI and SPPI) has 13 dataset
#
# Sub category: Public Finance has 4 sub-sub categories
# Sub-sub category: Duty-Paid Releases has 2 dataset
# Sub-sub category: Government Debt has 3 dataset
# Sub-sub category: Government Revenue and Expenditure has 9 dataset
# Sub-sub category: Taxable Individuals and Companies has 3 dataset
#
# Sub category: Public Sector has 4 sub-sub categories
# Sub-sub category: Government Employees has 5 dataset
# Sub-sub category: Judiciary has 4 dataset
# Sub-sub category: Members of Parliament has 1 dataset
# Sub-sub category: Ministers has 1 dataset
#
# Main category: Industry
# Total sub categories:
# 15
# Sub category: Agriculture, Animal Production and Fisheries has 2 sub-sub categories
# Sub-sub category: Food Farms has 1 dataset
# Sub-sub category: Food Supply has 3 dataset
#
# Sub category: Building, Real Estate, Construction and Housing has 4 sub-sub categories
# Sub-sub category: Building and Construction has 4 dataset
# Sub-sub category: HDB Residential Units and Properties has 3 dataset
# Sub-sub category: Real Estate has 8 dataset
# Sub-sub category: Residential Dwellings has 1 dataset
#
# Sub category: Business Expectations has 2 sub-sub categories
# Sub-sub category: Manufacturing Sector has 2 dataset
# Sub-sub category: Services Sector has 6 dataset
#
# Sub category: Corporate Sector has 2 sub-sub categories
# Sub-sub category: Performance has 7 dataset
# Sub-sub category: Size and Composition has 5 dataset
#
# Sub category: Energy and Utilities has 5 sub-sub categories
# Sub-sub category: Electricity Generation, Consumption and Tariffs has 4 dataset
# Sub-sub category: Energy Products and Consumption has 5 dataset
# Sub-sub category: Gas Sales and Tariffs has 3 dataset
# Sub-sub category: Overall Utilities has 2 dataset
# Sub-sub category: Water Sales and Prices has 2 dataset
#
# Sub category: Enterprises has 1 sub-sub categories
# Sub-sub category: Enterprise Landscape has 3 dataset
#
# Sub category: Finance and Insurance has 12 sub-sub categories
# Sub-sub category: Bankruptcy and Liquidation has 2 dataset
# Sub-sub category: Business Loans has 1 dataset
# Sub-sub category: CPF Contributions and Withdrawals has 5 dataset
# Sub-sub category: Currency has 1 dataset
# Sub-sub category: Exchange Rates has 3 dataset
# Sub-sub category: Foreign Exchange Market has 1 dataset
# Sub-sub category: Insurance has 6 dataset
# Sub-sub category: Interest Rates has 1 dataset
# Sub-sub category: Money and Banking has 11 dataset
# Sub-sub category: Pawnshop has 1 dataset
# Sub-sub category: Reserves has 1 dataset
# Sub-sub category: Singapore Exchange has 4 dataset
#
# Sub category: Food Establishments has 1 sub-sub categories
# Sub-sub category: Licensed Food Establishments has 1 dataset
#
# Sub category: Formation and Cessation of Business Entities has 2 sub-sub categories
# Sub-sub category: Cessation of Business Entities has 2 dataset
# Sub-sub category: Formation of Business Entities has 2 dataset
#
# Sub category: InfoComm and Media has 2 sub-sub categories
# Sub-sub category: InfoComm has 18 dataset
# Sub-sub category: Media has 3 dataset
#
# Sub category: Manufacturing has 3 sub-sub categories
# Sub-sub category: Index Of Industrial Production (IIP) has 2 dataset
# Sub-sub category: Principal Manufacturing Statistics has 14 dataset
# Sub-sub category: Unit Business Cost (UBC) has 1 dataset
#
# Sub category: Research and Development (R&D) has 4 sub-sub categories
# Sub-sub category: Organisations Performing R&D has 1 dataset
# Sub-sub category: R&D Expenditure has 4 dataset
# Sub-sub category: R&D Manpower has 1 dataset
# Sub-sub category: Patents has 1 dataset
#
# Sub category: Services has 5 sub-sub categories
# Sub-sub category: Annual Services Statistics - All Services Industries has 5 dataset
# Sub-sub category: Business Receipts Index (BRI) has 1 dataset
# Sub-sub category: Food & Beverage Services Index (FSI) has 4 dataset
# Sub-sub category: Retail Sales Index (RSI) has 4 dataset
# Sub-sub category: Wholesale Trade Index (WTI) has 4 dataset
#
# Sub category: Tourism has 4 sub-sub categories
# Sub-sub category: Hotel Industry has 1 dataset
# Sub-sub category: International Visitor Arrivals (IVA) has 7 dataset
# Sub-sub category: Outbound Departures of Singapore Residents has 1 dataset
# Sub-sub category: Tourism Receipts has 1 dataset
#
# Sub category: Transport has 4 sub-sub categories
# Sub-sub category: Air Transport has 7 dataset
# Sub-sub category: Land Transport (including MRT and LRT) has 13 dataset
# Sub-sub category: Public Roads has 1 dataset
# Sub-sub category: Sea Transport has 5 dataset
#
# Main category: Trade & Investment
# Total sub categories:
# 7
# Sub category: Direct Investment Abroad (DIA) has 1 sub-sub categories
# Sub-sub category: Singapore's Direct Investment Abroad (DIA) and Direct Equity Investment Abroad has 7 dataset
#
# Sub category: Foreign Affiliates Statistics has 1 sub-sub categories
# Sub-sub category: Foreign Affiliates in Singapore has 2 dataset
#
# Sub category: Foreign Direct Investment (FDI) has 2 sub-sub categories
# Sub-sub category: Foreign Direct Investment (FDI) and Foreign Direct Equity Investment has 6 dataset
# Sub-sub category: Income of FDI and Return on FDI has 4 dataset
#
# Sub category: Investment Commitments has 1 sub-sub categories
# Sub-sub category: Fixed Assets Investments has 3 dataset
#
# Sub category: Merchandise Trade has 5 sub-sub categories
# Sub-sub category: Exports by Commodity Section/ Division has 8 dataset
# Sub-sub category: Exports by Market/ Region has 25 dataset
# Sub-sub category: Imports by Commodity Section/ Division has 4 dataset
# Sub-sub category: Imports by Market/ Region has 3 dataset
# Sub-sub category: International Merchandise Trade by Commodity Section/ Division has 2 dataset
#
# Sub category: Trade in Services (TIS) has 3 sub-sub categories
# Sub-sub category: International Trade in Services (TIS) has 2 dataset
# Sub-sub category: Export of Services has 2 dataset
# Sub-sub category: Import of Services has 2 dataset
#
# Sub category: Trading Partner has 1 sub-sub categories
# Sub-sub category: International Merchandise Trade has 3 dataset
#
# Main category: Population
# Total sub categories:
# 10
# Sub category: Population and Population Structure has 2 sub-sub categories
# Sub-sub category: Key Annual Indicators on Population has 6 dataset
# Sub-sub category: Census of Population and General Household Survey has 24 dataset
#
# Sub category: Geographic Distribution has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 7 dataset
#
# Sub category: Marital Status, Marriages and Divorces has 12 sub-sub categories
# Sub-sub category: Total Marriages has 11 dataset
# Sub-sub category: Citizen Marriages has 6 dataset
# Sub-sub category: Marriages under the Women's Charter has 24 dataset
# Sub-sub category: Marriages under the Administration of Muslim Law Act has 23 dataset
# Sub-sub category: Total Divorces has 4 dataset
# Sub-sub category: Divorces under the Women's Charter has 19 dataset
# Sub-sub category: Divorces under the Administration of Muslim Law Act has 19 dataset
# Sub-sub category: Annulments under the Women's Charter has 7 dataset
# Sub-sub category: Dissolution of Marriages Among Resident Marriage Cohorts has 1 dataset
# Sub-sub category: Marital Status has 2 dataset
# Sub-sub category: Proportion of Singles has 4 dataset
# Sub-sub category: Census of Population and General Household Survey has 4 dataset
#
# Sub category: Births and Fertility has 2 sub-sub categories
# Sub-sub category: Births, Crude Birth Rate (CBR), Total Fertility Rate (TFR) and Reproduction Rates has 10 dataset
# Sub-sub category: Census of Population and General Household Survey has 1 dataset
#
# Sub category: Death and Life Expectancy has 2 sub-sub categories
# Sub-sub category: Deaths, Death Rates and Mortality has 6 dataset
# Sub-sub category: Life Expectancy has 1 dataset
#
# Sub category: Education, Language Spoken and Literacy has 11 sub-sub categories
# Sub-sub category: Highest Qualification Attained (HQA) has 2 dataset
# Sub-sub category: Mean Years of Schooling has 1 dataset
# Sub-sub category: Key Literacy and Proficiency Indicators has 2 dataset
# Sub-sub category: Census of Population and General Household Survey has 11 dataset
# Sub-sub category: Enrolment has 12 dataset
# Sub-sub category: Graduates has 8 dataset
# Sub-sub category: Intake has 3 dataset
# Sub-sub category: School Stage Completion or Graduation Rate has 6 dataset
# Sub-sub category: Schools, Students and Education Officers has 6 dataset
# Sub-sub category: Training has 2 dataset
# Sub-sub category: Government Expenditure on Education has 2 dataset
#
# Sub category: Religion has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 2 dataset
#
# Sub category: Mode of Transport has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 3 dataset
#
# Sub category: Difficulty Performing Basic Activities has 1 sub-sub categories
# Sub-sub category: Census of Population has 6 dataset
#
# Sub category: Elderly, Youth and Gender Profile has 4 sub-sub categories
# Sub-sub category: Elderly has 1 dataset
# Sub-sub category: Census of Population and General Household Survey has 1 dataset
# Sub-sub category: Youth has 1 dataset
# Sub-sub category: Gender has 1 dataset
#
# Main category: Households
# Total sub categories:
# 4
# Sub category: Household Expenditure has 1 sub-sub categories
# Sub-sub category: Household Expenditure Survey has 14 dataset
#
# Sub category: Household Income has 8 sub-sub categories
# Sub-sub category: Average and Median Household Income from Work has 4 dataset
# Sub-sub category: Average Household Income from Work by Type of Dwelling/Deciles has 12 dataset
# Sub-sub category: Household Income from Work at Selected Percentiles has 6 dataset
# Sub-sub category: Government Transfers and Taxes has 3 dataset
# Sub-sub category: Household Characteristics has 3 dataset
# Sub-sub category: Income Inequality has 2 dataset
# Sub-sub category: Key Indicators On Household Income From Work has 1 dataset
# Sub-sub category: Census of Population and General Household Survey has 2 dataset
#
# Sub category: Households has 2 sub-sub categories
# Sub-sub category: Resident Households has 6 dataset
# Sub-sub category: Census of Population and General Household Survey has 3 dataset
#
# Sub category: Households With Consumer Durables/ Services has 1 sub-sub categories
# Sub-sub category: Availability of Selected Consumer Durables/ Services has 1 dataset
#
# Main category: Society
# Total sub categories:
# 7
# Sub category: Community Services has 6 sub-sub categories
# Sub-sub category: Charities has 4 dataset
# Sub-sub category: Grassroots Organisations has 2 dataset
# Sub-sub category: Seniors has 2 dataset
# Sub-sub category: Social and Family Services has 4 dataset
# Sub-sub category: Social Assistance and Support has 3 dataset
# Sub-sub category: Volunteers and Volunteer Groups has 2 dataset
#
# Sub category: Culture and Recreation has 1 sub-sub categories
# Sub-sub category: The Arts, Sports, Interest Groups and Visitors to Places of Interest has 10 dataset
#
# Sub category: Environment has 4 sub-sub categories
# Sub-sub category: Air Quality and Climate has 5 dataset
# Sub-sub category: Land Area and Land Use has 5 dataset
# Sub-sub category: Solid Waste Management has 2 dataset
# Sub-sub category: Water and Sanitation has 1 dataset
#
# Sub category: Health has 9 sub-sub categories
# Sub-sub category: Admissions and Outpatient Attendances has 4 dataset
# Sub-sub category: Drug Abusers has 1 dataset
# Sub-sub category: Government Health Expenditure has 1 dataset
# Sub-sub category: Health Facilities has 2 dataset
# Sub-sub category: Health Personnel has 2 dataset
# Sub-sub category: Immunisation has 4 dataset
# Sub-sub category: Indicators on Health has 2 dataset
# Sub-sub category: Notifiable Diseases has 5 dataset
# Sub-sub category: Student Health Assessment has 2 dataset
#
# Sub category: Juveniles and Youth at Risk has 1 sub-sub categories
# Sub-sub category: New Cases and Admissions has 3 dataset
#
# Sub category: Protection and Welfare has 2 sub-sub categories
# Sub-sub category: Child Protection and Welfare has 1 dataset
# Sub-sub category: Personal and Family Protection has 1 dataset
#
# Sub category: Public Safety has 6 sub-sub categories
# Sub-sub category: Convicted Penal Population has 3 dataset
# Sub-sub category: Crimes and Offences has 4 dataset
# Sub-sub category: Emergency Medical Services has 1 dataset
# Sub-sub category: Fire Occurrences has 3 dataset
# Sub-sub category: Persons Arrested has 2 dataset
# Sub-sub category: Unlicensed Moneylending And Harassment has 2 dataset

# %%
# Check datasets amount
print(len(singstat_data_dict))

df = pd.DataFrame.from_dict(singstat_data_dict, orient="index", columns=["URL"])
df.reset_index(inplace=True)

dataset_category_list = ["Theme", "Categories", "SubCategories", "Dataset"]
df[dataset_category_list] = df["index"].str.split(">",expand=True)

datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
file_name_date = datetime.now().strftime("%d%m%Y_%H%M%S")

df["Date_of_check"] = datetime_now

dataset_filename = f"Singstat_dataset_{file_name_date}.csv"
df.drop(columns="index", inplace=True)
new_col_order = ["Dataset", "Theme", "Categories", "SubCategories", "URL", "Date_of_check"]
df[new_col_order].to_csv(dataset_filename,index=False)

df.head()
# Out:
# 867
#                                                  URL             Theme  \
# 0  https://tablebuilder.singstat.gov.sg/table/TS/...  Economy & Prices
# 1  https://tablebuilder.singstat.gov.sg/table/TS/...  Economy & Prices
# 2  https://tablebuilder.singstat.gov.sg/table/TS/...  Economy & Prices
# 3  https://tablebuilder.singstat.gov.sg/table/TS/...  Economy & Prices
# 4  https://tablebuilder.singstat.gov.sg/table/TS/...  Economy & Prices
#
#                   Categories                               SubCategories  \
# 0  Balance of Payments (BOP)       Singapore's Balance of Payments (BOP)
# 1  Balance of Payments (BOP)       Singapore's Balance of Payments (BOP)
# 2  Balance of Payments (BOP)       Singapore's Balance of Payments (BOP)
# 3  Balance of Payments (BOP)  Singapore's Inward Direct Investment Flows
# 4  Balance of Payments (BOP)  Singapore's Inward Direct Investment Flows
#
#                                              Dataset        Date_of_check
# 0     Singapore's Balance Of Payments, (BPM6 Format)  17/03/2024 20:28:35
# 1  Singapore's Balance Of Payments, Additional De...  17/03/2024 20:28:35
# 2  Singapore's Balance Of Payments, Additional De...  17/03/2024 20:28:35
# 3  Singapore's Inward Direct Investment Flows By ...  17/03/2024 20:28:35
# 4  Singapore's Inward Direct Investment Flows By ...  17/03/2024 20:28:35

# %% [markdown]
# # Singstat and Data.gov.sg Information crawler.
# This notebook is used for pulling and consolidating datasets found in both sites

# %% [markdown]
# ## Install dependencies for pulling data sources information
#
# ### Notes: BeautifulSoup can only handle static website content scraping. Selenium library is required together with beautifulsoup to read all dynamically loaded content which is the case for singstat and data.gov.sg.

# %% [markdown]
# Library imports

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException, TimeoutException, NoSuchWindowException, ElementClickInterceptedException
from datetime import datetime
import pandas as pd

# %% [markdown]
# ## Getting Global Holiday calendar from Time and Date webpage, https://www.timeanddate.com/holidays/

# %%
# Update URL here to point to correct source
URL = "https://www.timeanddate.com/holidays/?allcountries"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
driver.get(URL)

# XPATH to geolocations
geo_xpath= ".//article[@class='category-list']//ul//li//a"
year_dropdown_xpath = ".//label/select[@id='year']"
# XPath to all year options provided based on dropdown func in the page
year_xpath = ".//label/select[@id='year']//option"

# Webpage wait for required xpath to load
WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, geo_xpath)))

# Find elements
total_geo_locations_list = driver.find_elements(by=By.XPATH, value=geo_xpath)
if total_geo_locations_list:
    print(f"Total geo locations: {len(total_geo_locations_list)}")
else:
    print("Unable to find geo locations related element via XPATH specified. Assuming No results.")
    exit()

# Dictionary to store holidays of each geo
geo_holiday_tracking_dict = {}
href_list = []

# Get all href info
for geo_location in total_geo_locations_list:
    # Get href
    try:
        href = geo_location.get_attribute("href")
        print(href)
        href_list.append(href)
    except:
        href = "Unknown"
        continue
# Out:
# Total geo locations: 233
# https://www.timeanddate.com/holidays/afghanistan/
# https://www.timeanddate.com/holidays/albania/
# https://www.timeanddate.com/holidays/algeria/
# https://www.timeanddate.com/holidays/american-samoa/
# https://www.timeanddate.com/holidays/andorra/
# https://www.timeanddate.com/holidays/angola/
# https://www.timeanddate.com/holidays/anguilla/
# https://www.timeanddate.com/holidays/antigua-and-barbuda/
# https://www.timeanddate.com/holidays/argentina/
# https://www.timeanddate.com/holidays/armenia/
# https://www.timeanddate.com/holidays/aruba/
# https://www.timeanddate.com/holidays/australia/
# https://www.timeanddate.com/holidays/austria/
# https://www.timeanddate.com/holidays/azerbaijan/
# https://www.timeanddate.com/holidays/bahrain/
# https://www.timeanddate.com/holidays/bangladesh/
# https://www.timeanddate.com/holidays/barbados/
# https://www.timeanddate.com/holidays/belarus/
# https://www.timeanddate.com/holidays/belgium/
# https://www.timeanddate.com/holidays/belize/
# https://www.timeanddate.com/holidays/benin/
# https://www.timeanddate.com/holidays/bermuda/
# https://www.timeanddate.com/holidays/bhutan/
# https://www.timeanddate.com/holidays/bolivia/
# https://www.timeanddate.com/holidays/bosnia/
# https://www.timeanddate.com/holidays/botswana/
# https://www.timeanddate.com/holidays/brazil/
# https://www.timeanddate.com/holidays/british-virgin-islands/
# https://www.timeanddate.com/holidays/brunei/
# https://www.timeanddate.com/holidays/bulgaria/
# https://www.timeanddate.com/holidays/burkina-faso/
# https://www.timeanddate.com/holidays/burundi/
# https://www.timeanddate.com/holidays/cape-verde/
# https://www.timeanddate.com/holidays/cambodia/
# https://www.timeanddate.com/holidays/cameroon/
# https://www.timeanddate.com/holidays/canada/
# https://www.timeanddate.com/holidays/cayman-islands/
# https://www.timeanddate.com/holidays/central-african-republic/
# https://www.timeanddate.com/holidays/chad/
# https://www.timeanddate.com/holidays/chile/
# https://www.timeanddate.com/holidays/china/
# https://www.timeanddate.com/holidays/colombia/
# https://www.timeanddate.com/holidays/comores/
# https://www.timeanddate.com/holidays/republic-of-the-congo/
# https://www.timeanddate.com/holidays/dr-congo/
# https://www.timeanddate.com/holidays/cook-islands/
# https://www.timeanddate.com/holidays/costa-rica/
# https://www.timeanddate.com/holidays/ivory-coast/
# https://www.timeanddate.com/holidays/croatia/
# https://www.timeanddate.com/holidays/cuba/
# https://www.timeanddate.com/holidays/curacao/
# https://www.timeanddate.com/holidays/cyprus/
# https://www.timeanddate.com/holidays/czech/
# https://www.timeanddate.com/holidays/denmark/
# https://www.timeanddate.com/holidays/djibouti/
# https://www.timeanddate.com/holidays/dominica/
# https://www.timeanddate.com/holidays/dominican-republic/
# https://www.timeanddate.com/holidays/timor-leste/
# https://www.timeanddate.com/holidays/ecuador/
# https://www.timeanddate.com/holidays/egypt/
# https://www.timeanddate.com/holidays/el-salvador/
# https://www.timeanddate.com/holidays/guineaecuatorial/
# https://www.timeanddate.com/holidays/eritrea/
# https://www.timeanddate.com/holidays/estonia/
# https://www.timeanddate.com/holidays/swaziland/
# https://www.timeanddate.com/holidays/ethiopia/
# https://www.timeanddate.com/holidays/falkland-islands/
# https://www.timeanddate.com/holidays/faroe-islands/
# https://www.timeanddate.com/holidays/fiji/
# https://www.timeanddate.com/holidays/finland/
# https://www.timeanddate.com/holidays/france/
# https://www.timeanddate.com/holidays/french-guiana/
# https://www.timeanddate.com/holidays/french-polynesia/
# https://www.timeanddate.com/holidays/gabon/
# https://www.timeanddate.com/holidays/gambia/
# https://www.timeanddate.com/holidays/georgia/
# https://www.timeanddate.com/holidays/germany/
# https://www.timeanddate.com/holidays/ghana/
# https://www.timeanddate.com/holidays/gibraltar/
# https://www.timeanddate.com/holidays/greece/
# https://www.timeanddate.com/holidays/greenland/
# https://www.timeanddate.com/holidays/grenada/
# https://www.timeanddate.com/holidays/guadeloupe/
# https://www.timeanddate.com/holidays/guam/
# https://www.timeanddate.com/holidays/guatemala/
# https://www.timeanddate.com/holidays/guernsey/
# https://www.timeanddate.com/holidays/guinea/
# https://www.timeanddate.com/holidays/guinea-bissau/
# https://www.timeanddate.com/holidays/guyana/
# https://www.timeanddate.com/holidays/haiti/
# https://www.timeanddate.com/holidays/honduras/
# https://www.timeanddate.com/holidays/hong-kong/
# https://www.timeanddate.com/holidays/hungary/
# https://www.timeanddate.com/holidays/iceland/
# https://www.timeanddate.com/holidays/india/
# https://www.timeanddate.com/holidays/indonesia/
# https://www.timeanddate.com/holidays/iran/
# https://www.timeanddate.com/holidays/iraq/
# https://www.timeanddate.com/holidays/ireland/
# https://www.timeanddate.com/holidays/isle-of-man/
# https://www.timeanddate.com/holidays/israel/
# https://www.timeanddate.com/holidays/italy/
# https://www.timeanddate.com/holidays/jamaica/
# https://www.timeanddate.com/holidays/japan/
# https://www.timeanddate.com/holidays/jersey/
# https://www.timeanddate.com/holidays/jordan/
# https://www.timeanddate.com/holidays/kazakhstan/
# https://www.timeanddate.com/holidays/kenya/
# https://www.timeanddate.com/holidays/kiribati/
# https://www.timeanddate.com/holidays/kosovo/
# https://www.timeanddate.com/holidays/kuwait/
# https://www.timeanddate.com/holidays/kyrgyzstan/
# https://www.timeanddate.com/holidays/laos/
# https://www.timeanddate.com/holidays/latvia/
# https://www.timeanddate.com/holidays/lebanon/
# https://www.timeanddate.com/holidays/lesotho/
# https://www.timeanddate.com/holidays/liberia/
# https://www.timeanddate.com/holidays/libya/
# https://www.timeanddate.com/holidays/liechtenstein/
# https://www.timeanddate.com/holidays/lithuania/
# https://www.timeanddate.com/holidays/luxembourg/
# https://www.timeanddate.com/holidays/macau/
# https://www.timeanddate.com/holidays/madagascar/
# https://www.timeanddate.com/holidays/malawi/
# https://www.timeanddate.com/holidays/malaysia/
# https://www.timeanddate.com/holidays/maldives/
# https://www.timeanddate.com/holidays/mali/
# https://www.timeanddate.com/holidays/malta/
# https://www.timeanddate.com/holidays/marshall-islands/
# https://www.timeanddate.com/holidays/martinique/
# https://www.timeanddate.com/holidays/mauritania/
# https://www.timeanddate.com/holidays/mauritius/
# https://www.timeanddate.com/holidays/mayotte/
# https://www.timeanddate.com/holidays/mexico/
# https://www.timeanddate.com/holidays/micronesia/
# https://www.timeanddate.com/holidays/moldova/
# https://www.timeanddate.com/holidays/monaco/
# https://www.timeanddate.com/holidays/mongolia/
# https://www.timeanddate.com/holidays/montenegro/
# https://www.timeanddate.com/holidays/montserrat/
# https://www.timeanddate.com/holidays/morocco/
# https://www.timeanddate.com/holidays/mozambique/
# https://www.timeanddate.com/holidays/myanmar/
# https://www.timeanddate.com/holidays/namibia/
# https://www.timeanddate.com/holidays/nauru/
# https://www.timeanddate.com/holidays/nepal/
# https://www.timeanddate.com/holidays/netherlands/
# https://www.timeanddate.com/holidays/new-caledonia/
# https://www.timeanddate.com/holidays/new-zealand/
# https://www.timeanddate.com/holidays/nicaragua/
# https://www.timeanddate.com/holidays/niger/
# https://www.timeanddate.com/holidays/nigeria/
# https://www.timeanddate.com/holidays/norfolk-island/
# https://www.timeanddate.com/holidays/north-korea/
# https://www.timeanddate.com/holidays/macedonia/
# https://www.timeanddate.com/holidays/northern-mariana-islands/
# https://www.timeanddate.com/holidays/norway/
# https://www.timeanddate.com/holidays/oman/
# https://www.timeanddate.com/holidays/pakistan/
# https://www.timeanddate.com/holidays/palau/
# https://www.timeanddate.com/holidays/panama/
# https://www.timeanddate.com/holidays/papua-new-guinea/
# https://www.timeanddate.com/holidays/paraguay/
# https://www.timeanddate.com/holidays/peru/
# https://www.timeanddate.com/holidays/philippines/
# https://www.timeanddate.com/holidays/poland/
# https://www.timeanddate.com/holidays/portugal/
# https://www.timeanddate.com/holidays/puerto-rico/
# https://www.timeanddate.com/holidays/qatar/
# https://www.timeanddate.com/holidays/reunion/
# https://www.timeanddate.com/holidays/romania/
# https://www.timeanddate.com/holidays/russia/
# https://www.timeanddate.com/holidays/rwanda/
# https://www.timeanddate.com/holidays/saint-helena/
# https://www.timeanddate.com/holidays/saint-kitts-and-nevis/
# https://www.timeanddate.com/holidays/saint-lucia/
# https://www.timeanddate.com/holidays/saint-martin/
# https://www.timeanddate.com/holidays/saint-pierre-and-miquelon/
# https://www.timeanddate.com/holidays/saint-vincent-and-the-grenadines/
# https://www.timeanddate.com/holidays/samoa/
# https://www.timeanddate.com/holidays/san-marino/
# https://www.timeanddate.com/holidays/sao-tome-and-principe/
# https://www.timeanddate.com/holidays/saudi-arabia/
# https://www.timeanddate.com/holidays/senegal/
# https://www.timeanddate.com/holidays/serbia/
# https://www.timeanddate.com/holidays/seychelles/
# https://www.timeanddate.com/holidays/sierra-leone/
# https://www.timeanddate.com/holidays/singapore/
# https://www.timeanddate.com/holidays/sint-maarten/
# https://www.timeanddate.com/holidays/slovakia/
# https://www.timeanddate.com/holidays/slovenia/
# https://www.timeanddate.com/holidays/solomon-islands/
# https://www.timeanddate.com/holidays/somalia/
# https://www.timeanddate.com/holidays/south-africa/
# https://www.timeanddate.com/holidays/south-korea/
# https://www.timeanddate.com/holidays/south-sudan/
# https://www.timeanddate.com/holidays/spain/
# https://www.timeanddate.com/holidays/sri-lanka/
# https://www.timeanddate.com/holidays/saint-barthelemy/
# https://www.timeanddate.com/holidays/sudan/
# https://www.timeanddate.com/holidays/suriname/
# https://www.timeanddate.com/holidays/sweden/
# https://www.timeanddate.com/holidays/switzerland/
# https://www.timeanddate.com/holidays/syria/
# https://www.timeanddate.com/holidays/taiwan/
# https://www.timeanddate.com/holidays/tajikistan/
# https://www.timeanddate.com/holidays/tanzania/
# https://www.timeanddate.com/holidays/thailand/
# https://www.timeanddate.com/holidays/bahamas/
# https://www.timeanddate.com/holidays/togo/
# https://www.timeanddate.com/holidays/tonga/
# https://www.timeanddate.com/holidays/trinidad/
# https://www.timeanddate.com/holidays/tunisia/
# https://www.timeanddate.com/holidays/turkey/
# https://www.timeanddate.com/holidays/turkmenistan/
# https://www.timeanddate.com/holidays/turks-and-caicos-islands/
# https://www.timeanddate.com/holidays/tuvalu/
# https://www.timeanddate.com/holidays/uganda/
# https://www.timeanddate.com/holidays/ukraine/
# https://www.timeanddate.com/holidays/united-arab-emirates/
# https://www.timeanddate.com/holidays/uk/
# https://www.timeanddate.com/holidays/us/
# https://www.timeanddate.com/holidays/uruguay/
# https://www.timeanddate.com/holidays/united-states-virgin-islands/
# https://www.timeanddate.com/holidays/uzbekistan/
# https://www.timeanddate.com/holidays/vanuatu/
# https://www.timeanddate.com/holidays/vatican-city-state/
# https://www.timeanddate.com/holidays/venezuela/
# https://www.timeanddate.com/holidays/vietnam/
# https://www.timeanddate.com/holidays/wallis-and-futuna/
# https://www.timeanddate.com/holidays/yemen/
# https://www.timeanddate.com/holidays/zambia/
# https://www.timeanddate.com/holidays/zimbabwe/

# %% [markdown]
# Loop through all the href

# %%
for href in href_list:
    # Get location info
    geo_location_info = href.split("/")[-2]
    print(f"Current geo: {geo_location_info}")
    # For each geo location, go to the page of interest and get the information on available years
    driver.get(href)

    WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, year_xpath)))

    try:
        year_dropdown = driver.find_element(by=By.XPATH, value=year_dropdown_xpath)
        year_dropdown.click()
    except:
        print("Unable to find year dropdown to click")
        continue
    # Get all years availability for the geo location
    supported_years_ele_list = driver.find_elements(by=By.XPATH, value=year_xpath)
    supported_years_list = [year.text for year in supported_years_ele_list if year.text!="Today"]
    print(f"Total years: {len(supported_years_list)}")

    # Get the table content xpath
    holiday_details_xpath = ".//tr[contains(@class, 'showrow')]"

    holiday_list = []
    for year in supported_years_list:
        print(f"Processing year: {year}")
        # Add year suffix to current geo location
        year_url = f"{href}/{year}"
        # For each geo location go to the page of interest and get the information
        driver.get(year_url)
        holiday_table_xpath = ".//table[@id='holidays-table']"

        # Wait for holiday table element to load. If nothing means no data.
        try:
            WebDriverWait(driver, 3).until(EC.presence_of_element_located((By.XPATH, holiday_table_xpath)))
        except TimeoutException:
            print(f"No information found for year {year}. Moving to next year")
            continue
        
        holiday_details = driver.find_elements(
            by=By.XPATH, value=holiday_details_xpath
        )
        print(f"Total holidays for the year: {len(holiday_details)}")
        # Get date, day, name of holiday and type of holiday info from table
        for holiday_metadata in holiday_details:
            date = holiday_metadata.find_element(by=By.XPATH, value=".//th").text
            day = holiday_metadata.find_element(by=By.XPATH, value=".//td[1]").text
            name = holiday_metadata.find_element(by=By.XPATH, value=".//td[2]").text
            type = holiday_metadata.find_element(by=By.XPATH, value=".//td[3]").text
            holiday_info = [year, date, day, name, type]
            print(holiday_info)
            # Append such info to list
            holiday_list.append(holiday_info)
    # Update 
    geo_holiday_tracking_dict[geo_location_info] = holiday_list
    # Go back to main page and loop again for next geo
    print("Back to main page")
    driver.get(URL)
    # Webpage wait for required xpath to load
    WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, geo_xpath)))

# Find total entries based on date and location regardless of multiple same event information 
print(len(geo_holiday_tracking_dict))
driver.quit()
# Out:
# Current geo: afghanistan
# Total years: 41
# Processing year: 2000
# No information found for year 2000. Moving to next year
# Processing year: 2001
# No information found for year 2001. Moving to next year
# Processing year: 2002
# No information found for year 2002. Moving to next year
# Processing year: 2003
# No information found for year 2003. Moving to next year
# Processing year: 2004
# No information found for year 2004. Moving to next year
# Processing year: 2005
# No information found for year 2005. Moving to next year
# Processing year: 2006
# No information found for year 2006. Moving to next year
# Processing year: 2007
# No information found for year 2007. Moving to next year
# Processing year: 2008
# No information found for year 2008. Moving to next year
# Processing year: 2009
# No information found for year 2009. Moving to next year
# Processing year: 2010
# No information found for year 2010. Moving to next year
# Processing year: 2011
# No information found for year 2011. Moving to next year
# Processing year: 2012
# No information found for year 2012. Moving to next year
# Processing year: 2013
# No information found for year 2013. Moving to next year
# Processing year: 2014
# Total holidays for the year: 20
# ['2014', '14 Jan', 'Tuesday', "The Prophet's Birthday", 'Public Holiday']
# ['2014', '15 Feb', 'Saturday', 'Liberation Day', 'Public Holiday']
# ['2014', '20 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2014', '28 Apr', 'Monday', 'Afghan Victory Day', 'Public Holiday']
# ['2014', '1 May', 'Thursday', 'Labor Day', 'Public Holiday']
# ['2014', '21 Jun', 'Saturday', 'June Solstice', 'Season']
# ['2014', '29 Jun', 'Sunday', 'First Day of Ramadan', 'Public Holiday']
# ['2014', '29 Jul', 'Tuesday', 'Eid al-Fitr', 'Public Holiday']
# ['2014', '30 Jul', 'Wednesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2014', '31 Jul', 'Thursday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2014', '19 Aug', 'Tuesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2014', '9 Sep', 'Tuesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2014', '23 Sep', 'Tuesday', 'September Equinox', 'Season']
# ['2014', '4 Oct', 'Saturday', 'Day of Arafat', 'Public Holiday']
# ['2014', '5 Oct', 'Sunday', 'Eid al-Qurban', 'Public Holiday']
# ['2014', '6 Oct', 'Monday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2014', '7 Oct', 'Tuesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2014', '3 Nov', 'Monday', 'Ashura', 'Public Holiday']
# ['2014', '13 Dec', 'Saturday', "Arba'een", 'Observance']
# ['2014', '22 Dec', 'Monday', 'December Solstice', 'Season']
# Processing year: 2015
# Total holidays for the year: 25
# ['2015', '3 Jan', 'Saturday', "The Prophet's Birthday", 'Public Holiday']
# ['2015', '15 Feb', 'Sunday', 'Liberation Day', 'Public Holiday']
# ['2015', '21 Mar', 'Saturday', 'Nauruz', 'Public Holiday']
# ['2015', '21 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2015', '28 Apr', 'Tuesday', 'Afghan Victory Day', 'Public Holiday']
# ['2015', '1 May', 'Friday', 'Labor Day', 'Public Holiday']
# ['2015', '18 Jun', 'Thursday', 'First Day of Ramadan', 'Public Holiday']
# ['2015', '21 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2015', '18 Jul', 'Saturday', 'Eid al-Fitr', 'Public Holiday']
# ['2015', '19 Jul', 'Sunday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2015', '20 Jul', 'Monday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2015', '19 Aug', 'Wednesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2015', '9 Sep', 'Wednesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2015', '20 Sep', 'Sunday', 'Commemoration of the assassination of Burhanuddin Rabbani', 'Public Holiday']
# ['2015', '23 Sep', 'Wednesday', 'Eid al-Qurban', 'Public Holiday']
# ['2015', '23 Sep', 'Wednesday', 'Day of Arafat', 'Public Holiday']
# ['2015', '23 Sep', 'Wednesday', 'September Equinox', 'Season']
# ['2015', '24 Sep', 'Thursday', 'Eid al-Qurban', 'Public Holiday']
# ['2015', '25 Sep', 'Friday', 'Eid al-Qurban', 'Public Holiday']
# ['2015', '25 Sep', 'Friday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2015', '26 Sep', 'Saturday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2015', '24 Oct', 'Saturday', 'Ashura', 'Public Holiday']
# ['2015', '2 Dec', 'Wednesday', "Arba'een", 'Observance']
# ['2015', '22 Dec', 'Tuesday', 'December Solstice', 'Season']
# ['2015', '24 Dec', 'Thursday', "The Prophet's Birthday", 'Public Holiday']
# Processing year: 2016
# Total holidays for the year: 21
# ['2016', '15 Feb', 'Monday', 'Liberation Day', 'Public Holiday']
# ['2016', '20 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2016', '21 Mar', 'Monday', 'Nauruz', 'Public Holiday']
# ['2016', '28 Apr', 'Thursday', 'Afghan Victory Day', 'Public Holiday']
# ['2016', '1 May', 'Sunday', 'Labor Day', 'Public Holiday']
# ['2016', '7 Jun', 'Tuesday', 'First Day of Ramadan', 'Public Holiday']
# ['2016', '21 Jun', 'Tuesday', 'June Solstice', 'Season']
# ['2016', '7 Jul', 'Thursday', 'Eid al-Fitr', 'Public Holiday']
# ['2016', '8 Jul', 'Friday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2016', '9 Jul', 'Saturday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2016', '19 Aug', 'Friday', 'Independence Day (National Day)', 'Public Holiday']
# ['2016', '9 Sep', 'Friday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2016', '12 Sep', 'Monday', 'Day of Arafat', 'Public Holiday']
# ['2016', '13 Sep', 'Tuesday', 'Eid al-Qurban', 'Public Holiday']
# ['2016', '14 Sep', 'Wednesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2016', '15 Sep', 'Thursday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2016', '22 Sep', 'Thursday', 'September Equinox', 'Season']
# ['2016', '12 Oct', 'Wednesday', 'Ashura', 'Public Holiday']
# ['2016', '20 Nov', 'Sunday', "Arba'een", 'Observance']
# ['2016', '12 Dec', 'Monday', "The Prophet's Birthday", 'Public Holiday']
# ['2016', '21 Dec', 'Wednesday', 'December Solstice', 'Season']
# Processing year: 2017
# Total holidays for the year: 23
# ['2017', '5 Feb', 'Sunday', 'Non-working Day', 'Observance']
# ['2017', '14 Feb', 'Tuesday', 'Liberation Day', 'Public Holiday']
# ['2017', '20 Mar', 'Monday', 'March Equinox', 'Season']
# ['2017', '21 Mar', 'Tuesday', 'Nauruz', 'Public Holiday']
# ['2017', '28 Apr', 'Friday', 'Afghan Victory Day', 'Public Holiday']
# ['2017', '29 Apr', 'Saturday', 'Afghan Victory Day observed', 'Public Holiday']
# ['2017', '1 May', 'Monday', 'Labor Day', 'Public Holiday']
# ['2017', '27 May', 'Saturday', 'First Day of Ramadan', 'Public Holiday']
# ['2017', '21 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2017', '26 Jun', 'Monday', 'Eid al-Fitr', 'Public Holiday']
# ['2017', '27 Jun', 'Tuesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2017', '28 Jun', 'Wednesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2017', '19 Aug', 'Saturday', 'Independence Day (National Day)', 'Public Holiday']
# ['2017', '1 Sep', 'Friday', 'Day of Arafat', 'Public Holiday']
# ['2017', '2 Sep', 'Saturday', 'Eid al-Qurban', 'Public Holiday']
# ['2017', '3 Sep', 'Sunday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2017', '4 Sep', 'Monday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2017', '9 Sep', 'Saturday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2017', '23 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2017', '1 Oct', 'Sunday', 'Ashura', 'Public Holiday']
# ['2017', '9 Nov', 'Thursday', "Arba'een", 'Observance']
# ['2017', '1 Dec', 'Friday', "The Prophet's Birthday", 'Public Holiday']
# ['2017', '21 Dec', 'Thursday', 'December Solstice', 'Season']
# Processing year: 2018
# Total holidays for the year: 21
# ['2018', '15 Feb', 'Thursday', 'Liberation Day', 'Public Holiday']
# ['2018', '20 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2018', '21 Mar', 'Wednesday', 'Nauruz', 'Public Holiday']
# ['2018', '28 Apr', 'Saturday', 'Afghan Victory Day', 'Public Holiday']
# ['2018', '1 May', 'Tuesday', 'Labor Day', 'Public Holiday']
# ['2018', '16 May', 'Wednesday', 'First Day of Ramadan', 'Public Holiday']
# ['2018', '15 Jun', 'Friday', 'Eid al-Fitr', 'Public Holiday']
# ['2018', '16 Jun', 'Saturday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2018', '17 Jun', 'Sunday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2018', '21 Jun', 'Thursday', 'June Solstice', 'Season']
# ['2018', '19 Aug', 'Sunday', 'Independence Day (National Day)', 'Public Holiday']
# ['2018', '21 Aug', 'Tuesday', 'Day of Arafat', 'Public Holiday']
# ['2018', '22 Aug', 'Wednesday', 'Eid al-Qurban', 'Public Holiday']
# ['2018', '23 Aug', 'Thursday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2018', '24 Aug', 'Friday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2018', '9 Sep', 'Sunday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2018', '21 Sep', 'Friday', 'Ashura', 'Public Holiday']
# ['2018', '23 Sep', 'Sunday', 'September Equinox', 'Season']
# ['2018', '30 Oct', 'Tuesday', "Arba'een", 'Observance']
# ['2018', '21 Nov', 'Wednesday', "The Prophet's Birthday", 'Public Holiday']
# ['2018', '22 Dec', 'Saturday', 'December Solstice', 'Season']
# Processing year: 2019
# Total holidays for the year: 26
# ['2019', '15 Feb', 'Friday', 'Liberation Day', 'Public Holiday']
# ['2019', '21 Mar', 'Thursday', 'Nauruz', 'Public Holiday']
# ['2019', '21 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2019', '28 Apr', 'Sunday', 'Afghan Victory Day', 'Public Holiday']
# ['2019', '29 Apr', 'Monday', 'Loya Jirga Gathering Holiday (Kabul Only)', 'Public Holiday']
# ['2019', '30 Apr', 'Tuesday', 'Loya Jirga Gathering Holiday (Kabul Only)', 'Public Holiday']
# ['2019', '1 May', 'Wednesday', 'Loya Jirga Gathering Holiday (Kabul Only)', 'Public Holiday']
# ['2019', '1 May', 'Wednesday', 'Labor Day', 'Public Holiday']
# ['2019', '2 May', 'Thursday', 'Loya Jirga Gathering Holiday (Kabul Only)', 'Public Holiday']
# ['2019', '3 May', 'Friday', 'Loya Jirga Gathering Holiday (Kabul Only)', 'Public Holiday']
# ['2019', '6 May', 'Monday', 'First Day of Ramadan', 'Public Holiday']
# ['2019', '4 Jun', 'Tuesday', 'Eid al-Fitr', 'Public Holiday']
# ['2019', '5 Jun', 'Wednesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2019', '6 Jun', 'Thursday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2019', '21 Jun', 'Friday', 'June Solstice', 'Season']
# ['2019', '10 Aug', 'Saturday', 'Day of Arafat', 'Public Holiday']
# ['2019', '11 Aug', 'Sunday', 'Eid al-Qurban', 'Public Holiday']
# ['2019', '12 Aug', 'Monday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2019', '13 Aug', 'Tuesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2019', '19 Aug', 'Monday', 'Independence Day (National Day)', 'Public Holiday']
# ['2019', '9 Sep', 'Monday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2019', '10 Sep', 'Tuesday', 'Ashura', 'Public Holiday']
# ['2019', '23 Sep', 'Monday', 'September Equinox', 'Season']
# ['2019', '28 Sep', 'Saturday', 'Presidential Elections', 'Public Holiday']
# ['2019', '10 Nov', 'Sunday', "The Prophet's Birthday", 'Public Holiday']
# ['2019', '22 Dec', 'Sunday', 'December Solstice', 'Season']
# Processing year: 2020
# Total holidays for the year: 20
# ['2020', '15 Feb', 'Saturday', 'Liberation Day', 'Public Holiday']
# ['2020', '20 Mar', 'Friday', 'March Equinox', 'Season']
# ['2020', '21 Mar', 'Saturday', 'Nauruz', 'Public Holiday']
# ['2020', '24 Apr', 'Friday', 'First Day of Ramadan', 'Public Holiday']
# ['2020', '28 Apr', 'Tuesday', 'Afghan Victory Day', 'Public Holiday']
# ['2020', '1 May', 'Friday', 'Labor Day', 'Public Holiday']
# ['2020', '24 May', 'Sunday', 'Eid al-Fitr', 'Public Holiday']
# ['2020', '25 May', 'Monday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2020', '26 May', 'Tuesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2020', '21 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2020', '30 Jul', 'Thursday', 'Day of Arafat', 'Public Holiday']
# ['2020', '31 Jul', 'Friday', 'Eid al-Qurban', 'Public Holiday']
# ['2020', '1 Aug', 'Saturday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2020', '2 Aug', 'Sunday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2020', '19 Aug', 'Wednesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2020', '30 Aug', 'Sunday', 'Ashura', 'Public Holiday']
# ['2020', '9 Sep', 'Wednesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2020', '22 Sep', 'Tuesday', 'September Equinox', 'Season']
# ['2020', '29 Oct', 'Thursday', "The Prophet's Birthday", 'Public Holiday']
# ['2020', '21 Dec', 'Monday', 'December Solstice', 'Season']
# Processing year: 2021
# Total holidays for the year: 21
# ['2021', '15 Feb', 'Monday', 'Liberation Day', 'Public Holiday']
# ['2021', '20 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2021', '21 Mar', 'Sunday', 'Nauruz', 'Public Holiday']
# ['2021', '22 Mar', 'Monday', 'Nauruz', 'Public Holiday']
# ['2021', '13 Apr', 'Tuesday', 'First Day of Ramadan', 'Public Holiday']
# ['2021', '28 Apr', 'Wednesday', 'Afghan Victory Day', 'Public Holiday']
# ['2021', '1 May', 'Saturday', 'Labor Day', 'Public Holiday']
# ['2021', '13 May', 'Thursday', 'Eid al-Fitr', 'Public Holiday']
# ['2021', '14 May', 'Friday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2021', '15 May', 'Saturday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2021', '21 Jun', 'Monday', 'June Solstice', 'Season']
# ['2021', '19 Jul', 'Monday', 'Day of Arafat', 'Public Holiday']
# ['2021', '20 Jul', 'Tuesday', 'Eid al-Qurban', 'Public Holiday']
# ['2021', '21 Jul', 'Wednesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2021', '22 Jul', 'Thursday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2021', '19 Aug', 'Thursday', 'Independence Day (National Day)', 'Public Holiday']
# ['2021', '19 Aug', 'Thursday', 'Ashura', 'Public Holiday']
# ['2021', '9 Sep', 'Thursday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2021', '22 Sep', 'Wednesday', 'September Equinox', 'Season']
# ['2021', '19 Oct', 'Tuesday', "The Prophet's Birthday", 'Public Holiday']
# ['2021', '21 Dec', 'Tuesday', 'December Solstice', 'Season']
# Processing year: 2022
# Total holidays for the year: 22
# ['2022', '15 Feb', 'Tuesday', 'Liberation Day', 'Public Holiday']
# ['2022', '20 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2022', '21 Mar', 'Monday', 'Nauruz', 'Observance']
# ['2022', '2 Apr', 'Saturday', 'First Day of Ramadan', 'Public Holiday']
# ['2022', '28 Apr', 'Thursday', 'Afghan Victory Day', 'Public Holiday']
# ['2022', '1 May', 'Sunday', 'Eid al-Fitr', 'Public Holiday']
# ['2022', '1 May', 'Sunday', 'Labor Day', 'Public Holiday']
# ['2022', '2 May', 'Monday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2022', '3 May', 'Tuesday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2022', '21 Jun', 'Tuesday', 'June Solstice', 'Season']
# ['2022', '8 Jul', 'Friday', 'Day of Arafat', 'Public Holiday']
# ['2022', '9 Jul', 'Saturday', 'Eid al-Qurban', 'Public Holiday']
# ['2022', '10 Jul', 'Sunday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2022', '11 Jul', 'Monday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2022', '8 Aug', 'Monday', 'Ashura', 'Public Holiday']
# ['2022', '15 Aug', 'Monday', 'Anniversary of Taliban Rule', 'Public Holiday']
# ['2022', '19 Aug', 'Friday', 'Independence Day (National Day)', 'Public Holiday']
# ['2022', '31 Aug', 'Wednesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2022', '9 Sep', 'Friday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2022', '23 Sep', 'Friday', 'September Equinox', 'Season']
# ['2022', '8 Oct', 'Saturday', "The Prophet's Birthday", 'Public Holiday']
# ['2022', '22 Dec', 'Thursday', 'December Solstice', 'Season']
# Processing year: 2023
# Total holidays for the year: 22
# ['2023', '15 Feb', 'Wednesday', 'Liberation Day', 'Public Holiday']
# ['2023', '21 Mar', 'Tuesday', 'Nauruz', 'Observance']
# ['2023', '21 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2023', '23 Mar', 'Thursday', 'First Day of Ramadan', 'Observance']
# ['2023', '22 Apr', 'Saturday', 'Eid al-Fitr', 'Public Holiday']
# ['2023', '23 Apr', 'Sunday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2023', '24 Apr', 'Monday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2023', '28 Apr', 'Friday', 'Afghan Victory Day', 'Public Holiday']
# ['2023', '1 May', 'Monday', 'Labor Day', 'Public Holiday']
# ['2023', '21 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2023', '27 Jun', 'Tuesday', 'Day of Arafat', 'Public Holiday']
# ['2023', '28 Jun', 'Wednesday', 'Eid al-Qurban', 'Public Holiday']
# ['2023', '29 Jun', 'Thursday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2023', '30 Jun', 'Friday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2023', '28 Jul', 'Friday', 'Ashura', 'Public Holiday']
# ['2023', '15 Aug', 'Tuesday', 'Anniversary of Taliban Rule', 'Public Holiday']
# ['2023', '19 Aug', 'Saturday', 'Independence Day (National Day)', 'Public Holiday']
# ['2023', '31 Aug', 'Thursday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2023', '9 Sep', 'Saturday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2023', '23 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2023', '27 Sep', 'Wednesday', "The Prophet's Birthday", 'Public Holiday']
# ['2023', '22 Dec', 'Friday', 'December Solstice', 'Season']
# Processing year: 2024
# Total holidays for the year: 21
# ['2024', '15 Feb', 'Thursday', 'Liberation Day', 'Public Holiday']
# ['2024', '11 Mar', 'Monday', 'First Day of Ramadan', 'Public Holiday']
# ['2024', '20 Mar', 'Wednesday', 'March Equinox', 'Season']
# ['2024', '21 Mar', 'Thursday', 'Nauruz', 'Observance']
# ['2024', '10 Apr', 'Wednesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2024', '11 Apr', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2024', '12 Apr', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2024', '28 Apr', 'Sunday', 'Afghan Victory Day', 'Public Holiday']
# ['2024', '1 May', 'Wednesday', 'Labor Day', 'Public Holiday']
# ['2024', '16 Jun', 'Sunday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2024', '17 Jun', 'Monday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2024', '18 Jun', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2024', '19 Jun', 'Wednesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2024', '21 Jun', 'Friday', 'June Solstice', 'Season']
# ['2024', '17 Jul', 'Wednesday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2024', '19 Aug', 'Monday', 'Independence Day (National Day)', 'Public Holiday']
# ['2024', '31 Aug', 'Saturday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2024', '9 Sep', 'Monday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2024', '16 Sep', 'Monday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2024', '22 Sep', 'Sunday', 'September Equinox', 'Season']
# ['2024', '21 Dec', 'Saturday', 'December Solstice', 'Season']
# Processing year: 2025
# Total holidays for the year: 21
# ['2025', '15 Feb', 'Saturday', 'Liberation Day', 'Public Holiday']
# ['2025', '1 Mar', 'Saturday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2025', '20 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2025', '21 Mar', 'Friday', 'Nauruz', 'Observance']
# ['2025', '31 Mar', 'Monday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2025', '1 Apr', 'Tuesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2025', '2 Apr', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2025', '28 Apr', 'Monday', 'Afghan Victory Day', 'Public Holiday']
# ['2025', '1 May', 'Thursday', 'Labor Day', 'Public Holiday']
# ['2025', '6 Jun', 'Friday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2025', '7 Jun', 'Saturday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2025', '8 Jun', 'Sunday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2025', '9 Jun', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2025', '21 Jun', 'Saturday', 'June Solstice', 'Season']
# ['2025', '6 Jul', 'Sunday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2025', '19 Aug', 'Tuesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2025', '31 Aug', 'Sunday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2025', '5 Sep', 'Friday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2025', '9 Sep', 'Tuesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2025', '22 Sep', 'Monday', 'September Equinox', 'Season']
# ['2025', '21 Dec', 'Sunday', 'December Solstice', 'Season']
# Processing year: 2026
# Total holidays for the year: 21
# ['2026', '15 Feb', 'Sunday', 'Liberation Day', 'Public Holiday']
# ['2026', '18 Feb', 'Wednesday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2026', '20 Mar', 'Friday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2026', '20 Mar', 'Friday', 'March Equinox', 'Season']
# ['2026', '21 Mar', 'Saturday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2026', '21 Mar', 'Saturday', 'Nauruz', 'Observance']
# ['2026', '22 Mar', 'Sunday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2026', '28 Apr', 'Tuesday', 'Afghan Victory Day', 'Public Holiday']
# ['2026', '1 May', 'Friday', 'Labor Day', 'Public Holiday']
# ['2026', '26 May', 'Tuesday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2026', '27 May', 'Wednesday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2026', '28 May', 'Thursday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2026', '29 May', 'Friday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2026', '21 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2026', '26 Jun', 'Friday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2026', '19 Aug', 'Wednesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2026', '26 Aug', 'Wednesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2026', '31 Aug', 'Monday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2026', '9 Sep', 'Wednesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2026', '23 Sep', 'Wednesday', 'September Equinox', 'Season']
# ['2026', '22 Dec', 'Tuesday', 'December Solstice', 'Season']
# Processing year: 2027
# Total holidays for the year: 21
# ['2027', '8 Feb', 'Monday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2027', '15 Feb', 'Monday', 'Liberation Day', 'Public Holiday']
# ['2027', '10 Mar', 'Wednesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2027', '11 Mar', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2027', '12 Mar', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2027', '21 Mar', 'Sunday', 'Nauruz', 'Observance']
# ['2027', '21 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2027', '28 Apr', 'Wednesday', 'Afghan Victory Day', 'Public Holiday']
# ['2027', '1 May', 'Saturday', 'Labor Day', 'Public Holiday']
# ['2027', '16 May', 'Sunday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2027', '17 May', 'Monday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2027', '18 May', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2027', '19 May', 'Wednesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2027', '15 Jun', 'Tuesday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2027', '21 Jun', 'Monday', 'June Solstice', 'Season']
# ['2027', '15 Aug', 'Sunday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2027', '19 Aug', 'Thursday', 'Independence Day (National Day)', 'Public Holiday']
# ['2027', '31 Aug', 'Tuesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2027', '9 Sep', 'Thursday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2027', '23 Sep', 'Thursday', 'September Equinox', 'Season']
# ['2027', '22 Dec', 'Wednesday', 'December Solstice', 'Season']
# Processing year: 2028
# Total holidays for the year: 21
# ['2028', '28 Jan', 'Friday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2028', '15 Feb', 'Tuesday', 'Liberation Day', 'Public Holiday']
# ['2028', '27 Feb', 'Sunday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2028', '28 Feb', 'Monday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2028', '29 Feb', 'Tuesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2028', '20 Mar', 'Monday', 'March Equinox', 'Season']
# ['2028', '21 Mar', 'Tuesday', 'Nauruz', 'Observance']
# ['2028', '28 Apr', 'Friday', 'Afghan Victory Day', 'Public Holiday']
# ['2028', '1 May', 'Monday', 'Labor Day', 'Public Holiday']
# ['2028', '4 May', 'Thursday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2028', '5 May', 'Friday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2028', '6 May', 'Saturday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2028', '7 May', 'Sunday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2028', '3 Jun', 'Saturday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2028', '21 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2028', '3 Aug', 'Thursday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2028', '19 Aug', 'Saturday', 'Independence Day (National Day)', 'Public Holiday']
# ['2028', '31 Aug', 'Thursday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2028', '9 Sep', 'Saturday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2028', '22 Sep', 'Friday', 'September Equinox', 'Season']
# ['2028', '21 Dec', 'Thursday', 'December Solstice', 'Season']
# Processing year: 2029
# Total holidays for the year: 21
# ['2029', '16 Jan', 'Tuesday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2029', '15 Feb', 'Thursday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2029', '15 Feb', 'Thursday', 'Liberation Day', 'Public Holiday']
# ['2029', '16 Feb', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2029', '17 Feb', 'Saturday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2029', '20 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2029', '21 Mar', 'Wednesday', 'Nauruz', 'Observance']
# ['2029', '23 Apr', 'Monday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2029', '24 Apr', 'Tuesday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2029', '25 Apr', 'Wednesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2029', '26 Apr', 'Thursday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2029', '28 Apr', 'Saturday', 'Afghan Victory Day', 'Public Holiday']
# ['2029', '1 May', 'Tuesday', 'Labor Day', 'Public Holiday']
# ['2029', '24 May', 'Thursday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2029', '21 Jun', 'Thursday', 'June Solstice', 'Season']
# ['2029', '24 Jul', 'Tuesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2029', '19 Aug', 'Sunday', 'Independence Day (National Day)', 'Public Holiday']
# ['2029', '31 Aug', 'Friday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2029', '9 Sep', 'Sunday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2029', '22 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2029', '21 Dec', 'Friday', 'December Solstice', 'Season']
# Processing year: 2030
# Total holidays for the year: 22
# ['2030', '6 Jan', 'Sunday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2030', '5 Feb', 'Tuesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2030', '6 Feb', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2030', '7 Feb', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2030', '15 Feb', 'Friday', 'Liberation Day', 'Public Holiday']
# ['2030', '20 Mar', 'Wednesday', 'March Equinox', 'Season']
# ['2030', '21 Mar', 'Thursday', 'Nauruz', 'Observance']
# ['2030', '13 Apr', 'Saturday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2030', '14 Apr', 'Sunday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2030', '15 Apr', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2030', '16 Apr', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2030', '28 Apr', 'Sunday', 'Afghan Victory Day', 'Public Holiday']
# ['2030', '1 May', 'Wednesday', 'Labor Day', 'Public Holiday']
# ['2030', '13 May', 'Monday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2030', '21 Jun', 'Friday', 'June Solstice', 'Season']
# ['2030', '13 Jul', 'Saturday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2030', '19 Aug', 'Monday', 'Independence Day (National Day)', 'Public Holiday']
# ['2030', '31 Aug', 'Saturday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2030', '9 Sep', 'Monday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2030', '23 Sep', 'Monday', 'September Equinox', 'Season']
# ['2030', '22 Dec', 'Sunday', 'December Solstice', 'Season']
# ['2030', '26 Dec', 'Thursday', 'First Day of Ramadan', 'Public Holiday']
# Processing year: 2031
# Total holidays for the year: 21
# ['2031', '25 Jan', 'Saturday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2031', '26 Jan', 'Sunday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2031', '27 Jan', 'Monday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2031', '15 Feb', 'Saturday', 'Liberation Day', 'Public Holiday']
# ['2031', '21 Mar', 'Friday', 'Nauruz', 'Observance']
# ['2031', '21 Mar', 'Friday', 'March Equinox', 'Season']
# ['2031', '2 Apr', 'Wednesday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2031', '3 Apr', 'Thursday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2031', '4 Apr', 'Friday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2031', '5 Apr', 'Saturday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2031', '28 Apr', 'Monday', 'Afghan Victory Day', 'Public Holiday']
# ['2031', '1 May', 'Thursday', 'Labor Day', 'Public Holiday']
# ['2031', '2 May', 'Friday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2031', '21 Jun', 'Saturday', 'June Solstice', 'Season']
# ['2031', '2 Jul', 'Wednesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2031', '19 Aug', 'Tuesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2031', '31 Aug', 'Sunday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2031', '9 Sep', 'Tuesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2031', '23 Sep', 'Tuesday', 'September Equinox', 'Season']
# ['2031', '15 Dec', 'Monday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2031', '22 Dec', 'Monday', 'December Solstice', 'Season']
# Processing year: 2032
# Total holidays for the year: 21
# ['2032', '14 Jan', 'Wednesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2032', '15 Jan', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2032', '16 Jan', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2032', '15 Feb', 'Sunday', 'Liberation Day', 'Public Holiday']
# ['2032', '20 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2032', '21 Mar', 'Sunday', 'Nauruz', 'Observance']
# ['2032', '21 Mar', 'Sunday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2032', '22 Mar', 'Monday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2032', '23 Mar', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2032', '24 Mar', 'Wednesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2032', '21 Apr', 'Wednesday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2032', '28 Apr', 'Wednesday', 'Afghan Victory Day', 'Public Holiday']
# ['2032', '1 May', 'Saturday', 'Labor Day', 'Public Holiday']
# ['2032', '20 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2032', '21 Jun', 'Monday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2032', '19 Aug', 'Thursday', 'Independence Day (National Day)', 'Public Holiday']
# ['2032', '31 Aug', 'Tuesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2032', '9 Sep', 'Thursday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2032', '22 Sep', 'Wednesday', 'September Equinox', 'Season']
# ['2032', '4 Dec', 'Saturday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2032', '21 Dec', 'Tuesday', 'December Solstice', 'Season']
# Processing year: 2033
# Total holidays for the year: 24
# ['2033', '3 Jan', 'Monday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2033', '4 Jan', 'Tuesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2033', '5 Jan', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2033', '15 Feb', 'Tuesday', 'Liberation Day', 'Public Holiday']
# ['2033', '11 Mar', 'Friday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2033', '12 Mar', 'Saturday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2033', '13 Mar', 'Sunday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2033', '14 Mar', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2033', '20 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2033', '21 Mar', 'Monday', 'Nauruz', 'Observance']
# ['2033', '10 Apr', 'Sunday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2033', '28 Apr', 'Thursday', 'Afghan Victory Day', 'Public Holiday']
# ['2033', '1 May', 'Sunday', 'Labor Day', 'Public Holiday']
# ['2033', '10 Jun', 'Friday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2033', '21 Jun', 'Tuesday', 'June Solstice', 'Season']
# ['2033', '19 Aug', 'Friday', 'Independence Day (National Day)', 'Public Holiday']
# ['2033', '31 Aug', 'Wednesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2033', '9 Sep', 'Friday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2033', '22 Sep', 'Thursday', 'September Equinox', 'Season']
# ['2033', '23 Nov', 'Wednesday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2033', '21 Dec', 'Wednesday', 'December Solstice', 'Season']
# ['2033', '23 Dec', 'Friday', 'Eid al-Fitr', 'Public Holiday']
# ['2033', '24 Dec', 'Saturday', 'Eid al-Fitr Holiday', 'Public Holiday']
# ['2033', '25 Dec', 'Sunday', 'Eid al-Fitr Holiday', 'Public Holiday']
# Processing year: 2034
# Total holidays for the year: 21
# ['2034', '15 Feb', 'Wednesday', 'Liberation Day', 'Public Holiday']
# ['2034', '28 Feb', 'Tuesday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2034', '1 Mar', 'Wednesday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2034', '2 Mar', 'Thursday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2034', '3 Mar', 'Friday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2034', '20 Mar', 'Monday', 'March Equinox', 'Season']
# ['2034', '21 Mar', 'Tuesday', 'Nauruz', 'Observance']
# ['2034', '30 Mar', 'Thursday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2034', '28 Apr', 'Friday', 'Afghan Victory Day', 'Public Holiday']
# ['2034', '1 May', 'Monday', 'Labor Day', 'Public Holiday']
# ['2034', '30 May', 'Tuesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2034', '21 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2034', '19 Aug', 'Saturday', 'Independence Day (National Day)', 'Public Holiday']
# ['2034', '31 Aug', 'Thursday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2034', '9 Sep', 'Saturday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2034', '23 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2034', '12 Nov', 'Sunday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2034', '12 Dec', 'Tuesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2034', '13 Dec', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2034', '14 Dec', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2034', '22 Dec', 'Friday', 'December Solstice', 'Season']
# Processing year: 2035
# Total holidays for the year: 21
# ['2035', '15 Feb', 'Thursday', 'Liberation Day', 'Public Holiday']
# ['2035', '17 Feb', 'Saturday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2035', '18 Feb', 'Sunday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2035', '19 Feb', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2035', '20 Feb', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2035', '20 Mar', 'Tuesday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2035', '20 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2035', '21 Mar', 'Wednesday', 'Nauruz', 'Observance']
# ['2035', '28 Apr', 'Saturday', 'Afghan Victory Day', 'Public Holiday']
# ['2035', '1 May', 'Tuesday', 'Labor Day', 'Public Holiday']
# ['2035', '20 May', 'Sunday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2035', '21 Jun', 'Thursday', 'June Solstice', 'Season']
# ['2035', '19 Aug', 'Sunday', 'Independence Day (National Day)', 'Public Holiday']
# ['2035', '31 Aug', 'Friday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2035', '9 Sep', 'Sunday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2035', '23 Sep', 'Sunday', 'September Equinox', 'Season']
# ['2035', '2 Nov', 'Friday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2035', '2 Dec', 'Sunday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2035', '3 Dec', 'Monday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2035', '4 Dec', 'Tuesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2035', '22 Dec', 'Saturday', 'December Solstice', 'Season']
# Processing year: 2036
# Total holidays for the year: 21
# ['2036', '7 Feb', 'Thursday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2036', '8 Feb', 'Friday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2036', '9 Feb', 'Saturday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2036', '10 Feb', 'Sunday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2036', '15 Feb', 'Friday', 'Liberation Day', 'Public Holiday']
# ['2036', '8 Mar', 'Saturday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2036', '20 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2036', '21 Mar', 'Friday', 'Nauruz', 'Observance']
# ['2036', '28 Apr', 'Monday', 'Afghan Victory Day', 'Public Holiday']
# ['2036', '1 May', 'Thursday', 'Labor Day', 'Public Holiday']
# ['2036', '8 May', 'Thursday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2036', '20 Jun', 'Friday', 'June Solstice', 'Season']
# ['2036', '19 Aug', 'Tuesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2036', '31 Aug', 'Sunday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2036', '9 Sep', 'Tuesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2036', '22 Sep', 'Monday', 'September Equinox', 'Season']
# ['2036', '21 Oct', 'Tuesday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2036', '20 Nov', 'Thursday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2036', '21 Nov', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2036', '22 Nov', 'Saturday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2036', '21 Dec', 'Sunday', 'December Solstice', 'Season']
# Processing year: 2037
# Total holidays for the year: 21
# ['2037', '26 Jan', 'Monday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2037', '27 Jan', 'Tuesday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2037', '28 Jan', 'Wednesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2037', '29 Jan', 'Thursday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2037', '15 Feb', 'Sunday', 'Liberation Day', 'Public Holiday']
# ['2037', '26 Feb', 'Thursday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2037', '20 Mar', 'Friday', 'March Equinox', 'Season']
# ['2037', '21 Mar', 'Saturday', 'Nauruz', 'Observance']
# ['2037', '28 Apr', 'Tuesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2037', '28 Apr', 'Tuesday', 'Afghan Victory Day', 'Public Holiday']
# ['2037', '1 May', 'Friday', 'Labor Day', 'Public Holiday']
# ['2037', '21 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2037', '19 Aug', 'Wednesday', 'Independence Day (National Day)', 'Public Holiday']
# ['2037', '31 Aug', 'Monday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2037', '9 Sep', 'Wednesday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2037', '22 Sep', 'Tuesday', 'September Equinox', 'Season']
# ['2037', '11 Oct', 'Sunday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2037', '10 Nov', 'Tuesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2037', '11 Nov', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2037', '12 Nov', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2037', '21 Dec', 'Monday', 'December Solstice', 'Season']
# Processing year: 2038
# Total holidays for the year: 21
# ['2038', '16 Jan', 'Saturday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2038', '17 Jan', 'Sunday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2038', '18 Jan', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2038', '19 Jan', 'Tuesday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2038', '15 Feb', 'Monday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2038', '15 Feb', 'Monday', 'Liberation Day', 'Public Holiday']
# ['2038', '20 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2038', '21 Mar', 'Sunday', 'Nauruz', 'Observance']
# ['2038', '17 Apr', 'Saturday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2038', '28 Apr', 'Wednesday', 'Afghan Victory Day', 'Public Holiday']
# ['2038', '1 May', 'Saturday', 'Labor Day', 'Public Holiday']
# ['2038', '21 Jun', 'Monday', 'June Solstice', 'Season']
# ['2038', '19 Aug', 'Thursday', 'Independence Day (National Day)', 'Public Holiday']
# ['2038', '31 Aug', 'Tuesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2038', '9 Sep', 'Thursday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2038', '23 Sep', 'Thursday', 'September Equinox', 'Season']
# ['2038', '30 Sep', 'Thursday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2038', '30 Oct', 'Saturday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2038', '31 Oct', 'Sunday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2038', '1 Nov', 'Monday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2038', '21 Dec', 'Tuesday', 'December Solstice', 'Season']
# Processing year: 2039
# Total holidays for the year: 25
# ['2039', '5 Jan', 'Wednesday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2039', '6 Jan', 'Thursday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2039', '7 Jan', 'Friday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2039', '8 Jan', 'Saturday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2039', '4 Feb', 'Friday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2039', '15 Feb', 'Tuesday', 'Liberation Day', 'Public Holiday']
# ['2039', '20 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2039', '21 Mar', 'Monday', 'Nauruz', 'Observance']
# ['2039', '6 Apr', 'Wednesday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2039', '28 Apr', 'Thursday', 'Afghan Victory Day', 'Public Holiday']
# ['2039', '1 May', 'Sunday', 'Labor Day', 'Public Holiday']
# ['2039', '21 Jun', 'Tuesday', 'June Solstice', 'Season']
# ['2039', '19 Aug', 'Friday', 'Independence Day (National Day)', 'Public Holiday']
# ['2039', '31 Aug', 'Wednesday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2039', '9 Sep', 'Friday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2039', '19 Sep', 'Monday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2039', '23 Sep', 'Friday', 'September Equinox', 'Season']
# ['2039', '19 Oct', 'Wednesday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2039', '20 Oct', 'Thursday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2039', '21 Oct', 'Friday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2039', '22 Dec', 'Thursday', 'December Solstice', 'Season']
# ['2039', '25 Dec', 'Sunday', 'Day of Arafat', 'Public Holiday']
# ['2039', '26 Dec', 'Monday', 'Eid al-Qurban', 'Public Holiday']
# ['2039', '27 Dec', 'Tuesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# ['2039', '28 Dec', 'Wednesday', 'Eid al-Qurban Holiday', 'Public Holiday']
# Processing year: 2040
# Total holidays for the year: 21
# ['2040', '25 Jan', 'Wednesday', 'Ashura (Tentative Date)', 'Public Holiday']
# ['2040', '15 Feb', 'Wednesday', 'Liberation Day', 'Public Holiday']
# ['2040', '20 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2040', '21 Mar', 'Wednesday', 'Nauruz', 'Observance']
# ['2040', '26 Mar', 'Monday', "The Prophet's Birthday (Tentative Date)", 'Public Holiday']
# ['2040', '28 Apr', 'Saturday', 'Afghan Victory Day', 'Public Holiday']
# ['2040', '1 May', 'Tuesday', 'Labor Day', 'Public Holiday']
# ['2040', '20 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2040', '19 Aug', 'Sunday', 'Independence Day (National Day)', 'Public Holiday']
# ['2040', '31 Aug', 'Friday', 'Anniversary of the Withdrawal of Foreign Troops', 'Public Holiday']
# ['2040', '8 Sep', 'Saturday', 'First Day of Ramadan (Tentative Date)', 'Public Holiday']
# ['2040', '9 Sep', 'Sunday', 'Martyrs and Ahmad Shah Masoud Day', 'Public Holiday']
# ['2040', '22 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2040', '8 Oct', 'Monday', 'Eid al-Fitr (Tentative Date)', 'Public Holiday']
# ['2040', '9 Oct', 'Tuesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2040', '10 Oct', 'Wednesday', 'Eid al-Fitr Holiday (Tentative Date)', 'Public Holiday']
# ['2040', '14 Dec', 'Friday', 'Day of Arafat (Tentative Date)', 'Public Holiday']
# ['2040', '15 Dec', 'Saturday', 'Eid al-Qurban (Tentative Date)', 'Public Holiday']
# ['2040', '16 Dec', 'Sunday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2040', '17 Dec', 'Monday', 'Eid al-Qurban Holiday (Tentative Date)', 'Public Holiday']
# ['2040', '21 Dec', 'Friday', 'December Solstice', 'Season']
# Back to main page
# Current geo: albania
# Total years: 41
# Processing year: 2000
# No information found for year 2000. Moving to next year
# Processing year: 2001
# No information found for year 2001. Moving to next year
# Processing year: 2002
# No information found for year 2002. Moving to next year
# Processing year: 2003
# No information found for year 2003. Moving to next year
# Processing year: 2004
# No information found for year 2004. Moving to next year
# Processing year: 2005
# No information found for year 2005. Moving to next year
# Processing year: 2006
# No information found for year 2006. Moving to next year
# Processing year: 2007
# No information found for year 2007. Moving to next year
# Processing year: 2008
# No information found for year 2008. Moving to next year
# Processing year: 2009
# No information found for year 2009. Moving to next year
# Processing year: 2010
# Total holidays for the year: 40
# ['2010', '1 Jan', 'Friday', "New Year's Day", 'National holiday']
# ['2010', '2 Jan', 'Saturday', "New Year's Day (Day 2)", 'National holiday']
# ['2010', '4 Jan', 'Monday', "Day off for New Year's Day (Day 2)", 'National holiday']
# ['2010', '14 Feb', 'Sunday', "Valentine's Day", 'Observance']
# ['2010', '8 Mar', 'Monday', "Mothers' Day", 'Observance']
# ['2010', '14 Mar', 'Sunday', 'Summer Day', 'National holiday']
# ['2010', '15 Mar', 'Monday', 'Day off for Summer Day', 'National holiday']
# ['2010', '20 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2010', '22 Mar', 'Monday', 'Nevruz Day', 'National holiday']
# ['2010', '28 Mar', 'Sunday', 'Daylight Saving Time starts', 'Clock change/Daylight Saving Time']
# ['2010', '2 Apr', 'Friday', 'Good Friday', 'Observance']
# ['2010', '2 Apr', 'Friday', 'Good Friday (Orthodox)', 'Observance, Orthodox']
# ['2010', '3 Apr', 'Saturday', 'Holy Saturday', 'Observance']
# ['2010', '3 Apr', 'Saturday', 'Easter Saturday (Orthodox)', 'Observance, Orthodox']
# ['2010', '4 Apr', 'Sunday', 'Easter Sunday', 'National holiday']
# ['2010', '4 Apr', 'Sunday', 'Easter Sunday (Orthodox)', 'National holiday, Orthodox']
# ['2010', '5 Apr', 'Monday', 'Day off for Easter Sunday', 'National holiday']
# ['2010', '5 Apr', 'Monday', 'Easter Monday', 'Observance']
# ['2010', '5 Apr', 'Monday', 'Easter Monday (Orthodox)', 'Observance, Orthodox']
# ['2010', '5 Apr', 'Monday', 'Day off for Easter Sunday (Orthodox)', 'National holiday']
# ['2010', '1 May', 'Saturday', 'International Worker’s Day', 'National holiday']
# ['2010', '3 May', 'Monday', 'Day off for International Worker’s Day', 'National holiday']
# ...
# Processing year: 2023
# Total holidays for the year: 26
# ['2023', '1 Jan', 'Sunday', "New Year's Day", 'Public Holiday']
# ['2023', '2 Jan', 'Monday', "Day off for New Year's Day", 'Public Holiday']
# ['2023', '15 Jan', 'Sunday', 'George Price Day', 'Public Holiday']
# ['2023', '16 Jan', 'Monday', 'Day off for George Price Day', 'Public Holiday']
# ['2023', '6 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2023', '9 Mar', 'Thursday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2023', '20 Mar', 'Monday', 'March Equinox', 'Season']
# ['2023', '7 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2023', '8 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2023', '9 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2023', '10 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2023', '1 May', 'Monday', 'Labor Day / May Day', 'Public Holiday']
# ['2023', '21 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2023', '31 Jul', 'Monday', 'Day off for Emancipation Day', 'Public Holiday']
# ['2023', '1 Aug', 'Tuesday', 'Emancipation Day', 'Public Holiday']
# ['2023', '10 Sep', 'Sunday', "St. George's Caye Day", 'Public Holiday']
# ['2023', '11 Sep', 'Monday', "Day off for St. George's Caye Day", 'Public Holiday']
# ['2023', '21 Sep', 'Thursday', 'Independence Day', 'Public Holiday']
# ['2023', '23 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2023', '9 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2023', '12 Oct', 'Thursday', 'El Día de la Raza', 'Public Holiday']
# ['2023', '19 Nov', 'Sunday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2023', '20 Nov', 'Monday', 'Day off for Garifuna Settlement Day', 'Public Holiday']
# ['2023', '21 Dec', 'Thursday', 'December Solstice', 'Season']
# ['2023', '25 Dec', 'Monday', 'Christmas Day', 'Public Holiday']
# ['2023', '26 Dec', 'Tuesday', 'Boxing Day', 'Public Holiday']
# Processing year: 2024
# Total holidays for the year: 22
# ['2024', '1 Jan', 'Monday', "New Year's Day", 'Public Holiday']
# ['2024', '15 Jan', 'Monday', 'George Price Day', 'Public Holiday']
# ['2024', '9 Mar', 'Saturday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2024', '11 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2024', '19 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2024', '29 Mar', 'Friday', 'Good Friday', 'Public Holiday']
# ['2024', '30 Mar', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2024', '31 Mar', 'Sunday', 'Easter Sunday', 'Observance']
# ['2024', '1 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2024', '29 Apr', 'Monday', 'Day off for Labor Day / May Day', 'Public Holiday']
# ['2024', '1 May', 'Wednesday', 'Labor Day / May Day', 'Public Holiday']
# ['2024', '20 Jun', 'Thursday', 'June Solstice', 'Season']
# ['2024', '1 Aug', 'Thursday', 'Emancipation Day', 'Public Holiday']
# ['2024', '10 Sep', 'Tuesday', "St. George's Caye Day", 'Public Holiday']
# ['2024', '21 Sep', 'Saturday', 'Independence Day', 'Public Holiday']
# ['2024', '22 Sep', 'Sunday', 'September Equinox', 'Season']
# ['2024', '12 Oct', 'Saturday', 'El Día de la Raza', 'Public Holiday']
# ['2024', '14 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2024', '19 Nov', 'Tuesday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2024', '21 Dec', 'Saturday', 'December Solstice', 'Season']
# ['2024', '25 Dec', 'Wednesday', 'Christmas Day', 'Public Holiday']
# ['2024', '26 Dec', 'Thursday', 'Boxing Day', 'Public Holiday']
# Processing year: 2025
# Total holidays for the year: 22
# ['2025', '1 Jan', 'Wednesday', "New Year's Day", 'Public Holiday']
# ['2025', '15 Jan', 'Wednesday', 'George Price Day', 'Public Holiday']
# ['2025', '9 Mar', 'Sunday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2025', '10 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2025', '20 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2025', '18 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2025', '19 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2025', '20 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2025', '21 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2025', '1 May', 'Thursday', 'Labor Day / May Day', 'Public Holiday']
# ['2025', '20 Jun', 'Friday', 'June Solstice', 'Season']
# ['2025', '1 Aug', 'Friday', 'Emancipation Day', 'Public Holiday']
# ['2025', '10 Sep', 'Wednesday', "St. George's Caye Day", 'Public Holiday']
# ['2025', '21 Sep', 'Sunday', 'Independence Day', 'Public Holiday']
# ['2025', '22 Sep', 'Monday', 'Day off for Independence Day', 'Public Holiday']
# ['2025', '22 Sep', 'Monday', 'September Equinox', 'Season']
# ['2025', '12 Oct', 'Sunday', 'El Día de la Raza', 'Public Holiday']
# ['2025', '13 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2025', '19 Nov', 'Wednesday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2025', '21 Dec', 'Sunday', 'December Solstice', 'Season']
# ['2025', '25 Dec', 'Thursday', 'Christmas Day', 'Public Holiday']
# ['2025', '26 Dec', 'Friday', 'Boxing Day', 'Public Holiday']
# Processing year: 2026
# Total holidays for the year: 21
# ['2026', '1 Jan', 'Thursday', "New Year's Day", 'Public Holiday']
# ['2026', '15 Jan', 'Thursday', 'George Price Day', 'Public Holiday']
# ['2026', '9 Mar', 'Monday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2026', '20 Mar', 'Friday', 'March Equinox', 'Season']
# ['2026', '3 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2026', '4 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2026', '5 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2026', '6 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2026', '1 May', 'Friday', 'Labor Day / May Day', 'Public Holiday']
# ['2026', '21 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2026', '31 Jul', 'Friday', 'Day off for Emancipation Day', 'Public Holiday']
# ['2026', '1 Aug', 'Saturday', 'Emancipation Day', 'Public Holiday']
# ['2026', '10 Sep', 'Thursday', "St. George's Caye Day", 'Public Holiday']
# ['2026', '21 Sep', 'Monday', 'Independence Day', 'Public Holiday']
# ['2026', '22 Sep', 'Tuesday', 'September Equinox', 'Season']
# ['2026', '12 Oct', 'Monday', 'El Día de la Raza', 'Public Holiday']
# ['2026', '19 Nov', 'Thursday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2026', '21 Dec', 'Monday', 'December Solstice', 'Season']
# ['2026', '25 Dec', 'Friday', 'Christmas Day', 'Public Holiday']
# ['2026', '26 Dec', 'Saturday', 'Boxing Day', 'Public Holiday']
# ['2026', '28 Dec', 'Monday', 'Day off for Boxing Day', 'Public Holiday']
# Processing year: 2027
# Total holidays for the year: 23
# ['2027', '1 Jan', 'Friday', "New Year's Day", 'Public Holiday']
# ['2027', '15 Jan', 'Friday', 'George Price Day', 'Public Holiday']
# ['2027', '8 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2027', '9 Mar', 'Tuesday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2027', '20 Mar', 'Saturday', 'March Equinox', 'Season']
# ['2027', '26 Mar', 'Friday', 'Good Friday', 'Public Holiday']
# ['2027', '27 Mar', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2027', '28 Mar', 'Sunday', 'Easter Sunday', 'Observance']
# ['2027', '29 Mar', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2027', '1 May', 'Saturday', 'Labor Day / May Day', 'Public Holiday']
# ['2027', '21 Jun', 'Monday', 'June Solstice', 'Season']
# ['2027', '1 Aug', 'Sunday', 'Emancipation Day', 'Public Holiday']
# ['2027', '2 Aug', 'Monday', 'Day off for Emancipation Day', 'Public Holiday']
# ['2027', '10 Sep', 'Friday', "St. George's Caye Day", 'Public Holiday']
# ['2027', '21 Sep', 'Tuesday', 'Independence Day', 'Public Holiday']
# ['2027', '23 Sep', 'Thursday', 'September Equinox', 'Season']
# ['2027', '11 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2027', '12 Oct', 'Tuesday', 'El Día de la Raza', 'Public Holiday']
# ['2027', '19 Nov', 'Friday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2027', '21 Dec', 'Tuesday', 'December Solstice', 'Season']
# ['2027', '25 Dec', 'Saturday', 'Christmas Day', 'Public Holiday']
# ['2027', '26 Dec', 'Sunday', 'Boxing Day', 'Public Holiday']
# ['2027', '28 Dec', 'Tuesday', 'Day off for Boxing Day', 'Public Holiday']
# Processing year: 2028
# Total holidays for the year: 23
# ['2028', '1 Jan', 'Saturday', "New Year's Day", 'Public Holiday']
# ['2028', '15 Jan', 'Saturday', 'George Price Day', 'Public Holiday']
# ['2028', '6 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2028', '9 Mar', 'Thursday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2028', '19 Mar', 'Sunday', 'March Equinox', 'Season']
# ['2028', '14 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2028', '15 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2028', '16 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2028', '17 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2028', '1 May', 'Monday', 'Labor Day / May Day', 'Public Holiday']
# ['2028', '20 Jun', 'Tuesday', 'June Solstice', 'Season']
# ['2028', '1 Aug', 'Tuesday', 'Emancipation Day', 'Public Holiday']
# ['2028', '10 Sep', 'Sunday', "St. George's Caye Day", 'Public Holiday']
# ['2028', '11 Sep', 'Monday', "Day off for St. George's Caye Day", 'Public Holiday']
# ['2028', '21 Sep', 'Thursday', 'Independence Day', 'Public Holiday']
# ['2028', '22 Sep', 'Friday', 'September Equinox', 'Season']
# ['2028', '9 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2028', '12 Oct', 'Thursday', 'El Día de la Raza', 'Public Holiday']
# ['2028', '19 Nov', 'Sunday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2028', '20 Nov', 'Monday', 'Day off for Garifuna Settlement Day', 'Public Holiday']
# ['2028', '21 Dec', 'Thursday', 'December Solstice', 'Season']
# ['2028', '25 Dec', 'Monday', 'Christmas Day', 'Public Holiday']
# ['2028', '26 Dec', 'Tuesday', 'Boxing Day', 'Public Holiday']
# Processing year: 2029
# Total holidays for the year: 21
# ['2029', '1 Jan', 'Monday', "New Year's Day", 'Public Holiday']
# ['2029', '15 Jan', 'Monday', 'George Price Day', 'Public Holiday']
# ['2029', '9 Mar', 'Friday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2029', '12 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2029', '20 Mar', 'Tuesday', 'March Equinox', 'Season']
# ['2029', '30 Mar', 'Friday', 'Good Friday', 'Public Holiday']
# ['2029', '31 Mar', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2029', '1 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2029', '2 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2029', '1 May', 'Tuesday', 'Labor Day / May Day', 'Public Holiday']
# ['2029', '20 Jun', 'Wednesday', 'June Solstice', 'Season']
# ['2029', '1 Aug', 'Wednesday', 'Emancipation Day', 'Public Holiday']
# ['2029', '10 Sep', 'Monday', "St. George's Caye Day", 'Public Holiday']
# ['2029', '21 Sep', 'Friday', 'Independence Day', 'Public Holiday']
# ['2029', '22 Sep', 'Saturday', 'September Equinox', 'Season']
# ['2029', '12 Oct', 'Friday', 'El Día de la Raza', 'Public Holiday']
# ['2029', '15 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2029', '19 Nov', 'Monday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2029', '21 Dec', 'Friday', 'December Solstice', 'Season']
# ['2029', '25 Dec', 'Tuesday', 'Christmas Day', 'Public Holiday']
# ['2029', '26 Dec', 'Wednesday', 'Boxing Day', 'Public Holiday']
# Processing year: 2030
# Total holidays for the year: 21
# ['2030', '1 Jan', 'Tuesday', "New Year's Day", 'Public Holiday']
# ['2030', '15 Jan', 'Tuesday', 'George Price Day', 'Public Holiday']
# ['2030', '9 Mar', 'Saturday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2030', '11 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2030', '20 Mar', 'Wednesday', 'March Equinox', 'Season']
# ['2030', '19 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2030', '20 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2030', '21 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2030', '22 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2030', '1 May', 'Wednesday', 'Labor Day / May Day', 'Public Holiday']
# ['2030', '21 Jun', 'Friday', 'June Solstice', 'Season']
# ['2030', '1 Aug', 'Thursday', 'Emancipation Day', 'Public Holiday']
# ['2030', '10 Sep', 'Tuesday', "St. George's Caye Day", 'Public Holiday']
# ['2030', '21 Sep', 'Saturday', 'Independence Day', 'Public Holiday']
# ['2030', '22 Sep', 'Sunday', 'September Equinox', 'Season']
# ['2030', '12 Oct', 'Saturday', 'El Día de la Raza', 'Public Holiday']
# ['2030', '14 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2030', '19 Nov', 'Tuesday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2030', '21 Dec', 'Saturday', 'December Solstice', 'Season']
# ['2030', '25 Dec', 'Wednesday', 'Christmas Day', 'Public Holiday']
# ['2030', '26 Dec', 'Thursday', 'Boxing Day', 'Public Holiday']
# Processing year: 2031
# Total holidays for the year: 22
# ['2031', '1 Jan', 'Wednesday', "New Year's Day", 'Public Holiday']
# ['2031', '15 Jan', 'Wednesday', 'George Price Day', 'Public Holiday']
# ['2031', '9 Mar', 'Sunday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2031', '10 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2031', '20 Mar', 'Thursday', 'March Equinox', 'Season']
# ['2031', '11 Apr', 'Friday', 'Good Friday', 'Public Holiday']
# ['2031', '12 Apr', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2031', '13 Apr', 'Sunday', 'Easter Sunday', 'Observance']
# ['2031', '14 Apr', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2031', '1 May', 'Thursday', 'Labor Day / May Day', 'Public Holiday']
# ['2031', '21 Jun', 'Saturday', 'June Solstice', 'Season']
# ['2031', '1 Aug', 'Friday', 'Emancipation Day', 'Public Holiday']
# ['2031', '10 Sep', 'Wednesday', "St. George's Caye Day", 'Public Holiday']
# ['2031', '21 Sep', 'Sunday', 'Independence Day', 'Public Holiday']
# ['2031', '22 Sep', 'Monday', 'Day off for Independence Day', 'Public Holiday']
# ['2031', '22 Sep', 'Monday', 'September Equinox', 'Season']
# ['2031', '12 Oct', 'Sunday', 'El Día de la Raza', 'Public Holiday']
# ['2031', '13 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2031', '19 Nov', 'Wednesday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2031', '21 Dec', 'Sunday', 'December Solstice', 'Season']
# ['2031', '25 Dec', 'Thursday', 'Christmas Day', 'Public Holiday']
# ['2031', '26 Dec', 'Friday', 'Boxing Day', 'Public Holiday']
# Processing year: 2032
# Total holidays for the year: 23
# ['2032', '1 Jan', 'Thursday', "New Year's Day", 'Public Holiday']
# ['2032', '15 Jan', 'Thursday', 'George Price Day', 'Public Holiday']
# ['2032', '8 Mar', 'Monday', 'Day off for National Heroes and Benefactors Day', 'Public Holiday']
# ['2032', '9 Mar', 'Tuesday', 'National Heroes and Benefactors Day', 'Public Holiday']
# ['2032', '19 Mar', 'Friday', 'March Equinox', 'Season']
# ['2032', '26 Mar', 'Friday', 'Good Friday', 'Public Holiday']
# ['2032', '27 Mar', 'Saturday', 'Holy Saturday', 'Public Holiday']
# ['2032', '28 Mar', 'Sunday', 'Easter Sunday', 'Observance']
# ['2032', '29 Mar', 'Monday', 'Easter Monday', 'Public Holiday']
# ['2032', '1 May', 'Saturday', 'Labor Day / May Day', 'Public Holiday']
# ['2032', '20 Jun', 'Sunday', 'June Solstice', 'Season']
# ['2032', '1 Aug', 'Sunday', 'Emancipation Day', 'Public Holiday']
# ['2032', '2 Aug', 'Monday', 'Day off for Emancipation Day', 'Public Holiday']
# ['2032', '10 Sep', 'Friday', "St. George's Caye Day", 'Public Holiday']
# ['2032', '21 Sep', 'Tuesday', 'Independence Day', 'Public Holiday']
# ['2032', '22 Sep', 'Wednesday', 'September Equinox', 'Season']
# ['2032', '11 Oct', 'Monday', 'Day off for El Día de la Raza', 'Public Holiday']
# ['2032', '12 Oct', 'Tuesday', 'El Día de la Raza', 'Public Holiday']
# ['2032', '19 Nov', 'Friday', 'Garifuna Settlement Day', 'Public Holiday']
# ['2032', '21 Dec', 'Tuesday', 'December Solstice', 'Season']
# ['2032', '25 Dec', 'Saturday', 'Christmas Day', 'Public Holiday']
# ['2032', '26 Dec', 'Sunday', 'Boxing Day', 'Public Holiday']
# ['2032', '28 Dec', 'Tuesday', 'Day off for Boxing Day', 'Public Holiday']
# Processing year: 2033

# %% [markdown]
# ## Extract metadata of dataset for storing purpose

# %%
## Convert dataset dictionary to dataframe
if geo_holiday_tracking_dict:
    df = pd.DataFrame.from_dict(geo_holiday_tracking_dict, columns=["Event Year", "Date", "Day", "Name", "Type"])

    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime.now().strftime("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now
    df.head()

    dataset_filename = f"Smartlocal_dataset_{file_name_date}.csv"
    df.to_csv(dataset_filename,index=False)


# Close driver upon completion
driver.quit()

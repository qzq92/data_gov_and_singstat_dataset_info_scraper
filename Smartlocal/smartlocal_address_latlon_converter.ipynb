# %% [markdown]
# # Address to lat Lon conversion
# This notebook is used for generating lat lon for all known locations from the input files.
# It uses Nominatim tool to search addresses lat lon from OpenSourceMap service, which does not need any API key and is free.

# %%
# importing geopy library and Nominatim class
from geopy.distance import geodesic
from geopy.geocoders import Nominatim
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver 
from selenium.common.exceptions import NoSuchElementException
import pandas as pd
import time
import math
import pandas as pd
# calling the Nominatim tool and create Nominatim class limiting to SG
loc = Nominatim(user_agent="my-latlon-application",timeout=10)

# %% [markdown]
# # Using identified mrt stations as markers for NSEW
#
# - 'Tampines station': [1.3542907, 103.9446144428833],
# - 'Jurong East station': [1.3321552, 103.7429844],
# - 'Woodlands station': [1.4372552, 103.787231],
# - 'Outram park station': [1.2804624, 103.83991801312565]

# %%
# Location
country_codes="sg"
nsew_dict = {
    "Tampines station": None,
    "Jurong East station": None,
    "Woodlands station": None,
    "Outram park station": None
}

# Mapping dictionary for used mrt stations
stn_geo_dict = {
    "Tampines station": "East",
    "Jurong East station": "West",
    "Woodlands station": "North",
    "Outram park station": "South"
}

for location in nsew_dict.keys():
    try:
        print(f"Lat lon for {location}")
        getLoc = loc.geocode(location, country_codes="sg")
        if getLoc:
            nsew_dict[location] = [getLoc.latitude, getLoc.longitude]
        else:
            print("Cannot decipher the location")
    except TimeoutError:
        print("Retrying")
        time.sleep(3)
        getLoc = loc.geocode(location, country_codes="sg")
        print(f"Address: {getLoc.address}")
        nsew_dict[location] = [getLoc.latitude, getLoc.longitude]
nsew_dict
# Out:
# Lat lon for Tampines station
# Lat lon for Jurong East station
# Lat lon for Woodlands station
# Lat lon for Outram park station
# {'Tampines station': [1.3542907, 103.9446144428833],
#  'Jurong East station': [1.3321552, 103.7429844],
#  'Woodlands station': [1.4372552, 103.787231],
#  'Outram park station': [1.2804624, 103.83991801312565]}

# %% [markdown]
# ## Helper functions

# %%
# Define a retry decorator
def retry(max_retries, wait_time):
    def decorator(func):
        def wrapper(*args, **kwargs):
            retries = 0
            while retries < max_retries:
                try:
                    result = func(*args, **kwargs)
                    return result
                except TimeoutError:
                    retries += 1
                    time.sleep(wait_time)
            else:
              raise TimeoutError(f"Max retries of function {func} exceeded")
        return wrapper
    return decorator

# %%
# Apply search with retry decorartor 
@retry(max_retries=5, wait_time=1)
def location_lat_lon(location_str: str, country_codes: str ="sg"):
    # Get the first information block
    location_str = str(location_str)
    if location_str:
        print(location_str)
        location_list = location_str.split(",")
        for location in location_list:
            getLoc = loc.geocode(location, country_codes=country_codes, limit=1)
            if getLoc:
                print("Lat and Lon info:")
                print(getLoc.latitude, getLoc.longitude)
                print()
                return {"Lat": getLoc.latitude, "Lon": getLoc.longitude}
            else:
                print("Using the subsequent information to try")
                print()
    # For null case, just end the program
    else:
        return {"Lat": "All", "Lon": "All"}

# %%
# Some postal code cannot be geocoded due to sensitivities as below such as Istana
getLoc = loc.geocode("Singapore 238823", country_codes="sg", limit=1)
if getLoc:
    print(getLoc.latitude, getLoc.longitude)

# %%
# read in smart local dataset
SMARTLOCAL_DATASET_PATH = "Smartlocal_dataset_31032024_141310.csv"
df = pd.read_csv(SMARTLOCAL_DATASET_PATH)
df.head()
# Out:
#                                      Event Title                  Date  \
# 0  West Mall BT21-Themed CNY Activities & Promos  05 Jan - 24 Feb 2024
# 1              Comma Creative Arts Festival 2024      12 - 28 Jan 2024
# 2                            Light To Night 2024  19 Jan - 08 Feb 2024
# 3      Creative Intersections: Traces Of Dragons  19 Jan - 25 Feb 2024
# 4                             Artbox Avenue 2024  26 Jan - 04 Feb 2024
#
#                                             Location Status  \
# 0            1 Bukit Batok Central, Singapore 658713  ENDED
# 1                   2 Orchard Link, Singapore 237978  ENDED
# 2                                     Civic District  ENDED
# 3                                              Funan  ENDED
# 4  Singapore Expo Hall 2, 1 Expo Drive, Singapore...  ENDED
#
#                                                  URL        Date_of_check
# 0  https://thesmartlocal.com/read/west-mall-bt21-...  31/03/2024 14:13:10
# 1  https://thesmartlocal.com/read/comma-creative-...  31/03/2024 14:13:10
# 2  https://thesmartlocal.com/read/light-to-night-...  31/03/2024 14:13:10
# 3  https://thesmartlocal.com/read/singapore-art-w...  31/03/2024 14:13:10
# 4  https://thesmartlocal.com/read/artbox-avenue-2...  31/03/2024 14:13:10

# %% [markdown]
# There are missing location in the entries due to info unavailability on the page which info is scraped. TO determine the location, separate access to url link is required to extract relevant info out. This applies to date as well.

# %%
# Check of missing entries
missing_location_entries_df = df[df["Location"].isnull()]
missing_location_entries_df.shape
# Out:
# (84, 6)

# %% [markdown]
# Do location mapping based on scraped address in the best ability.
# Note that the geocoder tool may not necessary provide the lat/lon info which could be done via GoogleMapV3.

# %%
# Direct location mapping 
df[["Lat","Lon"]]= df.apply(lambda row: location_lat_lon(row["Location"]), axis="columns", result_type="expand")
# Out:
# 1 Bukit Batok Central, Singapore 658713
# Lat and Lon info:
# 1.3500765000000001 103.74925662743149
#
# 2 Orchard Link, Singapore 237978
# Lat and Lon info:
# 1.3010848 103.8352023
#
# Civic District
# Lat and Lon info:
# 1.2917349 103.8511298
#
# Funan
# Lat and Lon info:
# 1.291313 103.84994707397723
#
# Singapore Expo Hall 2, 1 Expo Drive, Singapore 486150
# Lat and Lon info:
# 1.3371524 103.9599267
#
# 6 Raffles Boulevard, #03-208/209 Marina Square, Singapore 039594
# Lat and Lon info:
# 1.29161 103.8568156522325
#
# Orchard Road, Singapore 238823
# Lat and Lon info:
# 1.3068733 103.8284095
#
# Palawan Green, Siloso Beach Walk, Sentosa, Singapore 098236
# Lat and Lon info:
# 1.2505965 103.8181594
#
# Kampong Gelam
# Lat and Lon info:
# 1.3025865 103.85996496668358
#
# 1 Geylang Serai, Singapore 402001
# Lat and Lon info:
# 1.3166958 103.8982195336871
#
# Chinatown Point
# Lat and Lon info:
# 1.28519745 103.8449051848437
#
# 18 Marina Gardens Drive, Gardens by the Bay, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# 8 Sentosa Gateway, Singapore 098269
# Lat and Lon info:
# 1.25574585 103.82123439403357
#
# nan
# Using the subsequent information to try
#
# Bukit Gombak Neighbourhood Centre
# Lat and Lon info:
# 1.3586722 103.7513271
#
# Katong Square, 88 East Coast Road, Singapore 423371
# Lat and Lon info:
# 1.30470365 103.90480078131988
#
# 1 St Andrew's Rd, #01-01, Singapore 178957
# Lat and Lon info:
# 1.29054805 103.85164439937722
#
# 39 Keppel Road, Tanjong Pagar Distripark, Singapore 089065
# Lat and Lon info:
# 1.2718641000000002 103.8366573
#
# Jewel Changi Airport, 78 Airport Boulevard., Singapore 819666
# Lat and Lon info:
# 1.36022425 103.98967490995528
#
# Bayfront Event Space, 12A Bayfront Avenue, Singapore 018970
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 10 Penang Road, Visual Arts Centre, Singapore 238469
# Lat and Lon info:
# 1.2988513 103.8436442
#
# Orchard Road, Singapore 238823
# Lat and Lon info:
# 1.3068733 103.8284095
#
# Sands Theatre, 4 Bayfront Avenue, B1, Singapore 018973
# Lat and Lon info:
# 1.2848963 103.8606918
#
# 200 Turf Club Road, The Grandstand South Carpark, Singapore 287994
# Lat and Lon info:
# 1.3406029 103.7926557
#
# Gardens by the Bay, 18 Marina Gardens Drive, Singapore 018953
# Lat and Lon info:
# 1.2791404499999999 103.86792771351024
#
# 14 Medical Drive, National University of Singapore, Block MD6, Level 2 (Audiology SMART Classroom), Singapore 117599
# Lat and Lon info:
# 1.2968894 103.7821868
#
# Esplanade Theatre, 1 Esplanade Drive, Singapore 038981
# Lat and Lon info:
# 1.2900899 103.85557894283974
#
# Suntec City West, Level 1 #327-328 (outside Uniqlo)
# Using the subsequent information to try
#
# Using the subsequent information to try
#
# Singapore Expo Hall 6, 1 Expo Drive, Singapore 486041
# Lat and Lon info:
# 1.3371524 103.9599267
#
# 176 Orchard Road, Singapore 238843
# Lat and Lon info:
# 1.3018345 103.8397126731343
#
# 18 Marina Gardens Drive, Gardens by the Bay, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# 1 Geylang Serai, Singapore 402001
# Lat and Lon info:
# 1.3166958 103.8982195336871
#
# 302 Tiong Bahru Road, Tiong Bahru Plaza (BreadTalk entrance), Singapore 168732
# Lat and Lon info:
# 1.286339 103.8271622
#
# Flower Dome, Gardens by the Bay, 18 Marina Gardens Drive, Singapore 018953
# Lat and Lon info:
# 1.2845358500000001 103.86470160717042
#
# Lorong Bekukong, Changi Point Waterfront Park
# Lat and Lon info:
# 1.3905623 103.9870566
#
# 250 Orchard Road, Design Orchard, Singapore 238905
# Lat and Lon info:
# 1.3020893500000001 103.83793019061343
#
# Marina Bay Sands Convention Centre, Level 3, Cassia Jr
# Lat and Lon info:
# 1.2823291 103.8585262
#
# 39 Keppel Rd, Tanjong Pagar Distripark, Singapore 089065
# Lat and Lon info:
# 1.2718641000000002 103.8366573
#
# 1 Tampines Walk, Singapore 528523
# Lat and Lon info:
# 1.3537755 103.9398986
#
# 6 Raffles Boulevard, #03-208/209 Marina Square, Singapore 039594
# Lat and Lon info:
# 1.29161 103.8568156522325
#
# Marina Bay, South Beach & Millenia Walk
# Lat and Lon info:
# 1.27546735 103.85477325464656
#
# 43 Admiralty Road West, SAF Yacht Club, Singapore 759962
# Lat and Lon info:
# 1.4698476 103.8193193
#
# 252 North Bridge Road, #01-01 Raffles City, Singapore 179103
# Lat and Lon info:
# 1.2938961 103.85334282751231
#
# 201 Victoria Street, Level 2 Bugis+, Sinagpore 188067
# Lat and Lon info:
# 1.3000551 103.8541314
#
# Along 391A Orchard Road, Ngee Ann City, Singapore 238873
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3026170499999998 103.83452841745742
#
# 113 Somerset Road, The Red Box, Singapore 238165
# Lat and Lon info:
# 1.300887 103.8365851
#
# 12A Bayfront Ave, Singapore 018970
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 409 Race Course Road, #03-01A, Singapore 218657
# Lat and Lon info:
# 1.3156522499999999 103.85731308030014
#
# 1 Stadium Drive, Kallang, Singapore 271003
# Lat and Lon info:
# 1.3043502 103.87766
#
# Fort Canning Green, River Valley Road, Singapore 179037
# Lat and Lon info:
# 1.2953885 103.8474312
#
# 176 Orchard Road, The Centrepoint, Level 1 Atrium, Singapore 238843
# Lat and Lon info:
# 1.3018345 103.8397126731343
#
# 93 Stamford Road, Singapore 178897
# Lat and Lon info:
# 1.2965476 103.84831668321195
#
# 12 Tai Gin Road, Singapore 327874
# Lat and Lon info:
# 1.32805595 103.8470566277956
#
# 1 HarbourFront Walk, Singapore 098585
# Lat and Lon info:
# 1.2651889 103.8220893
#
# 10 Paya Lebar Road, Singapore 409057
# Lat and Lon info:
# 1.3173659 103.8930327
#
# Multiple locations
# Using the subsequent information to try
#
# 18 Marina Gardens Drive, Gardens By The Bay, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# 27 Pasir Panjang Road, Singapore 117537
# Lat and Lon info:
# 1.27055095 103.79855219867372
#
# 8A Marina Boulevard, Singapore 018984
# Lat and Lon info:
# 1.2812488 103.8530087
#
# 8 Sentosa Gateway, Universal Studios Singapore, Singapore 098269
# Lat and Lon info:
# 1.25574585 103.82123439403357
#
# 11 Prinsep Link
# Lat and Lon info:
# 1.3000175 103.85030389813939
#
# 1 Sophia Road, Peace Centre, Singapore 228161
# Lat and Lon info:
# 1.3013567 103.8497242
#
# Marina Bay Sands Convention Centre Hall D
# Using the subsequent information to try
#
# Little India
# Lat and Lon info:
# 1.30684265 103.84927355170905
#
# 311 New Upper Changi Road, Singapore 467360
# Lat and Lon info:
# 1.32481115 103.92925437897793
#
# Haw Par Villa, 262 Pasir Panjang Road, Singapore 118628
# Lat and Lon info:
# 1.28267795 103.78180159288999
#
# 3 Temasek Boulevard, #03-373, Singapore 038983
# Lat and Lon info:
# 1.2951505 103.8598741
#
# 407 Northshore Drive, Singapore 820407
# Lat and Lon info:
# 1.4166164 103.9022247
#
# siloso beach
# Lat and Lon info:
# 1.25436715 103.81332806102239
#
# Suntec City
# Lat and Lon info:
# 1.2942651 103.8591876
#
# Jewel Changi Airport, Level 04-220/221
# Lat and Lon info:
# 1.36022425 103.98967490995528
#
# Jewel Changi, 78 Airport Boulevard, Singapore 819666
# Lat and Lon info:
# 1.36022425 103.98967490995528
#
# Level 7 Carpark, 68 Orchard Road, Singapore 238839
# Lat and Lon info:
# 1.3500391 103.750699
#
# 4 Bayfront Avenue, Sands Theatre, Singapore 018973
# Lat and Lon info:
# 1.2891903 103.8609981
#
# Science Centre Singapore
# Lat and Lon info:
# 1.3328377 103.73601896466558
#
# Padang A, Angsana Johor Bahru Mall, Bandar Baru Uda, 81200 Johor Bahru, Johor, Malaysia
# Lat and Lon info:
# 1.3095594 103.8658109
#
# 1 Expo Drive, Singapore 486150
# Lat and Lon info:
# 1.334308 103.959258
#
# 217 Lavender Street, Haus217, Singapore 338772
# Lat and Lon info:
# 1.3145395 103.8595953354118
#
# National Museum of Singapore
# Lat and Lon info:
# 1.2965476 103.84831668321195
#
# Gardens By The Bay, 18 Marina Gardens Drive, Singapore 018953
# Lat and Lon info:
# 1.2791404499999999 103.86792771351024
#
# 1 Raffles Boulevard, Room 321-322, Summit 1, Suntec Singapore Convention & Exhibition Centre, Singapore 039593
# Lat and Lon info:
# 1.2931797 103.8578355
#
# Bayfront Event Space,12A Bayfront Avenue, Singapore 018970
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2891903 103.8609981
#
# Bayfront Event Space, 12A Bayfront Avenue, Singapore 018970
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 311 New Upper Changi Road, Singapore 467360
# Lat and Lon info:
# 1.32481115 103.92925437897793
#
# 1 Maritime Square, Singapore 099253
# Lat and Lon info:
# 1.2643008 103.8204657
#
# Suntec Convention and Exhibition Centre, Level 3
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3544776 103.9888639
#
# Civic District
# Lat and Lon info:
# 1.2917349 103.8511298
#
# nan
# Using the subsequent information to try
#
# 2 Orchard Link, #01-02 MOX @ *SCAPE, Singapore 237978
# Lat and Lon info:
# 1.3010848 103.8352023
#
# Sentosa
# Lat and Lon info:
# 1.24894585 103.83430564159272
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 65 Airport Boulevard, Changi Airport Terminal 3, Singapore 819663
# Lat and Lon info:
# 1.3496232 103.982979
#
# nan
# Using the subsequent information to try
#
# 1 Geylang Serai, Singapore 402001
# Lat and Lon info:
# 1.3166958 103.8982195336871
#
# 3 Temasek Boulevard, Suntec City East Atrium Level 1 and 3, Singapore 038983
# Lat and Lon info:
# 1.2951505 103.8598741
#
# 1 Canning Rise, National Archives of Singapore, Singapore 179868
# Lat and Lon info:
# 1.29304665 103.84849132398564
#
# 39 Duxton Hill, Singapore 089616
# Lat and Lon info:
# 1.27853855 103.84292524949117
#
# nan
# Using the subsequent information to try
#
# LingoAce @ 111 Somerset, #01-47, Singapore 238164
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3120364 103.8393248
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Chinatown Point
# Lat and Lon info:
# 1.28519745 103.8449051848437
#
# Bugis+ 201 Victoria Street, Singapore 188067
# Lat and Lon info:
# 1.2996672999999999 103.85419039106034
#
# nan
# Using the subsequent information to try
#
# Marina Bay
# Lat and Lon info:
# 1.27546735 103.85477325464656
#
# Palawan Beach, Sentosa
# Lat and Lon info:
# 1.2485469 103.82222451791372
#
# National Museum of Singapore
# Lat and Lon info:
# 1.2965476 103.84831668321195
#
# Japan Creative Centre
# Using the subsequent information to try
#
# Downtown East Begonia Open-air Carpark, 1 Pasir Ris Close, Singapore 519599
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.37809395 103.95441368964549
#
# Southside Beach, 80 Siloso Road, 098969
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2560356 103.8161935
#
# Various locations
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 1 Raffles Boulevard, Suntec Singapore Convention and Exhibition Centre, Hall 406, Singapore 039593
# Lat and Lon info:
# 1.2931797 103.8578355
#
# 12 Marina View, Asia Square Tower 2, The Westin Singapore, Singapore 018961
# Lat and Lon info:
# 1.2783661 103.8508048
#
# 23 Serangoon Central, NEX, Atrium Level 1, Singapore 556083
# Lat and Lon info:
# 1.3507085 103.8725819
#
# Kong Beng Industrial Building, 41 Jalan Pemimpin, Singapore 577186
# Lat and Lon info:
# 1.3499265 103.84176999322344
#
# ArtScience Museum, 6 Bayfront Avenue, Singapore 018974
# Lat and Lon info:
# 1.2861382 103.8592297
#
# 6 Bayfront Avenue, ArtScience Museum VR Gallery Level 4, Singapore 018974
# Lat and Lon info:
# 1.2861382 103.8592297
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 1 Esplanade Drive, Esplanade Concert Hall, Singapore 038981
# Lat and Lon info:
# 1.2900434 103.8545929
#
# Sun Yat Sen Nanyang Memorial Hall
# Using the subsequent information to try
#
# 30 Raffles Place, CIMB Plaza #02-20, OnTheList Showroom, Singapore 048622
# Lat and Lon info:
# 1.2841645 103.85196462423015
#
# Bras Basah-Bugis Precinct
# Using the subsequent information to try
#
# 18 Marina Gardens Drive, Gardens by the Bay Flower Dome, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# Along 391A Orchard Road, Ngee Ann City, Singapore 238873
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3026170499999998 103.83452841745742
#
# nan
# Using the subsequent information to try
#
# 107 North Bridge Road, Funan, Roof Garden, Singapore 179105
# Lat and Lon info:
# 1.291313 103.84994707397723
#
# 133 New Bridge Road, Singapore 059413
# Lat and Lon info:
# 1.2855811 103.8451805
#
# Bayfront Event Space, 12A Bayfront Avenue, Singapore 018970
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 6 Bayfront Avenue, Singapore 018974
# Lat and Lon info:
# 1.2861382 103.8592297
#
# nan
# Using the subsequent information to try
#
# Resorts World Sentosa Waterfront, 8 Sentosa Gateway, Singapore 098269
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.25574585 103.82123439403357
#
# 1 Sophia Road, Singapore 228161
# Lat and Lon info:
# 1.3013567 103.8497242
#
# nan
# Using the subsequent information to try
#
# 100 Loewen Road, Singapore 248837
# Lat and Lon info:
# 1.3034643 103.8115792
#
# 80 Bras Basah Road, Raffles City Convention Centre, Level 4 Room Indiana and Mintro Singapore 189560
# Lat and Lon info:
# 1.29411325 103.85394837919677
#
# 139 Cecil Street, #13-01, Singapore 069539
# Lat and Lon info:
# 1.2817092 103.8495479
#
# 30 Raffles Place, CIMB Plaza #02-20, OnTheList Showroom, Singapore 048622
# Lat and Lon info:
# 1.2841645 103.85196462423015
#
# 200 Victoria Street #B1-26 Bugis Junction, Singapore 188021
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2899175 103.8519072
#
# 5 Campbell Lane, Singapore 209924
# Lat and Lon info:
# 1.3056249 103.8523218052765
#
# 85 Bedok North Street 4, Singapore 460085
# Lat and Lon info:
# 1.3334329 103.9394837
#
# nan
# Using the subsequent information to try
#
# 10 Paya Lebar Road, Paya Lebar Quarter, Singapore 409057
# Lat and Lon info:
# 1.3173659 103.8930327
#
# Bayfront Event Space, 12A Bayfront Avenue, Singapore 018970
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2891903 103.8609981
#
# Cloud Forest, Gardens by the Bay
# Lat and Lon info:
# 1.2838777000000001 103.86603420524474
#
# 2 Bayfront Avenue B1-67, Galleria Level, The Shoppes at Marina Bay Sands, Singapore 018972
# Using the subsequent information to try
#
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2840209 103.85886829029963
#
# 2 Orchard Link, *SCAPE, Singapore 237978
# Lat and Lon info:
# 1.3010848 103.8352023
#
# 350 Orchard Road, Level B1, Shaw House, Singapore 238868
# Lat and Lon info:
# 1.3055893 103.8316799
#
# National Museum of Singapore
# Lat and Lon info:
# 1.2965476 103.84831668321195
#
# Changi Airport Terminal 3
# Lat and Lon info:
# 1.3545752 103.98540514663097
#
# 18 Marina Gardens Drive, Gardens By The Bay, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# 18 Marina Gardens Drive, Gardens by the Bay, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# 1 Pasir Ris Close, D'Marquee, Downtown East, Singapore 519599
# Lat and Lon info:
# 1.37809395 103.95441368964549
#
# Giant Hypermarket, Outdoor Carpark, 21 Tampines North Drive 2, Singapore 528765
# Lat and Lon info:
# 1.3312172 103.9483149
#
# 1 Expo Drive, Singapore Expo Hall 6, Singapore 486150
# Lat and Lon info:
# 1.334308 103.959258
#
# 37 Emerald Hill Road, Singapore 229313
# Lat and Lon info:
# 1.3055189 103.8394459
#
# ART NOW, Raffles Hotel Arcade, 328 North Bridge Road, #02-32, Singapore 188719
# Using the subsequent information to try
#
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2957567 103.853871
#
# 12A Bayfront Avenue, Singapore 018970
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 12A Bayfront Avenue, Singapore 018970
# Lat and Lon info:
# 1.2891903 103.8609981
#
# 15 Science Centre Road, Singapore 609081
# Lat and Lon info:
# 1.3328377 103.73601896466558
#
# Outdoor Atrium & Hall 4, 1 Expo Drive, Singapore 486150
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.334308 103.959258
#
# 2 Tampines Central 5, Singapore 529509
# Lat and Lon info:
# 1.35237745 103.94381950026855
#
# 2 Tampines Central 5, Singapore 529509
# Lat and Lon info:
# 1.35237745 103.94381950026855
#
# 1 Saint Andrew's Road, National Gallery Singapore, Singapore 178957
# Lat and Lon info:
# 1.29054805 103.85164439937722
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Level 6, Singapore Chinese Cultural Centre, 1 Straits Boulevard, #11-01, Singapore 018906
# Lat and Lon info:
# 1.3134092499999999 103.80484595371372
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Gardens by the Bay
# Lat and Lon info:
# 1.2791404499999999 103.86792771351024
#
# nan
# Using the subsequent information to try
#
# Science Centre Singapore
# Lat and Lon info:
# 1.3328377 103.73601896466558
#
# 1 Teck Lim Road
# Lat and Lon info:
# 1.2799466 103.84189668300395
#
# Multiple locations
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# National Design Centre
# Lat and Lon info:
# 1.2987839 103.8535318
#
# National Museum of Singapore
# Lat and Lon info:
# 1.2965476 103.84831668321195
#
# 31 Ocean Way, Sentosa Cove, Singapore 098375
# Lat and Lon info:
# 1.2469551 103.84216950511873
#
# City Square Mall
# Lat and Lon info:
# 1.3113537 103.85657122520385
#
# Suntec Convention Centre
# Lat and Lon info:
# 1.2931797 103.8578355
#
# nan
# Using the subsequent information to try
#
# West Mall
# Lat and Lon info:
# 1.3500765000000001 103.74925662743149
#
# Changi Airport Terminal 4
# Lat and Lon info:
# 1.3388292499999999 103.9839097862648
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Kallang Wave Mall
# Lat and Lon info:
# 1.3035502 103.8727810707062
#
# VivoCity, 1 HarbourFront Walk, Singapore 098585
# Lat and Lon info:
# 1.26437065 103.82295373341057
#
# 133 New Bridge Road, #B1-50A, Chinatown Point, Singapore 059413
# Lat and Lon info:
# 1.2855811 103.8451805
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 1 Sengkang Square, Singapore 545078
# Lat and Lon info:
# 1.3920336999999998 103.89495266211111
#
# Civic District
# Lat and Lon info:
# 1.2917349 103.8511298
#
# 1 Straits Boulevard, Singapore 018906
# Lat and Lon info:
# 1.275624 103.8493161
#
# nan
# Using the subsequent information to try
#
# Cloud 9 Piazza, Level 5, Jewel Changi Airport, 78 Airport Blvd, Singapore 819666
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3134092499999999 103.80484595371372
#
# Suntec Convention Centre (Hall 403)
# Lat and Lon info:
# 1.2931797 103.8578355
#
# 510 Upper Jurong Road, Singapore Discovery Centre, Singapore 638365
# Lat and Lon info:
# 1.3325085 103.6789391
#
# nan
# Using the subsequent information to try
#
# Various participating outlets for redemption
# Using the subsequent information to try
#
# 68 Orchard Road, Plaza Singapura Level 1 Atrium,Singapore 238839
# Lat and Lon info:
# 1.3004414 103.84490279418733
#
# Gain City Megastore, 71 Sungei Kadut Drive, Singapore 729577
# Lat and Lon info:
# 1.4129285 103.74596512561071
#
# nan
# Using the subsequent information to try
#
# Singapore Zoo, Night Safari, River Safari
# Lat and Lon info:
# 1.4037076 103.79403742902613
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 180 Kitchener Road Singapore 208539
# Lat and Lon info:
# 1.3109755 103.8567196
#
# nan
# Using the subsequent information to try
#
# Chinatown Point, 133 New Bridge Rd, Singapore 059413
# Lat and Lon info:
# 1.28519745 103.8449051848437
#
# nan
# Using the subsequent information to try
#
# All FairPrice supermarkets islandwide
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 1 Raffles Place, Singapore 048616
# Lat and Lon info:
# 1.2839577 103.8514078
#
# 11 Stamford Road, Singapore 178884
# Lat and Lon info:
# 1.2931673 103.8527436
#
# nan
# Using the subsequent information to try
#
# 16 Collyer Quay, Change Alley Mall, Singapore 049318
# Lat and Lon info:
# 1.2841722500000001 103.85256944003397
#
# 1 HarbourFront Walk, Singapore 098585
# Lat and Lon info:
# 1.2651889 103.8220893
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 50 Siloso Beach Walk, Siloso Beach, Sentosa
# Lat and Lon info:
# 1.2567222 103.8117993
#
# Marina Square, 6 Raffles Boulevard, Singapore 039594
# Lat and Lon info:
# 1.2912739 103.8571835763402
#
# Vivo City
# Lat and Lon info:
# 1.2640486 103.8209808
#
# 137 Cecil Street, #02-02 Singapore 069537
# Lat and Lon info:
# 1.2817092 103.8495479
#
# Level 3, Suntec City Convention Centre
# Lat and Lon info:
# 1.3544776 103.9888639
#
# Harbourfront Centre
# Lat and Lon info:
# 1.26422175 103.82024541611074
#
# 80 Mandai Lake Road, Singapore 729826
# Lat and Lon info:
# 1.4037076 103.79403742902613
#
# Gardens by the Bay
# Lat and Lon info:
# 1.2791404499999999 103.86792771351024
#
# 5 Emerald Hill Road, Singapore 229289
# Lat and Lon info:
# 1.3055189 103.8394459
#
# Supertree Grove Lawn, Gardens by the Bay
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2791404499999999 103.86792771351024
#
# Palawan Green, Sentosa
# Lat and Lon info:
# 1.2505965 103.8181594
#
# nan
# Using the subsequent information to try
#
# 11 Tanjong Katong Rd, Singapore 436950
# Lat and Lon info:
# 1.3149651 103.894924
#
# 313@somerset, Level 1 Atrium, 313 Orchard Rd, Singapore 238895
# Lat and Lon info:
# 1.3010128 103.83853994515806
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 3 River Valley Road, Clarke Quay Fountain Square, Singapore 179019
# Lat and Lon info:
# 1.2903765 103.84706910778554
#
# PassionWave, Jurong Lake Gardens
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3437351 103.7268747928237
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Various outlets around Singapore
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# OCBC Square
# Lat and Lon info:
# 1.4361993 103.7859991
#
# No. 9 Raffles Boulevard, #01-59 to 63, Millenia Walk, Singapore 039596
# Lat and Lon info:
# 1.2919894 103.8578775
#
# Chong Pang Amphitheatre, Yishun Avenue 5, Singapore 763101
# Lat and Lon info:
# 1.4314646 103.82809697806462
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# Siloso Beach, Sentosa
# Lat and Lon info:
# 1.25436715 103.81332806102239
#
# Siloso Beach, Sentosa
# Lat and Lon info:
# 1.25436715 103.81332806102239
#
# Siloso Beach, Sentosa
# Lat and Lon info:
# 1.25436715 103.81332806102239
#
# Basement 2, Tanjong Pagar Centre (Guoco Tower), 1 Wallich Street, Singapore 078881
# Lat and Lon info:
# 1.359617 103.988456
#
# Warehouse Club, 1 Joo Koon Circle, Level 3, Singapore 629117
# Lat and Lon info:
# 1.3272092 103.6786571
#
# nan
# Using the subsequent information to try
#
# KINEX
# Lat and Lon info:
# 1.3147168 103.8943086
#
# Singapore Sports Hub
# Lat and Lon info:
# 1.3032958 103.87530020798854
#
# nan
# Using the subsequent information to try
#
# Orchard Central, Level 1 Atrium, 181 Orchard Road, Singapore 238896
# Lat and Lon info:
# 1.3004926 103.8403755
#
# 18 Marina Gardens Dr, Singapore 018953
# Lat and Lon info:
# 1.2821122 103.8654957
#
# Jurong Point
# Lat and Lon info:
# 1.3394963500000001 103.70525400783333
#
# nan
# Using the subsequent information to try
#
# Suntec City Convention Centre (Hall 403 & 404)
# Using the subsequent information to try
#
# Our Tampines Hub, 1 Tampines Walk, Singapore 528523
# Lat and Lon info:
# 1.3530262 103.94067277047982
#
# 1 Harbourfront Walk, VivoCity Level 3 Sky Park, Singapore 098585
# Lat and Lon info:
# 1.2651889 103.8220893
#
# nan
# Using the subsequent information to try
#
# Junction 8
# Lat and Lon info:
# 1.3505893 103.84874474726443
#
# Stadium Roar at Singapore Sports Hub
# Using the subsequent information to try
#
# SMU, 81 Victoria St, Singapore 188065
# Lat and Lon info:
# 1.29616795 103.85004365998248
#
# ARCADE @ THE CAPITOL KEMPINSKI + CAPITOL SINGAPORE, OUTDOOR PLAZA
# Using the subsequent information to try
#
# Using the subsequent information to try
#
# National Stadium, 1 Stadium Drive, Singapore 397629
# Lat and Lon info:
# 1.30449095 103.87434371851725
#
# The Meadows, Gardens by the Bay
# Lat and Lon info:
# 1.3992429 103.91568534444444
#
# Singapore Chinese Cultural Centre, 1 Straits Boulevard, Singapore 018906
# Lat and Lon info:
# 1.2758286499999998 103.8495163787634
#
# Fusionopolis One, 1 Fusionopolis Pl, Singapore 138632
# Lat and Lon info:
# 1.29923685 103.78789068320421
#
# Marina Square, 6 Raffles Blvd, Singapore 039594
# Lat and Lon info:
# 1.2912739 103.8571835763402
#
# nan
# Using the subsequent information to try
#
# Marina Bay Street Circuit
# Lat and Lon info:
# 1.2916929 103.8642117
#
# The Joyden Hall, Bugis+, 201 Victoria Street, #07-01, Singapore 188067
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.299966 103.85528918697341
#
# Bistro@DUO Galleria, 7 Fraser Street, #01-25/26, Singapore 189356
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3007562 103.8578065
#
# Marina Barrage
# Lat and Lon info:
# 1.2814033 103.87257361571164
#
# Universal Studios Singapore, Resorts World Sentosa, 8 Sentosa Gateway, Singapore 098269
# Lat and Lon info:
# 1.25420095 103.82266700104616
#
# nan
# Using the subsequent information to try
#
# 5 Emerald Hill Road, Singapore 229289
# Lat and Lon info:
# 1.3055189 103.8394459
#
# Fort Canning Green, Fort Canning Park
# Lat and Lon info:
# 1.2953885 103.8474312
#
# Junction 8
# Lat and Lon info:
# 1.3505893 103.84874474726443
#
# Raffles City Singapore
# Lat and Lon info:
# 1.2933767 103.8532134
#
# The Star Vista
# Lat and Lon info:
# 1.3080015 103.7883825
#
# Heartbeat@Bedok
# Lat and Lon info:
# 1.3268695 103.93207417137295
#
# 313 Orchard Rd, Singapore 238895
# Lat and Lon info:
# 1.3006387 103.8383836
#
# Singapore Expo Hall 6A, 1 Expo Drive, Singapore 486150
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.334308 103.959258
#
# nan
# Using the subsequent information to try
#
# 1 Raffles Boulevard, Suntec City Convention Centre Hall 401 & 402, Singapore 039593
# Lat and Lon info:
# 1.2931797 103.8578355
#
# 137 Cecil Street, Hengda Building, #02-02, Singapore 069537
# Lat and Lon info:
# 1.2817092 103.8495479
#
# 137 Cecil Street, Hengda Building, #02-02, Singapore 069537
# Lat and Lon info:
# 1.2817092 103.8495479
#
# SAFRA Mount Faber & Yishun
# Using the subsequent information to try
#
# SAFRA Toa Payoh & Jurong
# Using the subsequent information to try
#
# SAFRA Tampines
# Lat and Lon info:
# 1.34477595 103.94205961614855
#
# Resorts World Sentosa
# Lat and Lon info:
# 1.25574585 103.82123439403357
#
# 435 Orchard Road, Wisma Atria Outdoor Atrium, Level 2, Singapore 238877
# Lat and Lon info:
# 1.30369665 103.83328756379004
#
# *SCAPE Underground Orchard, 2 Orchard Link, Singapore 237978
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3010848 103.8352023
#
# Singapore Expo Hall 6A
# Using the subsequent information to try
#
# Artscience Museum at Marina Bay Sands, 6 Bayfront Ave, Singapore 018974
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2861382 103.8592297
#
# Core Collective Dempsey, 27A, 30B/C Loewen Road, Singapore 248839
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.3616114000000001 103.76497444333444
#
# nan
# Using the subsequent information to try
#
# Kallang Wave Mall, 1 Stadium Place, Singapore 397628
# Lat and Lon info:
# 1.3035502 103.8727810707062
#
# Suntec Convention Centre
# Lat and Lon info:
# 1.2931797 103.8578355
#
# Singapore Maritime Gallery (Marina South Pier)
# Using the subsequent information to try
#
# SAFRA Toa Payoh
# Lat and Lon info:
# 1.3308349 103.8546267
#
# Various locations
# Using the subsequent information to try
#
# AMK Hub, 53 Ang Mo Kio Avenue 3, Singapore 569933
# Lat and Lon info:
# 1.36943465 103.84833397934707
#
# Jurong Point, Jurong West Central 2, Singapore 648886
# Lat and Lon info:
# 1.3394963500000001 103.70525400783333
#
# City Square Mall - 180 Kitchener Rd, Singapore 208539
# Lat and Lon info:
# 1.3113537 103.85657122520385
#
# 133 New Bridge Road, Singapore 059413
# Lat and Lon info:
# 1.2855811 103.8451805
#
# Jewel Changi Airport
# Lat and Lon info:
# 1.36022425 103.98967490995528
#
# Singapore Turf Club (The Grounds@Kranji), 1 Turf Club Ave, Singapore 738078
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.4232954 103.7572684
#
# Singapore Turf Club (The Grounds@Kranji), 1 Turf Club Ave, Singapore 738078
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.4232954 103.7572684
#
# Sentosa Cove, Quayside Isle, 31 Ocean Way Singapore 098375
# Lat and Lon info:
# 1.2481118 103.8406065
#
# River Safari, 80 Mandai Lake Road, Singapore 729826
# Lat and Lon info:
# 1.4020188500000001 103.7916047754835
#
# Private Dining Room, Faber Peak
# Using the subsequent information to try
#
# Lat and Lon info:
# 1.2712059 103.81941409273557
#
# nan
# Using the subsequent information to try
#
# 435 Orchard Road, #02-14/15 Wisma Atria, Singapore 238877
# Lat and Lon info:
# 1.30369665 103.83328756379004
#
# Chinatown
# Lat and Lon info:
# 1.2829435 103.8441517
#
# *SCAPE, Shaw House and the Grange Road Car Park
# Lat and Lon info:
# 1.30105065 103.83588278154376
#
# Singapore Expo Hall 4A
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# 68 Orchard Rd, Singapore 238839
# Lat and Lon info:
# 1.3004414 103.84490279418733
#
# Sands Theatre, Marina Bay Sands, 10 Bayfront Avenue, Singapore 018956
# Lat and Lon info:
# 1.2848963 103.8606918
#
# 1 Expo Drive, Expo Halls 5 and 6, Singapore 486150
# Lat and Lon info:
# 1.334308 103.959258
#
# nan
# Using the subsequent information to try
#
# Vivocity
# Lat and Lon info:
# 1.26437065 103.82295373341057
#
# Armenian Street
# Lat and Lon info:
# 1.2937997 103.8491524
#
# VivoCity Singapore
# Lat and Lon info:
# 1.26437065 103.82295373341057
#
# F1 Pit Building, 1 Republic Boulevard, Singapore 038975 and The Float @ Marina Bay, 20 Raffles Avenue, Singapore 039805
# Lat and Lon info:
# 1.29190455 103.86386217542162
#
# 8-12 Kallang Avenue, Singapore 339509
# Lat and Lon info:
# 1.3117827 103.8680511
#
# 313@somerset
# Lat and Lon info:
# 1.3010128 103.83853994515806
#
# 10 Eunos Road 8, Singapore 408600
# Lat and Lon info:
# 1.3185877 103.8938575
#
# nan
# Using the subsequent information to try
#
# Marina at Keppel Bay, 2 Keppel Bay Vista, Singapore 098382
# Lat and Lon info:
# 1.2652116 103.81267904412528
#
# #02-13, Funan, 107 North Bridge Rd, Singapore 179105
# Lat and Lon info:
# 1.37291055 103.9678683546593
#
# nan
# Using the subsequent information to try
#
# Bayfront Event Space
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# nan
# Using the subsequent information to try
#
# The Float @ Marina Bay, 20 Raffles Ave, Singapore 039805
# Lat and Lon info:
# 1.2895748 103.8590508
#
# Capitol Singapore
# Lat and Lon info:
# 1.2930198 103.85098111219958

# %%
# Check nearest NSEW
def calc_distance(lat_loc: float, lon_loc:float, nsew_coord_dict: dict, stn_geo_mapping_dict: dict):
    region = "All"
    dist = None
    # Calculate distance when lat/lon is not nan
    if not math.isnan(lat_loc) and not math.isnan(lon_loc):
        #print(lat_loc, lon_loc)
        #event_coordinates
        event_coord = (lat_loc, lon_loc)

        dist = math.inf
        for k,v in nsew_coord_dict.items():
            nsew_coord = (v[0], v[1])
            new_dist = geodesic(event_coord, nsew_coord).km
            # Make necessary update and continue
            if new_dist < dist:
                dist = new_dist
                # Find the region using stn_geo_mapping_dict
                region = stn_geo_mapping_dict[k]
        #print(f"Nearest region: {region} and distance in km: {dist}")
    return {"Location": region, "Distance": dist}

def split_date_format(date_string):
    # Remove any spaces before and after the string
    date_string = str(date_string)
    date_string = date_string.strip()
    # Presence of date range with hyphens
    if date_string == "-":
        start, end = None, None
    elif "-" in date_string and len(date_string) > 1 :
        start, end = date_string.split("-", 1)
        # Strip excess spaces
        start = str(start).strip()
        end = str(end).strip()

        # Convert to datetime and extract month and year for filling start
        expected_format = "%d %b %Y"
        end = pd.to_datetime(end, format=expected_format)
        end_mth = end.strftime("%b")
        print(end_mth)
        end_year = str(end.year)

        # Convert back to typical format
        end = end.strftime(expected_format)
        if start.count(" ") == 0:
            start = " ".join([start, end_mth, end_year])
        if start.count(" ") == 1:
            start = " ".join([start, end_year])
        
    # Single date case where start is the same as end
    else:
        start, end = date_string, date_string
    return start, end

# %%
# Direct location mapping 
df[["Location", "Distance"]] = df.apply(lambda row: calc_distance(
        lat_loc=row["Lat"],
        lon_loc=row["Lon"],
        nsew_coord_dict=nsew_dict,
        stn_geo_mapping_dict=stn_geo_dict
    ),
    axis="columns",
    result_type="expand"
)

# %%
df.head()
# Out:
#                                      Event Title                  Date  \
# 0  West Mall BT21-Themed CNY Activities & Promos  05 Jan - 24 Feb 2024
# 1              Comma Creative Arts Festival 2024      12 - 28 Jan 2024
# 2                            Light To Night 2024  19 Jan - 08 Feb 2024
# 3      Creative Intersections: Traces Of Dragons  19 Jan - 25 Feb 2024
# 4                             Artbox Avenue 2024  26 Jan - 04 Feb 2024
#
#   Location Status                                                URL  \
# 0     West  ENDED  https://thesmartlocal.com/read/west-mall-bt21-...
# 1    South  ENDED  https://thesmartlocal.com/read/comma-creative-...
# 2    South  ENDED  https://thesmartlocal.com/read/light-to-night-...
# 3    South  ENDED  https://thesmartlocal.com/read/singapore-art-w...
# 4     East  ENDED  https://thesmartlocal.com/read/artbox-avenue-2...
#
#          Date_of_check       Lat         Lon  Distance
# 0  31/03/2024 14:13:10  1.350077  103.749257  2.100992
# 1  31/03/2024 14:13:10  1.301085  103.835202  2.339933
# 2  31/03/2024 14:13:10  1.291735  103.851130  1.763689
# 3  31/03/2024 14:13:10  1.291313  103.849947  1.638695
# 4  31/03/2024 14:13:10  1.337152  103.959927  2.548565

# %% [markdown]
# Quick view of date information extracted.

# %%
# Quick view of date formats
df["Date"].value_counts()
# Out:
# Date
# 13 - 14 Jul 2019             3
# 17 Nov 2023 - 01 Jan 2024    3
# 29 Nov - 01 Dec 2019         3
# 28 Sep 2019                  3
# -                            3
#                             ..
# 23 - 24 Jul 2022             1
# 16 Jul 2022                  1
# 12 - 19 Jul 2022             1
# 05 Jul - 14 Aug 2022         1
# 05 - 31 Mar 2021             1
# Name: count, Length: 341, dtype: int64

# %% [markdown]
# ## Process date and break into start and end dates
# Date format can be in:
# - 05 Jan- 24 Feb 2024 (missing start year)
# - 12 - 28 Jan 2024 (missing start mth and year)
#
# To standardise, we will use month and year information from the end date to update the start date whereeither its month and year are information, on the assumption that they are omitted for simplicity in representation

# %%
# Split period to start/end dates
df[["Date_start", "Date_end"]] = df.apply(lambda row: split_date_format(row["Date"]), axis="columns", result_type="expand")

df.head()
# Out:
# Feb
# Jan
# Feb
# Feb
# Feb
# Mar
# Apr
# Apr
# Mar
# Apr
# Jun
# Mar
# Apr
# Jan
# Jan
# Jan
# Apr
# Jan
# Jan
# Mar
# Apr
# Apr
# Feb
# Feb
# Mar
# Mar
# Apr
# Apr
# Apr
# May
# Apr
# Apr
# Sep
# Jun
# Jul
# Jun
# Jul
# Oct
# Jul
# Jul
# Aug
# Aug
# Aug
# Sep
# Aug
# Oct
# Oct
# Oct
# Sep
# Oct
# Sep
# Sep
# Nov
# Dec
# Oct
# Oct
# Nov
# Oct
# Oct
# Nov
# Nov
# Dec
# Jan
# Jan
# Jan
# Dec
# Dec
# Nov
# Nov
# Dec
# Jan
# Jan
# Dec
# Jan
# Feb
# Jan
# Feb
# Feb
# Jan
# Feb
# Feb
# Jul
# May
# Jul
# May
# Apr
# Jun
# May
# Apr
# Apr
# May
# Jul
# Jun
# Jun
# Jun
# Jun
# Jun
# Jun
# Oct
# Jul
# Sep
# Aug
# Jul
# Jul
# Jul
# Jul
# Jan
# Oct
# Jul
# Aug
# Jul
# Sep
# Aug
# Aug
# Sep
# Sep
# Sep
# Aug
# Sep
# Sep
# Feb
# Sep
# Jan
# Oct
# Oct
# Oct
# Oct
# Oct
# Oct
# Nov
# Nov
# Oct
# Mar
# Nov
# Feb
# Apr
# Nov
# Nov
# Feb
# Dec
# Nov
# Dec
# Mar
# Jan
# Jan
# Dec
# Dec
# Dec
# Dec
# Feb
# Mar
# Jan
# Jan
# Mar
# Feb
# Mar
# Mar
# Mar
# Mar
# Mar
# Aug
# Jun
# Jan
# Sep
# Dec
# Nov
# Sep
# Mar
# Dec
# Dec
# Mar
# Dec
# Dec
# Jan
# Jan
# Dec
# Dec
# Jan
# Mar
# Jan
# Jan
# Jan
# Jan
# Jan
# Jan
# Jan
# Jan
# Mar
# May
# Mar
# Mar
# Mar
# Mar
# Dec
# Jun
# Aug
# Aug
# Sep
# Oct
# Oct
# Dec
# Nov
# Nov
# Dec
# Dec
# Dec
# Nov
# Nov
# Dec
# Dec
# Jan
# Dec
# Jan
# Aug
# Jun
# Jun
# Jul
# Feb
# Jul
# Jun
# Jun
# Aug
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Jul
# Aug
# Jul
# Aug
# Jul
# Aug
# Aug
# Aug
# Aug
# Aug
# Aug
# Aug
# Aug
# Aug
# Sep
# Sep
# Aug
# Aug
# Sep
# Aug
# Sep
# Sep
# Sep
# Sep
# Sep
# Sep
# Sep
# Sep
# Oct
# Oct
# Oct
# Oct
# Nov
# Oct
# Oct
# Oct
# Oct
# Oct
# Oct
# Oct
# Dec
# Nov
# Mar
# Nov
# Nov
# Dec
# Nov
# Nov
# Nov
# Nov
# Dec
# Dec
# Dec
# Dec
# Nov
# Nov
# Nov
# Dec
# Dec
# Nov
# Jan
# Nov
# Nov
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Dec
# Jan
# Dec
# Dec
# Jan
# Jan
#                                      Event Title                  Date  \
# 0  West Mall BT21-Themed CNY Activities & Promos  05 Jan - 24 Feb 2024
# 1              Comma Creative Arts Festival 2024      12 - 28 Jan 2024
# 2                            Light To Night 2024  19 Jan - 08 Feb 2024
# 3      Creative Intersections: Traces Of Dragons  19 Jan - 25 Feb 2024
# 4                             Artbox Avenue 2024  26 Jan - 04 Feb 2024
#
#   Location Status                                                URL  \
# 0     West  ENDED  https://thesmartlocal.com/read/west-mall-bt21-...
# 1    South  ENDED  https://thesmartlocal.com/read/comma-creative-...
# 2    South  ENDED  https://thesmartlocal.com/read/light-to-night-...
# 3    South  ENDED  https://thesmartlocal.com/read/singapore-art-w...
# 4     East  ENDED  https://thesmartlocal.com/read/artbox-avenue-2...
#
#          Date_of_check       Lat         Lon  Distance   Date_start  \
# 0  31/03/2024 14:13:10  1.350077  103.749257  2.100992  05 Jan 2024
# 1  31/03/2024 14:13:10  1.301085  103.835202  2.339933  12 Jan 2024
# 2  31/03/2024 14:13:10  1.291735  103.851130  1.763689  19 Jan 2024
# 3  31/03/2024 14:13:10  1.291313  103.849947  1.638695  19 Jan 2024
# 4  31/03/2024 14:13:10  1.337152  103.959927  2.548565  26 Jan 2024
#
#       Date_end
# 0  24 Feb 2024
# 1  28 Jan 2024
# 2  08 Feb 2024
# 3  25 Feb 2024
# 4  04 Feb 2024

# %%
print(df.shape)
# Drop null first
df = df[~df["Date_start"].isnull()]
print(df.shape)
# Drop date
df.drop(columns="Date", axis=1 ,inplace=True)
# Out:
# (366, 11)
# (363, 11)

# %%
# Convert to datetime
df["Date_start"] = pd.to_datetime(df["Date_start"], format="%d %b %Y")
df["Date_end"] = pd.to_datetime(df["Date_end"], format="%d %b %Y")

# %%
# Explode the dates
df["Date"] = df.apply(
    lambda x: pd.date_range(start=x["Date_start"], end=x["Date_end"]), axis=1
)
df = df.explode("Date")

# %%
column_of_interest = ["Date", "Location"]
for location in df["Location"].unique():
    print(location)
    df_location = df[df["Location"] == location][column_of_interest]

    # Drop duplicates
    df.drop_duplicates(inplace=True, keep="first")
    if location:
        filename = f"{location}_event_latlon.csv"
    else:
        filename = "nsew_latlon.csv"
    df_location.to_csv(filename, index=False)
# Out:
# West
# South
# East
# All
# North

# %% [markdown]
# # The following codes are more for filling those unknown locations

# %%
# Define chrome options
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:137, in SeleniumManager.run(args)
#     136 if sys.platform == "win32":
# --> 137     completed_proc = subprocess.run(args, capture_output=True, creationflags=subprocess.CREATE_NO_WINDOW)
#     138 else:
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1023             self.stderr = io.TextIOWrapper(self.stderr,
#    1024                     encoding=encoding, errors=errors)
# -> 1026     self._execute_child(args, executable, preexec_fn, close_fds,
#    1027                         pass_fds, cwd, env,
#    1028                         startupinfo, creationflags, shell,
#    1029                         p2cread, p2cwrite,
#    1030                         c2pread, c2pwrite,
#    1031                         errread, errwrite,
#    1032                         restore_signals,
#    1033                         gid, gids, uid, umask,
#    1034                         start_new_session, process_group)
#    1035 except:
#    1036     # Cleanup if the child failed starting.
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\subprocess.py:1538, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1537 try:
# -> 1538     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1539                              # no special security
#    1540                              None, None,
#    1541                              int(not close_fds),
#    1542                              creationflags,
#    1543                              env,
#    1544                              cwd,
#    1545                              startupinfo)
#    1546 finally:
#    1547     # Child is launched. Close the parent's copy of those pipe
#    1548     # handles that only the child should have open.  You need
#    (...)
#    1551     # pipe will not close when the child process exits and the
#    1552     # ReadFile will hang.
#
# OSError: [WinError 87] The parameter is incorrect
#
# The above exception was the direct cause of the following exception:
#
# WebDriverException                        Traceback (most recent call last)
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\driver_finder.py:38, in DriverFinder.get_path(service, options)
#      37 try:
# ---> 38     path = SeleniumManager().driver_location(options) if path is None else path
#      39 except Exception as err:
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:106, in SeleniumManager.driver_location(self, options)
#     104     args.append(value)
# --> 106 output = self.run(args)
#     108 browser_path = output["browser_path"]
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\selenium_manager.py:145, in SeleniumManager.run(args)
#     144 except Exception as err:
# --> 145     raise WebDriverException(f"Unsuccessful command executed: {command}") from err
#     147 for item in output["logs"]:
#
# WebDriverException: Message: Unsuccessful command executed: c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\windows\selenium-manager.exe --browser chrome --language-binding python --output json
#
#
# The above exception was the direct cause of the following exception:
#
# NoSuchDriverException                     Traceback (most recent call last)
# Cell In[18], line 5
#       3 chrome_options.add_argument('--no-sandbox')
#       4 chrome_options.add_argument('--disable-dev-shm-usage')
# ----> 5 driver = webdriver.Chrome(options=chrome_options)
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\chromium\webdriver.py:49, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      37 """Creates a new WebDriver instance of the ChromiumDriver. Starts the
#      38 service and then creates new WebDriver instance of ChromiumDriver.
#      39
#    (...)
#      45  - keep_alive - Whether to configure ChromiumRemoteConnection to use HTTP keep-alive.
#      46 """
#      47 self.service = service
# ---> 49 self.service.path = DriverFinder.get_path(self.service, options)
#      50 self.service.start()
#      52 executor = ChromiumRemoteConnection(
#      53     remote_server_addr=self.service.service_url,
#      54     browser_name=browser_name,
#    (...)
#      57     ignore_proxy=options._ignore_local_proxy,
#      58 )
#
# File c:\Users\ZhiQiangQUEK\.conda\envs\pdw\Lib\site-packages\selenium\webdriver\common\driver_finder.py:41, in DriverFinder.get_path(service, options)
#      39 except Exception as err:
#      40     msg = f"Unable to obtain driver for {options.capabilities['browserName']} using Selenium Manager."
# ---> 41     raise NoSuchDriverException(msg) from err
#      43 if path is None or not Path(path).is_file():
#      44     raise NoSuchDriverException(f"Unable to locate or obtain driver for {options.capabilities['browserName']}")
#
# NoSuchDriverException: Message: Unable to obtain driver for chrome using Selenium Manager.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors/driver_location

# %% [markdown]
# As we access the actual pages, we expect some pages to have missing venue information under "Event information" (although this is primary point of information where location name can be pulled). Otherwise we seek for the text with venue or address as a fallback.

# %%
for location in missing_location_entries_df["URL"].unique():
    URL = location
    driver.get(URL)
    # venue XPATH
    venue_xpath= '//h5[@class="wfnb-venue"]'

# %%
def find_venue_info_xpath(xpath:str) -> str:
    try:
        val = driver.find_element(by=By.XPATH, value=xpath).text
    except NoSuchElementException:
        print("Unable to find info, returning none")
        val = None
    
    return val

# %%
# Process those entries which have missing location info
URL = "https://thesmartlocal.com/event-calendar/?a=alltime"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
driver.get(URL)

xpath_list = [
    '//h5[@class="wfnb-venue"]',
    '//b[contains(text(),"Venue:")]/../following-sibling::span',
    '//b[contains(text(),"Venue:")]/..' #Case when there is no sibling span
]
# venue default XPATH
venue_xpath= '//h5[@class="wfnb-venue"]'

venue = find_venue_info_xpath(xpath=venue_xpath)

# Second approach
if not venue:
    venue_xpath = '//b[contains(text(),"Venue:")]/../following-sibling::span'
    venue = find_venue_info_xpath(xpath=venue_xpath)


# Webpage wait for required xpath to load
WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, venue_xpath)))

# %% [markdown]
# Map out lat lon using defined function

# %%
df[["Lat","Lon"]] = df["Location"]

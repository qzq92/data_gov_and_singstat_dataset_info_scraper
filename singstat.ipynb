# %% [markdown]
# # Singstat and Data.gov.sg Information crawler.
# This notebook is used for pulling and consolidating datasets found in both sites

# %% [markdown]
# ## Install dependencies for pulling data sources information
#
# ### Notes: BeautifulSoup can only handle static website content scraping. Selenium library is required together with beautifulsoup to read all dynamically loaded content which is the case for singstat and data.gov.sg.

# %%
#!pip install requests selenium

# %% [markdown]
# Library imports

# %%
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium import webdriver 
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException,StaleElementReferenceException,TimeoutException, ElementClickInterceptedException
from datetime import datetime
from typing import NewType
import time
import pandas as pd
# Define options for webdriver
chrome_options = Options()

# %% [markdown]
# Try to click Data.gov.sg and pull data information
# Attempt to load as much information as possible before one shot scraping. TO avoid issues, please do not minimize the page when executing

# %%
# Helper function
def load_all_data(dataset_on_display: list,
                  total_results: int,
                  load_more_button: object,
                  datasets_div_xpath:str,
                  load_more_xpath:str,
                  driver: NewType):
    while len(dataset_on_display) < total_results and load_more_button:
        print("Loading more data")
        # Count displayed dataset

        dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
        try:
            WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, 
            load_more_xpath)))
        except TimeoutException:
            print("No load more button available after waiting. Assuming the end of page")


        try:
            load_more_button = driver.find_element(by=By.XPATH, value=load_more_xpath)
            print(f"Current display data: {len(dataset_on_display)}/{total_results}")
            load_more_button.click()
        except NoSuchElementException:
            print("Unable to click load more button due to no such element")
        except ElementClickInterceptedException:
            print("Encountered interference with clicking...")

# %%
URL = "https://beta.data.gov.sg/datasets?sort=Last%20updated"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
driver.get(URL)

# XPATH
load_more_xpath = "//button[contains(@class, 'chakra-button') and text()='Load more']"
results_xpath = "//div[@class='css-no1clx']/p[contains(@class, 'chakra-text')][2]"
datasets_div_xpath = "//a[@class='chakra-link css-mfiv8d']"

# Webpage wait
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, load_more_xpath)))

# FInd elements
total_results = driver.find_element(by=By.XPATH, value=results_xpath)
if total_results:
    # Results value in the string format of xxx,xxx. Hence need to remove commas
    total_results_text = total_results.text
    total_results = total_results_text.replace(",","")
    total_results = int(total_results)
else:
    print("Cant extract any results information from page")
    exit()
load_more_button = driver.find_element(by=By.XPATH, value=load_more_xpath)
# Count displayed dataset
dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)

# CHeck current dataset display numbers
if load_more_button and total_results:
    print(f"Found load more button with {total_results} total results available")

# This function will force expansion of web page by clicking on load more button until there isnt any.
   
load_all_data(dataset_on_display=dataset_on_display,
              total_results=total_results,
              load_more_button=load_more_button,
              datasets_div_xpath=datasets_div_xpath,
              load_more_xpath=load_more_xpath,
              driver=driver)
# Out:
# Found load more button with 4832 total results available
# Loading more data
# Current display data: 20/4832
# Loading more data
# Current display data: 20/4832
# Loading more data
# Current display data: 40/4832
# Loading more data
# Current display data: 60/4832
# Loading more data
# Current display data: 80/4832
# Loading more data
# Current display data: 100/4832
# Loading more data
# Current display data: 120/4832
# Loading more data
# Current display data: 140/4832
# Loading more data
# Current display data: 160/4832
# Loading more data
# Current display data: 180/4832
# Loading more data
# Current display data: 200/4832
# Loading more data
# Current display data: 220/4832
# Loading more data
# Current display data: 240/4832
# Loading more data
# Current display data: 260/4832
# Loading more data
# Current display data: 280/4832
# Loading more data
# Current display data: 300/4832
# Loading more data
# Current display data: 320/4832
# Loading more data
# Current display data: 340/4832
# Loading more data
# Current display data: 360/4832
# Loading more data
# Current display data: 380/4832
# Loading more data
# Current display data: 400/4832
# Loading more data
# Current display data: 420/4832
# Loading more data
# Current display data: 440/4832
# Loading more data
# Current display data: 460/4832
# Loading more data
# Current display data: 480/4832
# Loading more data
# Current display data: 500/4832
# Loading more data
# Current display data: 520/4832
# Loading more data
# Current display data: 560/4832
# Loading more data
# Current display data: 580/4832
# Loading more data
# Current display data: 580/4832
# Loading more data
# Current display data: 600/4832
# Loading more data
# Current display data: 620/4832
# Loading more data
# Current display data: 660/4832
# Loading more data
# Current display data: 680/4832
# Loading more data
# Current display data: 680/4832
# Loading more data
# Current display data: 720/4832
# Loading more data
# Current display data: 720/4832
# Loading more data
# Current display data: 760/4832
# Loading more data
# Current display data: 780/4832
# Loading more data
# Current display data: 800/4832
# Loading more data
# Current display data: 820/4832
# Loading more data
# Current display data: 840/4832
# Loading more data
# Current display data: 860/4832
# Loading more data
# Current display data: 880/4832
# Loading more data
# Current display data: 900/4832
# Loading more data
# Current display data: 920/4832
# Loading more data
# Current display data: 940/4832
# Loading more data
# Current display data: 960/4832
# Loading more data
# Current display data: 980/4832
# Loading more data
# Current display data: 1000/4832
# Loading more data
# Current display data: 1020/4832
# Loading more data
# Current display data: 1040/4832
# Loading more data
# Current display data: 1060/4832
# Loading more data
# Current display data: 1080/4832
# Loading more data
# Current display data: 1100/4832
# Loading more data
# Current display data: 1120/4832
# Loading more data
# Current display data: 1140/4832
# Loading more data
# Current display data: 1160/4832
# Loading more data
# Current display data: 1180/4832
# Loading more data
# Current display data: 1200/4832
# Loading more data
# Current display data: 1220/4832
# Loading more data
# Current display data: 1240/4832
# Loading more data
# Current display data: 1260/4832
# Loading more data
# Current display data: 1280/4832
# Loading more data
# Current display data: 1300/4832
# Loading more data
# Current display data: 1320/4832
# Loading more data
# Current display data: 1340/4832
# Loading more data
# Current display data: 1360/4832
# Loading more data
# Current display data: 1380/4832
# Loading more data
# Current display data: 1400/4832
# Loading more data
# Current display data: 1420/4832
# Loading more data
# Current display data: 1440/4832
# Loading more data
# Current display data: 1460/4832
# Loading more data
# Current display data: 1480/4832
# Loading more data
# Current display data: 1500/4832
# Loading more data
# Current display data: 1520/4832
# Loading more data
# Current display data: 1540/4832
# Loading more data
# Current display data: 1560/4832
# Loading more data
# Current display data: 1580/4832
# Loading more data
# Current display data: 1600/4832
# Loading more data
# Current display data: 1620/4832
# Loading more data
# Current display data: 1640/4832
# Loading more data
# Current display data: 1660/4832
# Loading more data
# Current display data: 1680/4832
# Loading more data
# Current display data: 1700/4832
# Loading more data
# Current display data: 1720/4832
# Loading more data
# Current display data: 1740/4832
# Loading more data
# Current display data: 1760/4832
# Loading more data
# Current display data: 1780/4832
# Loading more data
# Current display data: 1800/4832
# Loading more data
# Current display data: 1820/4832
# Loading more data
# Current display data: 1840/4832
# Loading more data
# Current display data: 1860/4832
# Loading more data
# Current display data: 1880/4832
# Loading more data
# Current display data: 1900/4832
# Loading more data
# Current display data: 1920/4832
# Loading more data
# Current display data: 1940/4832
# Loading more data
# Current display data: 1960/4832
# Loading more data
# Current display data: 1980/4832
# Loading more data
# Current display data: 2000/4832
# Loading more data
# Current display data: 2020/4832
# Loading more data
# Current display data: 2040/4832
# Loading more data
# Current display data: 2060/4832
# Loading more data
# Current display data: 2080/4832
# Loading more data
# Current display data: 2100/4832
# Loading more data
# Current display data: 2120/4832
# Loading more data
# Current display data: 2140/4832
# Loading more data
# Current display data: 2160/4832
# Loading more data
# Current display data: 2180/4832
# Loading more data
# Current display data: 2200/4832
# Loading more data
# Current display data: 2220/4832
# Loading more data
# Current display data: 2240/4832
# Loading more data
# Current display data: 2260/4832
# Loading more data
# Current display data: 2280/4832
# Loading more data
# Current display data: 2300/4832
# Loading more data
# Current display data: 2320/4832
# Loading more data
# Current display data: 2340/4832
# Loading more data
# Current display data: 2360/4832
# Loading more data
# Current display data: 2380/4832
# Loading more data
# Current display data: 2400/4832
# Loading more data
# Current display data: 2420/4832
# Loading more data
# Current display data: 2440/4832
# Loading more data
# Current display data: 2460/4832
# Loading more data
# Current display data: 2480/4832
# Loading more data
# Current display data: 2500/4832
# Loading more data
# Current display data: 2520/4832
# Loading more data
# Current display data: 2540/4832
# Loading more data
# Current display data: 2560/4832
# Loading more data
# Current display data: 2580/4832
# Loading more data
# Current display data: 2600/4832
# Loading more data
# Current display data: 2620/4832
# Loading more data
# Current display data: 2640/4832
# Loading more data
# Current display data: 2660/4832
# Loading more data
# Current display data: 2680/4832
# Loading more data
# Current display data: 2700/4832
# Loading more data
# Current display data: 2720/4832
# Loading more data
# Current display data: 2740/4832
# Loading more data
# Current display data: 2760/4832
# Loading more data
# Current display data: 2780/4832
# Loading more data
# Current display data: 2800/4832
# Loading more data
# Current display data: 2820/4832
# Loading more data
# Current display data: 2840/4832
# Loading more data
# Current display data: 2860/4832
# Loading more data
# Current display data: 2880/4832
# Loading more data
# Current display data: 2900/4832
# Loading more data
# Current display data: 2920/4832
# Loading more data
# Current display data: 2940/4832
# Loading more data
# Current display data: 2960/4832
# Loading more data
# Current display data: 2980/4832
# Loading more data
# Current display data: 3000/4832
# Loading more data
# Current display data: 3020/4832
# Loading more data
# Current display data: 3040/4832
# Loading more data
# Current display data: 3060/4832
# Loading more data
# Current display data: 3080/4832
# Loading more data
# Current display data: 3100/4832
# Loading more data
# Current display data: 3120/4832
# Loading more data
# Current display data: 3140/4832
# Loading more data
# Current display data: 3160/4832
# Loading more data
# Current display data: 3180/4832
# Loading more data
# Current display data: 3200/4832
# Loading more data
# Current display data: 3220/4832
# Loading more data
# Current display data: 3240/4832
# Loading more data
# Current display data: 3260/4832
# Loading more data
# Current display data: 3280/4832
# Loading more data
# Current display data: 3300/4832
# Loading more data
# Current display data: 3320/4832
# Loading more data
# Current display data: 3340/4832
# Loading more data
# Current display data: 3360/4832
# Loading more data
# Current display data: 3380/4832
# Loading more data
# Current display data: 3400/4832
# Loading more data
# Current display data: 3420/4832
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[45], line 23, in load_all_data(dataset_on_display, total_results, load_more_button, datasets_div_xpath, load_more_xpath, driver)
#      22     print(f"Current display data: {len(dataset_on_display)}/{total_results}")
# ---> 23     load_more_button.click()
#      24 except NoSuchElementException:
#
# File c:\Users\quekz\anaconda3\envs\public_data_env\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      93 """Clicks the element."""
# ---> 94 self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\quekz\anaconda3\envs\public_data_env\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\quekz\anaconda3\envs\public_data_env\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\quekz\anaconda3\envs\public_data_env\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: element click intercepted: Element <button type="button" class="chakra-button css-1aoqvq6">...</button> is not clickable at point (465, 853). Other element would receive the click: <div class="css-gz1jaj">...</div>
#   (Session info: chrome=122.0.6261.129)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF686B5AD02+56930]
# 	(No symbol) [0x00007FF686ACF602]
# 	(No symbol) [0x00007FF6869842E5]
# 	(No symbol) [0x00007FF6869D0A80]
# 	(No symbol) [0x00007FF6869CE8AB]
# 	(No symbol) [0x00007FF6869CC0B4]
# 	(No symbol) [0x00007FF6869CAE45]
# 	(No symbol) [0x00007FF6869BF798]
# 	(No symbol) [0x00007FF6869EBC9A]
# 	(No symbol) [0x00007FF6869BF09A]
# 	(No symbol) [0x00007FF6869EBEB0]
# 	(No symbol) [0x00007FF686A081E2]
# 	(No symbol) [0x00007FF6869EBA43]
# 	(No symbol) [0x00007FF6869BD438]
# 	(No symbol) [0x00007FF6869BE4D1]
# 	GetHandleVerifier [0x00007FF686ED6F8D+3711213]
# 	GetHandleVerifier [0x00007FF686F304CD+4077101]
# 	GetHandleVerifier [0x00007FF686F2865F+4044735]
# 	GetHandleVerifier [0x00007FF686BF9736+706710]
# 	(No symbol) [0x00007FF686ADB8DF]
# 	(No symbol) [0x00007FF686AD6AC4]
# 	(No symbol) [0x00007FF686AD6C1C]
# 	(No symbol) [0x00007FF686AC68D4]
# 	BaseThreadInitThunk [0x00007FFED895257D+29]
# 	RtlUserThreadStart [0x00007FFEDA4CAA58+40]
#
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 36
#      32     print(f"Found load more button with {total_results} total results available")
#      34 # This function will force expansion of web page by clicking on load more button until there isnt any.
# ---> 36 load_all_data(dataset_on_display=dataset_on_display,
#      37               total_results=total_results,
#      38               load_more_button=load_more_button,
#      39               datasets_div_xpath=datasets_div_xpath,
#      40               load_more_xpath=load_more_xpath,
#      41               driver=driver)
#
# Cell In[45], line 26, in load_all_data(dataset_on_display, total_results, load_more_button, datasets_div_xpath, load_more_xpath, driver)
#      24 except NoSuchElementException:
#      25     print("Unable to click load more button due to no such element")
# ---> 26 except ElementClickInterceptedException:
#      27     print("Encountered interference with clicking...")
#
# NameError: name 'ElementClickInterceptedException' is not defined

# %% [markdown]
# ## Do an overall count after load more has been exhausted

# %%
total_dataset_on_display = driver.find_elements(by=By.XPATH, value=datasets_div_xpath)
print(len(total_dataset_on_display))
# Out:
# 20

# %% [markdown]
# ## Extract metadata of dataset for storing purpose

# %%
# Expand the list
#Collection
collection_tracker_dict = {}

# Dataset 
dataset_tracker_dict= {}

get_dataset_name_xpath = ".//div/div/p"
get_metadata_info_xpath = ".//div/div/div[contains(@class, 'chakra-wrap')]/ul/p[contains(@class, 'chakra-text')]"
for dataset in total_dataset_on_display:
    try:
        href = dataset.get_attribute('href')
        print("Dataset link:")
        print(href)
    except AttributeError:
        print("No href info found.")
    
    try:
        name = dataset.find_element(by=By.XPATH, value=get_dataset_name_xpath)
        name = name.text
        print("Dataset name:")
        print(name) 
    except NoSuchElementException:
        print("No name information found")

    # Multiple metadata information
    metadata_list = dataset.find_elements(by=By.XPATH, value=get_metadata_info_xpath)
    # Filter alternate elements
    metadata_list = [metadata.text for i,metadata in enumerate(metadata_list) if i%2==0]
    print(metadata_list)

    # In the case where metadata list only has 3 elements (no date), include None as info to ensure ease of outputing all dataset info into csv file.
    if len(metadata_list) == 3:
        metadata_list.insert(0, "No Date info")
    #Insert href info
    metadata_list.append(href)

    # MEtadata construct influence whether we are dealing with collections or dataset
    if any(" dataset" in metadata for metadata in metadata_list):
        collection_tracker_dict[name] = metadata_list
    else:
        dataset_tracker_dict[name] = metadata_list
    print()   

driver.quit()
# Out:
# Dataset link:
# https://beta.data.gov.sg/datasets/d_c31c965da0c7c4bdc897eebb6747486a/view
# Dataset name:
# Notices under other Acts 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_2c7c87c899bf1264f34eba18890518e5/view
# Dataset name:
# Notices under the Constitution 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_edb599302d97748dc95ef4fe16fcecd5/view
# Dataset name:
# Death 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_830ca47f48adfac75b79dc7d0efd8744/view
# Dataset name:
# Leave 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_8f848100c27d6d4c534769130dbba7ff/view
# Dataset name:
# Supplements (Current Notices)
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e2de193f0888e615ec7b6b12f099db16/view
# Dataset name:
# Tenders 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_68ec1ad5ce7a99da51edf182fe0e12cf/view
# Dataset name:
# Bankruptcy Act Notices 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_3bc5e9401a77986ab974a95b197ff4bc/view
# Dataset name:
# Legislation Gazettes (Current Notices)
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_03f6016f32c83fecdf724ea536d8ecb7/view
# Dataset name:
# Appointments 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e845c87f3dfe3979022ba7ac5b3a9b10/view
# Dataset name:
# Cessation of Service 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_75a8ec0018721707ac67c8df6b570cb4/view
# Dataset name:
# Termination of Service 2023
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_e477350cc4eedf507d9b435e0b89e7ae/view
# Dataset name:
# Statutes 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_f1d530a536bc6985fea6a7ecacd8706b/view
# Dataset name:
# Revocation 2023
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_1a520c1ec747499dc1418b03f6e68b49/view
# Dataset name:
# Others 2023
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_60877dfe2dc76b197660c16c7d43cffa/view
# Dataset name:
# Termination of Service 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_a9e75af8a5c5166f253894f9d2ae1fa0/view
# Dataset name:
# Companies Act Notices 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_fec59dbfd4f1f6020212394aa45fb861/view
# Dataset name:
# Industrial Relations Supplement 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_66ce50ab169cf6e5db6c53561dbacb0f/view
# Dataset name:
# Vacation of Service 2023
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_4dc111478d0294c30e9cd071105a48cf/view
# Dataset name:
# Bankruptcy Act Notices 2023
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']
#
# Dataset link:
# https://beta.data.gov.sg/datasets/d_95daf2b05bda238dee921352130de047/view
# Dataset name:
# Trade Marks Supplement 2024
# ['Updated 13 minutes ago', 'CSV', 'Ministry of Communications and Information (MCI)']

# %%
print(len(dataset_tracker_dict), len(collection_tracker_dict))
# Out:
# 20 0

# %%
## Convert dataset dictionary to dataframe
if dataset_tracker_dict:
    df = pd.DataFrame.from_dict(dataset_tracker_dict, orient="index", columns=["Data period", "Last updated", "Datatype", "Source", "Dataset url"])

    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime_now().strfttme("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now
    df.index.name = "Datasets"
    df.head()

    dataset_filename = f"Datagovsg_dataset_{file_name_date}.csv"
    df.to_csv(dataset_filename,index=True)


## Convert collections dictioanry to dataframe
if collection_tracker_dict:
    df = pd.DataFrame.from_dict(dataset_tracker_dict, orient="index", columns=["Data period", "Number of datasets", "Datatype", "Source", "Collections url"])

    datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
    file_name_date = datetime_now().strfttme("%d%m%Y_%H%M%S")

    df["Date_of_check"] = datetime_now
    df.index.name = "Collections"
    df.head()

    dataset_filename = f"Datagovsg_collections_{file_name_date}.csv"
    df.to_csv(dataset_filename,index=True)

# %% [markdown]
# ## Handling SingStat tablebuilder as source

# %%
new_url="https://tablebuilder.singstat.gov.sg/"
chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
chrome_options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=chrome_options)
#maximize browser
driver.get(new_url)

# Wait popup
WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Maybe Later']"))).click()

# Wait removal of popup
WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[text()='Expand all']"))).click()

singstat_data_dict = {}

# Navigate through the body after expand all

# We have 6 headers
main_categories_xpath = "//span[contains(@class, 'irmCui')]"
main_categories = driver.find_elements(by=By.XPATH, value=main_categories_xpath)

print(f"Total sections: {len(main_categories)}")
for i, option in enumerate(main_categories):
    
    main_category = option.text
    print(f"Main category: {main_category}")

    sub_category_caret_xpath = f"//*[contains(text(), '{option.text}')]/../../../following-sibling::div/div"

    WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, sub_category_caret_xpath)))
    
    # Get the caret-right
    sub_categories_carets = option.find_elements(by=By.XPATH, value=sub_category_caret_xpath)

    print("Total sub categories:")
    print(len(sub_categories_carets))

    # Nested loop to extract subcategories
    for sub_categories_caret in sub_categories_carets:
        # Expand each subcategories
        sub_categories_caret.click()

        # Get the text of sub category
        text_div= ".//a/div/div[2]/div"
        sub_category_text_name = sub_categories_caret.find_element(by=By.XPATH, value=text_div).text

        # THere are nested sub categories
        sub_sub_category_caret_xpath =".//div[contains(@class, 'sgds-accordion-body is-open')]/div"

        # FInd number of such
        sub_sub_categories_list = sub_categories_caret.find_elements(by=By.XPATH, value=sub_sub_category_caret_xpath)
        print(f"Sub category: {sub_category_text_name} has {len(sub_sub_categories_list)} sub-sub categories")

        # Inner nested loop for sub-sub categories
        for sub_sub_cat in sub_sub_categories_list:
            sub_sub_cat.click()

            sub_sub_category_text_name = sub_sub_cat.find_element(by=By.XPATH, value = text_div).text

            sub_sub_category_file_xpath = ".//div/a"
            file_elements_list = sub_sub_cat.find_elements(by=By.XPATH, value=sub_sub_category_file_xpath)
            
            print(f"Sub-sub category: {sub_sub_category_text_name} has {len(file_elements_list)} dataset")
            # Processing or the anchor tags <a> to obtain href info and text

            if file_elements_list:
                for file in file_elements_list:
                    href = file.get_attribute('href')
                    text = file.text

                    dataset_hierarachy_str = main_category + ">" + sub_category_text_name + ">" + sub_sub_category_text_name + ">" + text

                    singstat_data_dict[dataset_hierarachy_str] = [href]
        print()
# Quit browser to free resources
driver.quit()
# Out:
# Total sections: 6
# Main category: Economy & Prices
# Total sub categories:
# 10
# Sub category: Balance of Payments (BOP) has 2 sub-sub categories
# Sub-sub category: Singapore's Balance of Payments (BOP) has 3 dataset
# Sub-sub category: Singapore's Inward Direct Investment Flows has 5 dataset
#
# Sub category: External Debt has 1 sub-sub categories
# Sub-sub category: Singapore's External Debt has 1 dataset
#
# Sub category: Household Sector Balance Sheet has 1 sub-sub categories
# Sub-sub category: Household Net Worth, Assets and Liabilities has 1 dataset
#
# Sub category: International Investment Position (IIP) has 3 sub-sub categories
# Sub-sub category: Singapore's International Investment Position (IIP) has 1 dataset
# Sub-sub category: Singapore's Portfolio Investment Assets has 1 dataset
# Sub-sub category: Singapore’s Portfolio Investment Liabilities has 1 dataset
#
# Sub category: Labour, Employment, Wages and Productivity has 12 sub-sub categories
# Sub-sub category: CPF Members and Employers has 4 dataset
# Sub-sub category: Employment has 16 dataset
# Sub-sub category: Job Vacancies has 1 dataset
# Sub-sub category: Labour Force has 11 dataset
# Sub-sub category: Labour Relations has 3 dataset
# Sub-sub category: Productivity has 7 dataset
# Sub-sub category: Recruitment and Resignation Rate has 2 dataset
# Sub-sub category: Redundancy has 3 dataset
# Sub-sub category: Training has 2 dataset
# Sub-sub category: Unemployment has 4 dataset
# Sub-sub category: Unit Labour Cost (ULC) has 1 dataset
# Sub-sub category: Wages and Income from Employment has 5 dataset
#
# Sub category: Leading Indicators has 1 sub-sub categories
# Sub-sub category: Composite Leading Index (CLI) has 1 dataset
#
# Sub category: National Accounts has 14 sub-sub categories
# Sub-sub category: Capital Stock has 6 dataset
# Sub-sub category: Compensation of Employees has 1 dataset
# Sub-sub category: Expenditure on Gross Domestic Product (GDP) has 4 dataset
# Sub-sub category: Government Consumption Expenditure has 1 dataset
# Sub-sub category: Gross Domestic Product (GDP) has 12 dataset
# Sub-sub category: Gross Fixed Capital Formation (GFCF) has 2 dataset
# Sub-sub category: Gross Operating Surplus has 1 dataset
# Sub-sub category: Gross Value Added (GVA) by Institutional Sector has 2 dataset
# Sub-sub category: Other Taxes Less Subsidies on Production has 1 dataset
# Sub-sub category: Output, Saving and Investment has 2 dataset
# Sub-sub category: Personal Disposable Income and Personal Saving has 1 dataset
# Sub-sub category: Private Consumption Expenditure has 2 dataset
# Sub-sub category: Supply, Use and Input-Output Tables (SUT and IOT) has 22 dataset
# Sub-sub category: Total Demand has 2 dataset
#
# Sub category: Prices and Price Indices has 6 sub-sub categories
# Sub-sub category: Construction Materials has 1 dataset
# Sub-sub category: Consumer Price Index (CPI)/ Inflation Rate has 11 dataset
# Sub-sub category: HDB Resale Flats has 1 dataset
# Sub-sub category: International Trade Price Indices (EPI and IPI) has 10 dataset
# Sub-sub category: Private Property has 9 dataset
# Sub-sub category: Producer Price Indices (DSPI, SMPPI and SPPI) has 13 dataset
#
# Sub category: Public Finance has 4 sub-sub categories
# Sub-sub category: Duty-Paid Releases has 2 dataset
# Sub-sub category: Government Debt has 3 dataset
# Sub-sub category: Government Revenue and Expenditure has 9 dataset
# Sub-sub category: Taxable Individuals and Companies has 3 dataset
#
# Sub category: Public Sector has 4 sub-sub categories
# Sub-sub category: Government Employees has 5 dataset
# Sub-sub category: Judiciary has 4 dataset
# Sub-sub category: Members of Parliament has 1 dataset
# Sub-sub category: Ministers has 1 dataset
#
# Main category: Industry
# Total sub categories:
# 15
# Sub category: Agriculture, Animal Production and Fisheries has 2 sub-sub categories
# Sub-sub category: Food Farms has 1 dataset
# Sub-sub category: Food Supply has 3 dataset
#
# Sub category: Building, Real Estate, Construction and Housing has 4 sub-sub categories
# Sub-sub category: Building and Construction has 4 dataset
# Sub-sub category: HDB Residential Units and Properties has 3 dataset
# Sub-sub category: Real Estate has 8 dataset
# Sub-sub category: Residential Dwellings has 1 dataset
#
# Sub category: Business Expectations has 2 sub-sub categories
# Sub-sub category: Manufacturing Sector has 2 dataset
# Sub-sub category: Services Sector has 6 dataset
#
# Sub category: Corporate Sector has 2 sub-sub categories
# Sub-sub category: Performance has 7 dataset
# Sub-sub category: Size and Composition has 5 dataset
#
# Sub category: Energy and Utilities has 5 sub-sub categories
# Sub-sub category: Electricity Generation, Consumption and Tariffs has 4 dataset
# Sub-sub category: Energy Products and Consumption has 5 dataset
# Sub-sub category: Gas Sales and Tariffs has 3 dataset
# Sub-sub category: Overall Utilities has 2 dataset
# Sub-sub category: Water Sales and Prices has 2 dataset
#
# Sub category: Enterprises has 1 sub-sub categories
# Sub-sub category: Enterprise Landscape has 3 dataset
#
# Sub category: Finance and Insurance has 12 sub-sub categories
# Sub-sub category: Bankruptcy and Liquidation has 2 dataset
# Sub-sub category: Business Loans has 1 dataset
# Sub-sub category: CPF Contributions and Withdrawals has 5 dataset
# Sub-sub category: Currency has 1 dataset
# Sub-sub category: Exchange Rates has 3 dataset
# Sub-sub category: Foreign Exchange Market has 1 dataset
# Sub-sub category: Insurance has 6 dataset
# Sub-sub category: Interest Rates has 1 dataset
# Sub-sub category: Money and Banking has 11 dataset
# Sub-sub category: Pawnshop has 1 dataset
# Sub-sub category: Reserves has 1 dataset
# Sub-sub category: Singapore Exchange has 4 dataset
#
# Sub category: Food Establishments has 1 sub-sub categories
# Sub-sub category: Licensed Food Establishments has 1 dataset
#
# Sub category: Formation and Cessation of Business Entities has 2 sub-sub categories
# Sub-sub category: Cessation of Business Entities has 2 dataset
# Sub-sub category: Formation of Business Entities has 2 dataset
#
# Sub category: InfoComm and Media has 2 sub-sub categories
# Sub-sub category: InfoComm has 18 dataset
# Sub-sub category: Media has 3 dataset
#
# Sub category: Manufacturing has 3 sub-sub categories
# Sub-sub category: Index Of Industrial Production (IIP) has 2 dataset
# Sub-sub category: Principal Manufacturing Statistics has 14 dataset
# Sub-sub category: Unit Business Cost (UBC) has 1 dataset
#
# Sub category: Research and Development (R&D) has 4 sub-sub categories
# Sub-sub category: Organisations Performing R&D has 1 dataset
# Sub-sub category: R&D Expenditure has 4 dataset
# Sub-sub category: R&D Manpower has 1 dataset
# Sub-sub category: Patents has 1 dataset
#
# Sub category: Services has 5 sub-sub categories
# Sub-sub category: Annual Services Statistics - All Services Industries has 5 dataset
# Sub-sub category: Business Receipts Index (BRI) has 1 dataset
# Sub-sub category: Food & Beverage Services Index (FSI) has 4 dataset
# Sub-sub category: Retail Sales Index (RSI) has 4 dataset
# Sub-sub category: Wholesale Trade Index (WTI) has 4 dataset
#
# Sub category: Tourism has 4 sub-sub categories
# Sub-sub category: Hotel Industry has 1 dataset
# Sub-sub category: International Visitor Arrivals (IVA) has 7 dataset
# Sub-sub category: Outbound Departures of Singapore Residents has 1 dataset
# Sub-sub category: Tourism Receipts has 1 dataset
#
# Sub category: Transport has 4 sub-sub categories
# Sub-sub category: Air Transport has 7 dataset
# Sub-sub category: Land Transport (including MRT and LRT) has 13 dataset
# Sub-sub category: Public Roads has 1 dataset
# Sub-sub category: Sea Transport has 5 dataset
#
# Main category: Trade & Investment
# Total sub categories:
# 7
# Sub category: Direct Investment Abroad (DIA) has 1 sub-sub categories
# Sub-sub category: Singapore's Direct Investment Abroad (DIA) and Direct Equity Investment Abroad has 7 dataset
#
# Sub category: Foreign Affiliates Statistics has 1 sub-sub categories
# Sub-sub category: Foreign Affiliates in Singapore has 2 dataset
#
# Sub category: Foreign Direct Investment (FDI) has 2 sub-sub categories
# Sub-sub category: Foreign Direct Investment (FDI) and Foreign Direct Equity Investment has 6 dataset
# Sub-sub category: Income of FDI and Return on FDI has 4 dataset
#
# Sub category: Investment Commitments has 1 sub-sub categories
# Sub-sub category: Fixed Assets Investments has 3 dataset
#
# Sub category: Merchandise Trade has 5 sub-sub categories
# Sub-sub category: Exports by Commodity Section/ Division has 8 dataset
# Sub-sub category: Exports by Market/ Region has 25 dataset
# Sub-sub category: Imports by Commodity Section/ Division has 4 dataset
# Sub-sub category: Imports by Market/ Region has 3 dataset
# Sub-sub category: International Merchandise Trade by Commodity Section/ Division has 2 dataset
#
# Sub category: Trade in Services (TIS) has 3 sub-sub categories
# Sub-sub category: International Trade in Services (TIS) has 2 dataset
# Sub-sub category: Export of Services has 2 dataset
# Sub-sub category: Import of Services has 2 dataset
#
# Sub category: Trading Partner has 1 sub-sub categories
# Sub-sub category: International Merchandise Trade has 3 dataset
#
# Main category: Population
# Total sub categories:
# 10
# Sub category: Population and Population Structure has 2 sub-sub categories
# Sub-sub category: Key Annual Indicators on Population has 6 dataset
# Sub-sub category: Census of Population and General Household Survey has 24 dataset
#
# Sub category: Geographic Distribution has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 7 dataset
#
# Sub category: Marital Status, Marriages and Divorces has 12 sub-sub categories
# Sub-sub category: Total Marriages has 11 dataset
# Sub-sub category: Citizen Marriages has 6 dataset
# Sub-sub category: Marriages under the Women's Charter has 24 dataset
# Sub-sub category: Marriages under the Administration of Muslim Law Act has 23 dataset
# Sub-sub category: Total Divorces has 4 dataset
# Sub-sub category: Divorces under the Women's Charter has 19 dataset
# Sub-sub category: Divorces under the Administration of Muslim Law Act has 19 dataset
# Sub-sub category: Annulments under the Women's Charter has 7 dataset
# Sub-sub category: Dissolution of Marriages Among Resident Marriage Cohorts has 1 dataset
# Sub-sub category: Marital Status has 2 dataset
# Sub-sub category: Proportion of Singles has 4 dataset
# Sub-sub category: Census of Population and General Household Survey has 4 dataset
#
# Sub category: Births and Fertility has 2 sub-sub categories
# Sub-sub category: Births, Crude Birth Rate (CBR), Total Fertility Rate (TFR) and Reproduction Rates has 10 dataset
# Sub-sub category: Census of Population and General Household Survey has 1 dataset
#
# Sub category: Death and Life Expectancy has 2 sub-sub categories
# Sub-sub category: Deaths, Death Rates and Mortality has 6 dataset
# Sub-sub category: Life Expectancy has 1 dataset
#
# Sub category: Education, Language Spoken and Literacy has 11 sub-sub categories
# Sub-sub category: Highest Qualification Attained (HQA) has 2 dataset
# Sub-sub category: Mean Years of Schooling has 1 dataset
# Sub-sub category: Key Literacy and Proficiency Indicators has 2 dataset
# Sub-sub category: Census of Population and General Household Survey has 11 dataset
# Sub-sub category: Enrolment has 12 dataset
# Sub-sub category: Graduates has 8 dataset
# Sub-sub category: Intake has 3 dataset
# Sub-sub category: School Stage Completion or Graduation Rate has 6 dataset
# Sub-sub category: Schools, Students and Education Officers has 6 dataset
# Sub-sub category: Training has 2 dataset
# Sub-sub category: Government Expenditure on Education has 2 dataset
#
# Sub category: Religion has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 2 dataset
#
# Sub category: Mode of Transport has 1 sub-sub categories
# Sub-sub category: Census of Population and General Household Survey has 3 dataset
#
# Sub category: Difficulty Performing Basic Activities has 1 sub-sub categories
# Sub-sub category: Census of Population has 6 dataset
#
# Sub category: Elderly, Youth and Gender Profile has 4 sub-sub categories
# Sub-sub category: Elderly has 1 dataset
# Sub-sub category: Census of Population and General Household Survey has 1 dataset
# Sub-sub category: Youth has 1 dataset
# Sub-sub category: Gender has 1 dataset
#
# Main category: Households
# Total sub categories:
# 4
# Sub category: Household Expenditure has 1 sub-sub categories
# Sub-sub category: Household Expenditure Survey has 14 dataset
#
# Sub category: Household Income has 8 sub-sub categories
# Sub-sub category: Average and Median Household Income from Work has 4 dataset
# Sub-sub category: Average Household Income from Work by Type of Dwelling/Deciles has 12 dataset
# Sub-sub category: Household Income from Work at Selected Percentiles has 6 dataset
# Sub-sub category: Government Transfers and Taxes has 3 dataset
# Sub-sub category: Household Characteristics has 3 dataset
# Sub-sub category: Income Inequality has 2 dataset
# Sub-sub category: Key Indicators On Household Income From Work has 1 dataset
# Sub-sub category: Census of Population and General Household Survey has 2 dataset
#
# Sub category: Households has 2 sub-sub categories
# Sub-sub category: Resident Households has 6 dataset
# Sub-sub category: Census of Population and General Household Survey has 3 dataset
#
# Sub category: Households With Consumer Durables/ Services has 1 sub-sub categories
# Sub-sub category: Availability of Selected Consumer Durables/ Services has 1 dataset
#
# Main category: Society
# Total sub categories:
# 7
# Sub category: Community Services has 6 sub-sub categories
# Sub-sub category: Charities has 4 dataset
# Sub-sub category: Grassroots Organisations has 2 dataset
# Sub-sub category: Seniors has 2 dataset
# Sub-sub category: Social and Family Services has 4 dataset
# Sub-sub category: Social Assistance and Support has 3 dataset
# Sub-sub category: Volunteers and Volunteer Groups has 2 dataset
#
# Sub category: Culture and Recreation has 1 sub-sub categories
# Sub-sub category: The Arts, Sports, Interest Groups and Visitors to Places of Interest has 10 dataset
#
# Sub category: Environment has 4 sub-sub categories
# Sub-sub category: Air Quality and Climate has 5 dataset
# Sub-sub category: Land Area and Land Use has 5 dataset
# Sub-sub category: Solid Waste Management has 2 dataset
# Sub-sub category: Water and Sanitation has 1 dataset
#
# Sub category: Health has 9 sub-sub categories
# Sub-sub category: Admissions and Outpatient Attendances has 4 dataset
# Sub-sub category: Drug Abusers has 1 dataset
# Sub-sub category: Government Health Expenditure has 1 dataset
# Sub-sub category: Health Facilities has 2 dataset
# Sub-sub category: Health Personnel has 2 dataset
# Sub-sub category: Immunisation has 4 dataset
# Sub-sub category: Indicators on Health has 2 dataset
# Sub-sub category: Notifiable Diseases has 5 dataset
# Sub-sub category: Student Health Assessment has 2 dataset
#
# Sub category: Juveniles and Youth at Risk has 1 sub-sub categories
# Sub-sub category: New Cases and Admissions has 3 dataset
#
# Sub category: Protection and Welfare has 2 sub-sub categories
# Sub-sub category: Child Protection and Welfare has 1 dataset
# Sub-sub category: Personal and Family Protection has 1 dataset
#
# Sub category: Public Safety has 6 sub-sub categories
# Sub-sub category: Convicted Penal Population has 3 dataset
# Sub-sub category: Crimes and Offences has 4 dataset
# Sub-sub category: Emergency Medical Services has 1 dataset
# Sub-sub category: Fire Occurrences has 3 dataset
# Sub-sub category: Persons Arrested has 2 dataset
# Sub-sub category: Unlicensed Moneylending And Harassment has 2 dataset

# %%
# Check datasets amount
print(len(singstat_data_dict))

df = pd.DataFrame.from_dict(singstat_data_dict, orient="index", columns=["Dataset url"])
df.reset_index(inplace=True)

dataset_category_list = ["Theme", "Categories", "SubCategories", "Dataset"]
df[dataset_category_list] = df["index"].str.split(">",expand=True)

datetime_now = datetime.now().strftime("%d/%m/%Y %H:%M:%S")
file_name_date = datetime_now().strfttme("%d%m%Y_%H%M%S")

df["Date_of_check"] = datetime_now

dataset_filename = f"Singstat_dataset_{file_name_date}.csv"
df.to_csv(dataset_filename,index=True)

df.head()
# Out:
# 867
#                                                index  \
# 0  Economy & Prices>Balance of Payments (BOP)>Sin...
# 1  Economy & Prices>Balance of Payments (BOP)>Sin...
# 2  Economy & Prices>Balance of Payments (BOP)>Sin...
# 3  Economy & Prices>Balance of Payments (BOP)>Sin...
# 4  Economy & Prices>Balance of Payments (BOP)>Sin...
#
#                                          Dataset url
# 0  https://tablebuilder.singstat.gov.sg/table/TS/...
# 1  https://tablebuilder.singstat.gov.sg/table/TS/...
# 2  https://tablebuilder.singstat.gov.sg/table/TS/...
# 3  https://tablebuilder.singstat.gov.sg/table/TS/...
# 4  https://tablebuilder.singstat.gov.sg/table/TS/...

# %% [markdown]
# ## Note on filtering from driver.find_elements (big bracket over):
# Example 3rd element of all find elements:
# detailsAccordion = driver.find_elements(by=By.XPATH, value="(//*[contains(@class, 'is-open sgds-accordion-body')])[2]")

# %%
detailsAccordion = driver.find_elements(by=By.XPATH, value="(//*[contains(@class, 'is-open sgds-accordion-body')])[2]")
detailsAccordion
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="081dccc68fc703cfa846c88cc73ba243", element="f.70A807E70882149E9A2ADEECF7E68E8D.d.946879DEBFEF4C7C62F943CB1E5E1C1D.e.191")>]
